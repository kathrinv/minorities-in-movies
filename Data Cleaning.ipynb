# %% [markdown]
# **Movie attributes**
#
# https://developers.themoviedb.org/3/movies/get-movie-details
# 1. box office gross revenue (Int'l + US) (API: movie details - 'revenue')
#     - international gross
#     - US gross
# 2. Movie name(API: movie details - 'original_title')
# 3. Budget (API: movie details - 'budget')
# 4. IMDB number (or any other unique movie ID) (API: movie details - 'id' or 'imdb_id)
# 5. Release Date (year) (API: movie details - 'release_date')
# . Popularity (API: movie details - 'popularity')
# 6. Number of theaters (or how widespread release)
# 7. Country of Release (US only)
# 8. Genre(s)
# 9. Actors/Actresses
#     - Separate table (Join table)
# 10. Reviews (time permitting)
# 11. Awards (time permitting)
#
# **Join Table**
# Use /movie/{movie_id}/credits API
# https://developers.themoviedb.org/3/movies/get-movie-credits
# 1. Movie ID
# 2. Actor/Actress name or ID
#
# **Movie Actors/Actresses**
# 1. Name
# 2. Ethnicity - web scrape https://ethnicelebs.com/
# 3. A-list or not (how to define this?)
# 4. Awards

# %% [markdown]
# ## API call to obtain list of most popular movies by Release Year

# %%
def get_movies_by_year(year, page_num):
    import config
    import requests
    import json
    
    api_url = 'https://api.themoviedb.org/3/discover/movie'
    api_filter = '&primary_release_year='+year+'&sort_by=popularity.desc&page='
    api_call = api_url + config.api_key + api_filter
    response = requests.get(api_call+str(page_num))
    if response.status_code == 200:
        result = response.json() 
        movie_ids = []
        for movie in result['results']:
            movie_ids.append(movie['id'])
        return movie_ids
    else:
        print("There was an error:", response.status_code)

# %%
def api_get_movie_details(movie):
    api_url = 'https://api.themoviedb.org/3/movie/'
    api_call = api_url + str(movie) + config.api_key
    response = requests.get(api_call)
    return response

# %%
def create_movie_detail_dict(result):
    movie_dict = {}
    movie_dict['id'] = result['id']
    movie_dict['imdb_id'] = result['imdb_id']
    movie_dict['name'] = result['title']
    movie_dict['budget'] = result['budget']
    movie_dict['revenue'] = result['revenue']
    movie_dict['popularity'] = result['popularity']
    movie_dict['release_date'] = result['release_date']
    movie_dict['vote_average'] = result['vote_average']
    movie_dict['vote_count'] = result['vote_count']
    movie_dict['runtime'] = result['runtime']
    for country in result['production_countries']:
        if country['name'] == 'United States of America':
            movie_dict['production_country'] = 'US'
    if 'production_country' not in movie_dict:
        movie_dict['production_country'] = 'non-US'
    movie_dict['language'] = result['original_language']
    return movie_dict

# %%
def create_movie_genre_dict(result):
    genres_list = []
    genre_dict = {}
    for genre in result['genres']:
        genres_list.append(genre['name'])
    genre_dict[result['id']] = genres_list
    return genre_dict

# %%
def movie_formatting(movie):
    movie_tuple = (movie['id'], movie['imdb_id'], movie['name'], movie['budget'], 
    movie['revenue'], movie['popularity'], 
    movie['release_date'], movie['vote_average'], 
    movie['vote_count'], movie['runtime'], movie['production_country'], movie['language'])
    return movie_tuple

# %%
def add_to_db_movie(movie_tuple):
    cnx = mysql.connector.connect(
    host = config.host,
    user = config.user,
    password = config.password,
    database = config.database)
    c = cnx.cursor()    
    stmt = """INSERT INTO details (id,
       imdb_id,
       name,
       budget,
       revenue,
       popularity,
       release_date,
       vote_average,
       vote_count,
       runtime,
       production_country,
       language) VALUES (%s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s) ON DUPLICATE KEY UPDATE id = id;"""
    c.execute(stmt, movie_tuple)
    cnx.commit()
    c.close()
    cnx.close()

# %%
def add_to_db_movies(movie_list):
    cnx = mysql.connector.connect(
    host = config.host,
    user = config.user,
    password = config.password,
    database = config.database)
    c = cnx.cursor()    
    stmt = """INSERT INTO details (id,
       imdb_id,
       name,
       budget,
       revenue,
       popularity,
       release_date,
       vote_average,
       vote_count,
       runtime,
       production_country,
       language) VALUES (%s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s);"""
    c.executemany(stmt, movie_list)
    cnx.commit()
    c.close()
    cnx.close()

# %%
genre = {385922: []}

# %%
a = genre.items()

# %%
def genre_formatting(genre):
    for key, value in genre.items():
        if value:
            many_genres = []
            for genre in value:
                genre_tuple = (key, genre)
                many_genres.append(genre_tuple)
            return many_genres
        else:
            return (key, '')

# %%
def add_to_db_genres(genre_list):
    cnx = mysql.connector.connect(
    host = config.host,
    user = config.user,
    password = config.password,
    database = config.database)
    c = cnx.cursor()    
    stmt = """INSERT INTO genre (id, genre)
       VALUES (%s, %s) ON DUPLICATE KEY UPDATE id = id;"""
    c.executemany(stmt, genre_list)
    cnx.commit()
    c.close()
    cnx.close()

# %%
def get_and_format_movies(year, page_num):
    movie_ids = get_movies_by_year(year, page_num)
    for movie in movie_ids:
        response = api_get_movie_details(movie)
        if response.status_code == 200:
            result = response.json()
            movie_dict = create_movie_detail_dict(result)
            movie_tuple = movie_formatting(movie_dict)
            print(movie_dict)
            add_to_db_movie(movie_tuple)
        
            genre_dict = create_movie_genre_dict(result)
            print(genre_dict)
            genre_list = genre_formatting(genre_dict)
            add_to_db_genres(genre_list)

# %%
years = ['2017']
for year in years:
    for page_num in range(6, 20):
        get_and_format_movies(year, page_num)
# Out:
# {'id': 324852, 'imdb_id': 'tt3469046', 'name': 'Despicable Me 3', 'budget': 80000000, 'revenue': 1031552585, 'popularity': 12.43, 'release_date': '2017-06-15', 'vote_average': 6.3, 'vote_count': 4301, 'runtime': 96, 'production_country': 'US', 'language': 'en'}
# {324852: ['Action', 'Animation', 'Comedy', 'Family', 'Adventure']}
# {'id': 289222, 'imdb_id': 'tt1730768', 'name': "The Zookeeper's Wife", 'budget': 20000000, 'revenue': 23299081, 'popularity': 9.344, 'release_date': '2017-03-31', 'vote_average': 7.4, 'vote_count': 774, 'runtime': 126, 'production_country': 'US', 'language': 'en'}
# {289222: ['Drama', 'History']}
# {'id': 372343, 'imdb_id': 'tt1758810', 'name': 'The Snowman', 'budget': 35000000, 'revenue': 43203413, 'popularity': 14.988, 'release_date': '2017-10-12', 'vote_average': 5.1, 'vote_count': 1287, 'runtime': 119, 'production_country': 'US', 'language': 'en'}
# {372343: ['Crime', 'Thriller']}
# {'id': 407445, 'imdb_id': 'tt5716464', 'name': 'Breathe', 'budget': 0, 'revenue': 477815, 'popularity': 10.322, 'release_date': '2017-10-13', 'vote_average': 7.5, 'vote_count': 347, 'runtime': 118, 'production_country': 'non-US', 'language': 'en'}
# {407445: ['Drama', 'Romance']}
# {'id': 418680, 'imdb_id': 'tt1653665', 'name': 'Goodbye Christopher Robin', 'budget': 0, 'revenue': 7299662, 'popularity': 11.063, 'release_date': '2017-09-29', 'vote_average': 7.1, 'vote_count': 438, 'runtime': 107, 'production_country': 'non-US', 'language': 'en'}
# {418680: ['Family', 'History']}
# {'id': 446791, 'imdb_id': 'tt5294550', 'name': 'All the Money in the World', 'budget': 50000000, 'revenue': 56996304, 'popularity': 13.758, 'release_date': '2017-12-21', 'vote_average': 6.4, 'vote_count': 1263, 'runtime': 132, 'production_country': 'US', 'language': 'en'}
# {446791: ['Thriller', 'Drama', 'Crime', 'Mystery']}
# {'id': 400106, 'imdb_id': 'tt5519340', 'name': 'Bright', 'budget': 90000000, 'revenue': 0, 'popularity': 14.058, 'release_date': '2017-12-22', 'vote_average': 6.2, 'vote_count': 3363, 'runtime': 117, 'production_country': 'US', 'language': 'en'}
# {400106: ['Action', 'Crime', 'Fantasy']}
# {'id': 378018, 'imdb_id': 'tt4255304', 'name': 'The Void', 'budget': 0, 'revenue': 151042, 'popularity': 11.038, 'release_date': '2017-01-15', 'vote_average': 5.8, 'vote_count': 548, 'runtime': 90, 'production_country': 'non-US', 'language': 'en'}
# {378018: ['Mystery', 'Horror', 'Science Fiction']}
# {'id': 408220, 'imdb_id': 'tt2494376', 'name': 'Justice League Dark', 'budget': 0, 'revenue': 0, 'popularity': 9.279, 'release_date': '2017-01-24', 'vote_average': 6.9, 'vote_count': 419, 'runtime': 75, 'production_country': 'US', 'language': 'en'}
# {408220: ['Action', 'Animation', 'Fantasy', 'Science Fiction', 'Thriller']}
# {'id': 428449, 'imdb_id': 'tt6265828', 'name': 'A Ghost Story', 'budget': 100000, 'revenue': 1596371, 'popularity': 11.26, 'release_date': '2017-04-24', 'vote_average': 7.0, 'vote_count': 974, 'runtime': 93, 'production_country': 'US', 'language': 'en'}
# {428449: ['Drama', 'Fantasy', 'Romance']}
# {'id': 417644, 'imdb_id': 'tt0493405', 'name': 'CHiPS', 'budget': 25000000, 'revenue': 26800152, 'popularity': 10.745, 'release_date': '2017-01-16', 'vote_average': 6.0, 'vote_count': 693, 'runtime': 100, 'production_country': 'US', 'language': 'en'}
# {417644: ['Action', 'Comedy', 'Crime']}
# {'id': 419479, 'imdb_id': 'tt4225622', 'name': 'The Babysitter', 'budget': 0, 'revenue': 0, 'popularity': 10.949, 'release_date': '2017-10-13', 'vote_average': 5.9, 'vote_count': 1669, 'runtime': 85, 'production_country': 'US', 'language': 'en'}
# {419479: ['Horror', 'Comedy']}
# {'id': 438736, 'imdb_id': 'tt6318848', 'name': 'The Heretics', 'budget': 0, 'revenue': 0, 'popularity': 7.891, 'release_date': '2017-11-01', 'vote_average': 5.1, 'vote_count': 28, 'runtime': 87, 'production_country': 'non-US', 'language': 'en'}
# {438736: ['Horror', 'Fantasy']}
# {'id': 343674, 'imdb_id': 'tt3748172', 'name': "Gerald's Game", 'budget': 0, 'revenue': 0, 'popularity': 13.126, 'release_date': '2017-09-19', 'vote_average': 6.4, 'vote_count': 1824, 'runtime': 104, 'production_country': 'US', 'language': 'en'}
# {343674: ['Drama', 'Horror', 'Thriller']}
# {'id': 345914, 'imdb_id': 'tt4481514', 'name': 'The House', 'budget': 40000000, 'revenue': 0, 'popularity': 8.98, 'release_date': '2017-06-29', 'vote_average': 5.7, 'vote_count': 511, 'runtime': 88, 'production_country': 'US', 'language': 'en'}
# {345914: ['Comedy']}
# {'id': 418078, 'imdb_id': 'tt4695012', 'name': 'It Comes at Night', 'budget': 5000000, 'revenue': 0, 'popularity': 11.622, 'release_date': '2017-06-09', 'vote_average': 5.7, 'vote_count': 1204, 'runtime': 91, 'production_country': 'US', 'language': 'en'}
# {418078: ['Horror']}
# {'id': 373569, 'imdb_id': 'tt2334871', 'name': 'Snatched', 'budget': 42000000, 'revenue': 60845711, 'popularity': 9.704, 'release_date': '2017-05-03', 'vote_average': 5.2, 'vote_count': 515, 'runtime': 90, 'production_country': 'US', 'language': 'en'}
# {373569: ['Action', 'Comedy']}
# {'id': 399019, 'imdb_id': 'tt5592248', 'name': 'The Beguiled', 'budget': 10500000, 'revenue': 27397655, 'popularity': 11.655, 'release_date': '2017-06-23', 'vote_average': 5.7, 'vote_count': 1248, 'runtime': 93, 'production_country': 'US', 'language': 'en'}
# {399019: ['Drama', 'Western']}
# {'id': 398181, 'imdb_id': 'tt5742374', 'name': 'You Were Never Really Here', 'budget': 0, 'revenue': 2528078, 'popularity': 12.352, 'release_date': '2017-11-08', 'vote_average': 6.6, 'vote_count': 1130, 'runtime': 89, 'production_country': 'US', 'language': 'en'}
# {398181: ['Thriller']}
# {'id': 417678, 'imdb_id': 'tt5001718', 'name': 'Everything, Everything', 'budget': 10000000, 'revenue': 34000284, 'popularity': 11.642, 'release_date': '2017-05-18', 'vote_average': 7.2, 'vote_count': 2602, 'runtime': 96, 'production_country': 'US', 'language': 'en'}
# {417678: ['Drama', 'Romance']}
# {'id': 55341, 'imdb_id': 'tt1139592', 'name': 'Jeepers Creepers 3', 'budget': 30000000, 'revenue': 0, 'popularity': 9.196, 'release_date': '2017-09-26', 'vote_average': 4.3, 'vote_count': 343, 'runtime': 100, 'production_country': 'US', 'language': 'en'}
# {55341: ['Horror', 'Mystery', 'Thriller']}
# {'id': 369894, 'imdb_id': 'tt5195412', 'name': 'Wakefield', 'budget': 0, 'revenue': 0, 'popularity': 10.436, 'release_date': '2017-05-19', 'vote_average': 6.1, 'vote_count': 183, 'runtime': 106, 'production_country': 'US', 'language': 'en'}
# {369894: ['Drama']}
# {'id': 420622, 'imdb_id': 'tt6133130', 'name': 'Professor Marston and the Wonder Women', 'budget': 0, 'revenue': 1584759, 'popularity': 9.677, 'release_date': '2017-10-13', 'vote_average': 7.2, 'vote_count': 388, 'runtime': 108, 'production_country': 'US', 'language': 'en'}
# {420622: ['Drama', 'Romance']}
# {'id': 423899, 'imdb_id': 'tt5816682', 'name': 'Victoria & Abdul', 'budget': 0, 'revenue': 65421267, 'popularity': 8.922, 'release_date': '2017-09-14', 'vote_average': 6.9, 'vote_count': 661, 'runtime': 112, 'production_country': 'US', 'language': 'en'}
# {423899: ['Drama', 'History']}
# {'id': 399057, 'imdb_id': 'tt5715874', 'name': 'The Killing of a Sacred Deer', 'budget': 0, 'revenue': 2291901, 'popularity': 16.672, 'release_date': '2017-10-20', 'vote_average': 6.9, 'vote_count': 1659, 'runtime': 121, 'production_country': 'US', 'language': 'en'}
# {399057: ['Drama', 'Thriller', 'Mystery']}
# {'id': 401104, 'imdb_id': 'tt5541240', 'name': 'To the Bone', 'budget': 0, 'revenue': 0, 'popularity': 9.911, 'release_date': '2017-01-22', 'vote_average': 7.3, 'vote_count': 2349, 'runtime': 107, 'production_country': 'US', 'language': 'en'}
# {401104: ['Drama']}
# {'id': 324849, 'imdb_id': 'tt4116284', 'name': 'The Lego Batman Movie', 'budget': 80000000, 'revenue': 311950384, 'popularity': 14.146, 'release_date': '2017-02-08', 'vote_average': 7.2, 'vote_count': 3015, 'runtime': 104, 'production_country': 'US', 'language': 'en'}
# {324849: ['Action', 'Animation', 'Comedy', 'Family', 'Fantasy']}
# {'id': 339987, 'imdb_id': 'tt4721124', 'name': 'The Exception', 'budget': 0, 'revenue': 708973, 'popularity': 11.643, 'release_date': '2017-06-02', 'vote_average': 6.9, 'vote_count': 193, 'runtime': 107, 'production_country': 'US', 'language': 'en'}
# {339987: ['Drama']}
# {'id': 448358, 'imdb_id': 'tt4208432', 'name': 'Darker Shades of Elise', 'budget': 0, 'revenue': 0, 'popularity': 15.14, 'release_date': '2017-07-10', 'vote_average': 4.5, 'vote_count': 13, 'runtime': 92, 'production_country': 'non-US', 'language': 'en'}
# {448358: ['Thriller', 'Drama']}
# {'id': 440597, 'imdb_id': 'tt5322012', 'name': 'Wish Upon', 'budget': 12000000, 'revenue': 14301505, 'popularity': 10.879, 'release_date': '2017-07-07', 'vote_average': 5.4, 'vote_count': 738, 'runtime': 90, 'production_country': 'non-US', 'language': 'en'}
# {440597: ['Thriller', 'Horror', 'Fantasy']}
# {'id': 424488, 'imdb_id': 'tt4899370', 'name': 'Megan Leavey', 'budget': 0, 'revenue': 13406883, 'popularity': 12.574, 'release_date': '2017-06-09', 'vote_average': 7.1, 'vote_count': 401, 'runtime': 116, 'production_country': 'US', 'language': 'en'}
# {424488: ['Drama', 'War']}
# {'id': 437670, 'imdb_id': 'tt6471264', 'name': 'Suck Me Shakespeer 3', 'budget': 0, 'revenue': 0, 'popularity': 13.621, 'release_date': '2017-10-26', 'vote_average': 6.1, 'vote_count': 183, 'runtime': 119, 'production_country': 'non-US', 'language': 'de'}
# {437670: ['Comedy']}
# {'id': 438740, 'imdb_id': 'tt6537238', 'name': 'Salyut-7', 'budget': 15000000, 'revenue': 13767037, 'popularity': 8.118, 'release_date': '2017-09-22', 'vote_average': 7.0, 'vote_count': 167, 'runtime': 106, 'production_country': 'non-US', 'language': 'ru'}
# {438740: ['Action', 'Drama', 'Adventure']}
# {'id': 429189, 'imdb_id': 'tt5825380', 'name': 'Wonder Wheel', 'budget': 25000000, 'revenue': 15366466, 'popularity': 9.117, 'release_date': '2017-12-01', 'vote_average': 6.3, 'vote_count': 756, 'runtime': 101, 'production_country': 'US', 'language': 'en'}
# {429189: ['Drama']}
# {'id': 341174, 'imdb_id': 'tt4465564', 'name': 'Fifty Shades Darker', 'budget': 55000000, 'revenue': 378827494, 'popularity': 11.625, 'release_date': '2017-02-08', 'vote_average': 6.1, 'vote_count': 4655, 'runtime': 118, 'production_country': 'US', 'language': 'en'}
# {341174: ['Drama', 'Romance']}
# {'id': 339404, 'imdb_id': 'tt4565520', 'name': 'The Layover', 'budget': 0, 'revenue': 0, 'popularity': 15.803, 'release_date': '2017-09-01', 'vote_average': 5.1, 'vote_count': 370, 'runtime': 88, 'production_country': 'US', 'language': 'en'}
# {339404: ['Comedy', 'Romance']}
# {'id': 433356, 'imdb_id': 'tt4943322', 'name': 'The Ottoman Lieutenant', 'budget': 40000000, 'revenue': 240978, 'popularity': 11.848, 'release_date': '2017-03-10', 'vote_average': 6.0, 'vote_count': 136, 'runtime': 111, 'production_country': 'US', 'language': 'en'}
# {433356: ['Romance', 'Drama', 'War']}
# {'id': 429191, 'imdb_id': 'tt5639354', 'name': 'A Fantastic Woman', 'budget': 0, 'revenue': 1880736, 'popularity': 10.997, 'release_date': '2017-04-06', 'vote_average': 7.1, 'vote_count': 367, 'runtime': 104, 'production_country': 'non-US', 'language': 'es'}
# {429191: ['Drama']}
# {'id': 323368, 'imdb_id': 'tt3011960', 'name': 'Hangman', 'budget': 0, 'revenue': 0, 'popularity': 10.85, 'release_date': '2017-12-22', 'vote_average': 5.7, 'vote_count': 242, 'runtime': 98, 'production_country': 'US', 'language': 'en'}
# {323368: ['Mystery', 'Crime', 'Thriller']}
# {'id': 427900, 'imdb_id': 'tt5719700', 'name': 'Home Again', 'budget': 12000000, 'revenue': 27020284, 'popularity': 8.587, 'release_date': '2017-09-07', 'vote_average': 6.0, 'vote_count': 707, 'runtime': 97, 'production_country': 'US', 'language': 'en'}
# {427900: ['Comedy', 'Drama', 'Romance']}
# {'id': 330947, 'imdb_id': 'tt2062700', 'name': 'Song to Song', 'budget': 10000000, 'revenue': 1710528, 'popularity': 8.769, 'release_date': '2017-03-17', 'vote_average': 5.4, 'vote_count': 494, 'runtime': 129, 'production_country': 'US', 'language': 'en'}
# {330947: ['Drama', 'Music', 'Romance']}
# {'id': 293768, 'imdb_id': 'tt1458169', 'name': 'Kidnap', 'budget': 21000000, 'revenue': 30718107, 'popularity': 13.321, 'release_date': '2017-06-16', 'vote_average': 6.1, 'vote_count': 842, 'runtime': 95, 'production_country': 'US', 'language': 'en'}
# {293768: ['Drama', 'Thriller']}
# {'id': 381289, 'imdb_id': 'tt1753383', 'name': "A Dog's Purpose", 'budget': 22000000, 'revenue': 194647323, 'popularity': 13.014, 'release_date': '2017-01-19', 'vote_average': 7.3, 'vote_count': 1609, 'runtime': 100, 'production_country': 'US', 'language': 'en'}
# {381289: ['Comedy', 'Drama', 'Family', 'Fantasy', 'Adventure']}
# {'id': 429174, 'imdb_id': 'tt6304162', 'name': 'Loveless', 'budget': 0, 'revenue': 566356, 'popularity': 8.762, 'release_date': '2017-06-01', 'vote_average': 7.5, 'vote_count': 358, 'runtime': 127, 'production_country': 'non-US', 'language': 'ru'}
# {429174: ['Drama']}
# {'id': 417320, 'imdb_id': 'tt5117876', 'name': 'Descendants 2', 'budget': 0, 'revenue': 0, 'popularity': 13.312, 'release_date': '2017-07-21', 'vote_average': 7.3, 'vote_count': 819, 'runtime': 111, 'production_country': 'US', 'language': 'en'}
# {417320: ['Family', 'Action', 'Comedy', 'Adventure']}
# {'id': 413998, 'imdb_id': 'tt4411596', 'name': 'My Cousin Rachel', 'budget': 0, 'revenue': 9200168, 'popularity': 9.31, 'release_date': '2017-06-08', 'vote_average': 5.5, 'vote_count': 357, 'runtime': 106, 'production_country': 'US', 'language': 'en'}
# {413998: ['Drama', 'Romance']}
# {'id': 350312, 'imdb_id': 'tt4849438', 'name': 'Baahubali 2: The Conclusion', 'budget': 40000000, 'revenue': 275947313, 'popularity': 7.706, 'release_date': '2017-04-27', 'vote_average': 7.0, 'vote_count': 271, 'runtime': 168, 'production_country': 'non-US', 'language': 'te'}
# {350312: ['Action', 'Drama']}
# {'id': 452507, 'imdb_id': 'tt6214928', 'name': '1922', 'budget': 0, 'revenue': 0, 'popularity': 11.059, 'release_date': '2017-10-20', 'vote_average': 5.9, 'vote_count': 1344, 'runtime': 101, 'production_country': 'US', 'language': 'en'}
# {452507: ['Crime', 'Drama', 'Horror', 'Mystery', 'Thriller']}
# {'id': 301337, 'imdb_id': 'tt1389072', 'name': 'Downsizing', 'budget': 68000000, 'revenue': 55003890, 'popularity': 9.757, 'release_date': '2017-12-22', 'vote_average': 5.1, 'vote_count': 1997, 'runtime': 135, 'production_country': 'US', 'language': 'en'}
# {301337: ['Comedy', 'Drama', 'Science Fiction']}
# {'id': 335777, 'imdb_id': 'tt3486626', 'name': 'The Nut Job 2: Nutty by Nature', 'budget': 40000000, 'revenue': 65146020, 'popularity': 11.863, 'release_date': '2017-08-11', 'vote_average': 5.7, 'vote_count': 238, 'runtime': 91, 'production_country': 'US', 'language': 'en'}
# {335777: ['Family', 'Animation', 'Adventure', 'Comedy']}
# {'id': 354287, 'imdb_id': 'tt4758646', 'name': 'War Machine', 'budget': 60000000, 'revenue': 0, 'popularity': 8.995, 'release_date': '2017-05-26', 'vote_average': 5.5, 'vote_count': 614, 'runtime': 122, 'production_country': 'US', 'language': 'en'}
# {354287: ['Comedy', 'Drama', 'War']}
# {'id': 418437, 'imdb_id': 'tt3462710', 'name': 'Unforgettable', 'budget': 12000000, 'revenue': 17768012, 'popularity': 9.29, 'release_date': '2017-03-06', 'vote_average': 5.5, 'vote_count': 330, 'runtime': 100, 'production_country': 'US', 'language': 'en'}
# {418437: ['Drama', 'Thriller']}
# {'id': 300687, 'imdb_id': 'tt1230168', 'name': 'Same Kind of Different as Me', 'budget': 6500000, 'revenue': 6423381, 'popularity': 8.296, 'release_date': '2017-10-20', 'vote_average': 6.8, 'vote_count': 113, 'runtime': 119, 'production_country': 'US', 'language': 'en'}
# {300687: ['Drama']}
# {'id': 401898, 'imdb_id': 'tt6304046', 'name': 'Thelma', 'budget': 5741614, 'revenue': 147391, 'popularity': 8.041, 'release_date': '2017-09-15', 'vote_average': 7.1, 'vote_count': 381, 'runtime': 117, 'production_country': 'non-US', 'language': 'no'}
# {401898: ['Romance', 'Drama', 'Mystery']}
# {'id': 419680, 'imdb_id': 'tt5657846', 'name': "Daddy's Home 2", 'budget': 69000000, 'revenue': 180613180, 'popularity': 10.787, 'release_date': '2017-11-09', 'vote_average': 6.1, 'vote_count': 1346, 'runtime': 100, 'production_country': 'US', 'language': 'en'}
# {419680: ['Comedy']}
# {'id': 425134, 'imdb_id': 'tt4795124', 'name': 'How to Be a Latin Lover', 'budget': 0, 'revenue': 26251899, 'popularity': 11.28, 'release_date': '2017-04-28', 'vote_average': 6.3, 'vote_count': 203, 'runtime': 115, 'production_country': 'US', 'language': 'en'}
# {425134: ['Comedy']}
# {'id': 405775, 'imdb_id': 'tt4218696', 'name': 'The Wall', 'budget': 0, 'revenue': 1803009, 'popularity': 8.781, 'release_date': '2017-05-12', 'vote_average': 6.1, 'vote_count': 428, 'runtime': 90, 'production_country': 'US', 'language': 'en'}
# {405775: ['Thriller', 'War', 'Drama']}
# {'id': 392982, 'imdb_id': 'tt5301662', 'name': 'Marshall', 'budget': 12000000, 'revenue': 10051659, 'popularity': 13.532, 'release_date': '2017-10-13', 'vote_average': 7.3, 'vote_count': 282, 'runtime': 118, 'production_country': 'US', 'language': 'en'}
# {392982: ['Drama']}
# {'id': 411741, 'imdb_id': 'tt5962210', 'name': 'Ingrid Goes West', 'budget': 0, 'revenue': 24931915, 'popularity': 11.278, 'release_date': '2017-08-11', 'vote_average': 6.5, 'vote_count': 449, 'runtime': 97, 'production_country': 'US', 'language': 'en'}
# {411741: ['Drama', 'Comedy']}
# {'id': 451644, 'imdb_id': 'tt5610626', 'name': 'Dragonheart: Battle for the Heartfire', 'budget': 0, 'revenue': 0, 'popularity': 7.246, 'release_date': '2017-07-09', 'vote_average': 5.9, 'vote_count': 99, 'runtime': 98, 'production_country': 'US', 'language': 'en'}
# {451644: ['Adventure']}
# {'id': 423646, 'imdb_id': 'tt5723272', 'name': 'In the Fade', 'budget': 0, 'revenue': 321011, 'popularity': 9.03, 'release_date': '2017-11-23', 'vote_average': 7.0, 'vote_count': 408, 'runtime': 106, 'production_country': 'non-US', 'language': 'de'}
# {423646: ['Drama', 'Crime']}
# {'id': 347984, 'imdb_id': 'tt4703048', 'name': '6 Days', 'budget': 1500000, 'revenue': 0, 'popularity': 10.223, 'release_date': '2017-08-03', 'vote_average': 5.9, 'vote_count': 337, 'runtime': 95, 'production_country': 'non-US', 'language': 'en'}
# {347984: ['Action', 'Drama', 'History', 'Thriller']}
# {'id': 460648, 'imdb_id': 'tt5813366', 'name': 'Bleeding Steel', 'budget': 65000000, 'revenue': 0, 'popularity': 13.723, 'release_date': '2017-12-18', 'vote_average': 5.4, 'vote_count': 138, 'runtime': 109, 'production_country': 'non-US', 'language': 'zh'}
# {460648: ['Action', 'Science Fiction', 'Thriller']}
# {'id': 203835, 'imdb_id': 'tt1935897', 'name': 'Amityville: The Awakening', 'budget': 0, 'revenue': 0, 'popularity': 9.709, 'release_date': '2017-07-20', 'vote_average': 5.4, 'vote_count': 670, 'runtime': 85, 'production_country': 'US', 'language': 'en'}
# {203835: ['Thriller', 'Horror']}
# {'id': 333354, 'imdb_id': 'tt2957760', 'name': 'Extortion', 'budget': 0, 'revenue': 0, 'popularity': 10.754, 'release_date': '2017-01-02', 'vote_average': 6.1, 'vote_count': 141, 'runtime': 108, 'production_country': 'US', 'language': 'en'}
# {333354: ['Action', 'Adventure', 'Crime', 'Drama', 'Thriller']}
# {'id': 407448, 'imdb_id': 'tt5390504', 'name': 'Detroit', 'budget': 34000000, 'revenue': 16790139, 'popularity': 11.509, 'release_date': '2017-07-28', 'vote_average': 7.3, 'vote_count': 848, 'runtime': 143, 'production_country': 'US', 'language': 'en'}
# {407448: ['Crime', 'Drama', 'Thriller', 'History']}
# {'id': 400617, 'imdb_id': 'tt5776858', 'name': 'Phantom Thread', 'budget': 35000000, 'revenue': 47756590, 'popularity': 9.456, 'release_date': '2017-12-25', 'vote_average': 7.3, 'vote_count': 1716, 'runtime': 130, 'production_country': 'US', 'language': 'en'}
# {400617: ['Drama', 'Romance']}
# {'id': 414425, 'imdb_id': 'tt2396589', 'name': 'Mudbound', 'budget': 10000000, 'revenue': 0, 'popularity': 9.751, 'release_date': '2017-11-16', 'vote_average': 7.6, 'vote_count': 626, 'runtime': 135, 'production_country': 'US', 'language': 'en'}
# {414425: ['Drama']}
# {'id': 354861, 'imdb_id': 'tt1966359', 'name': 'Father Figures', 'budget': 25000000, 'revenue': 25601244, 'popularity': 8.252, 'release_date': '2017-12-21', 'vote_average': 5.8, 'vote_count': 298, 'runtime': 125, 'production_country': 'US', 'language': 'en'}
# {354861: ['Comedy']}
# {'id': 445954, 'imdb_id': 'tt6288694', 'name': 'Acts of Vengeance', 'budget': 10000000, 'revenue': 0, 'popularity': 12.442, 'release_date': '2017-10-27', 'vote_average': 5.7, 'vote_count': 215, 'runtime': 87, 'production_country': 'US', 'language': 'en'}
# {445954: ['Thriller', 'Action', 'Drama']}
# {'id': 269795, 'imdb_id': 'tt1131724', 'name': '2:22', 'budget': 0, 'revenue': 3500000, 'popularity': 8.93, 'release_date': '2017-06-29', 'vote_average': 5.8, 'vote_count': 843, 'runtime': 99, 'production_country': 'US', 'language': 'en'}
# {269795: ['Drama', 'Thriller', 'Romance', 'Science Fiction', 'Mystery']}
# {'id': 449574, 'imdb_id': 'tt5979874', 'name': 'Godzilla: Planet of the Monsters', 'budget': 0, 'revenue': 0, 'popularity': 11.617, 'release_date': '2017-11-17', 'vote_average': 6.1, 'vote_count': 194, 'runtime': 89, 'production_country': 'non-US', 'language': 'ja'}
# {449574: ['Action', 'Adventure', 'Science Fiction', 'Animation']}
# {'id': 345915, 'imdb_id': 'tt4694544', 'name': 'Once Upon a Time in Venice', 'budget': 0, 'revenue': 0, 'popularity': 11.96, 'release_date': '2017-06-08', 'vote_average': 5.2, 'vote_count': 323, 'runtime': 94, 'production_country': 'US', 'language': 'en'}
# {345915: ['Action', 'Comedy', 'Thriller', 'Mystery']}
# {'id': 437311, 'imdb_id': 'tt3469798', 'name': 'Orbiter 9', 'budget': 0, 'revenue': 0, 'popularity': 10.454, 'release_date': '2017-04-07', 'vote_average': 5.8, 'vote_count': 135, 'runtime': 95, 'production_country': 'non-US', 'language': 'es'}
# {437311: ['Drama', 'Science Fiction', 'Romance']}
# {'id': 390056, 'imdb_id': 'tt4986134', 'name': 'Rebel in the Rye', 'budget': 0, 'revenue': 354363, 'popularity': 7.454, 'release_date': '2017-09-15', 'vote_average': 6.9, 'vote_count': 107, 'runtime': 106, 'production_country': 'US', 'language': 'en'}
# {390056: ['Drama', 'Romance']}
# {'id': 399366, 'imdb_id': 'tt5886440', 'name': 'Marrowbone', 'budget': 8000000, 'revenue': 11165901, 'popularity': 10.952, 'release_date': '2017-10-27', 'vote_average': 7.1, 'vote_count': 546, 'runtime': 111, 'production_country': 'non-US', 'language': 'en'}
# {399366: ['Drama', 'Horror', 'Thriller', 'Mystery']}
# {'id': 444539, 'imdb_id': 'tt3127022', 'name': 'The Bookshop', 'budget': 3582070, 'revenue': 0, 'popularity': 15.525, 'release_date': '2017-11-10', 'vote_average': 6.6, 'vote_count': 165, 'runtime': 110, 'production_country': 'non-US', 'language': 'en'}
# {444539: ['Romance', 'Drama']}
# {'id': 335360, 'imdb_id': 'tt4131800', 'name': 'My Little Pony: The Movie', 'budget': 0, 'revenue': 60330833, 'popularity': 10.679, 'release_date': '2017-10-05', 'vote_average': 6.8, 'vote_count': 150, 'runtime': 99, 'production_country': 'US', 'language': 'en'}
# {335360: ['Music', 'Adventure', 'Animation', 'Family', 'Fantasy']}
# {'id': 441701, 'imdb_id': 'tt5862312', 'name': 'Veronica', 'budget': 0, 'revenue': 0, 'popularity': 7.178, 'release_date': '2017-08-25', 'vote_average': 6.2, 'vote_count': 890, 'runtime': 105, 'production_country': 'non-US', 'language': 'es'}
# {441701: ['Horror']}
# {'id': 430354, 'imdb_id': 'tt4720702', 'name': 'Bushwick', 'budget': 0, 'revenue': 0, 'popularity': 11.0, 'release_date': '2017-07-30', 'vote_average': 5.2, 'vote_count': 225, 'runtime': 94, 'production_country': 'US', 'language': 'en'}
# {430354: ['Thriller', 'Action']}
# {'id': 76812, 'imdb_id': 'tt2090465', 'name': 'Black Butterfly', 'budget': 0, 'revenue': 0, 'popularity': 11.663, 'release_date': '2017-05-26', 'vote_average': 6.3, 'vote_count': 314, 'runtime': 93, 'production_country': 'US', 'language': 'en'}
# {76812: ['Thriller']}
# {'id': 397837, 'imdb_id': 'tt1691916', 'name': 'Before I Fall', 'budget': 5000000, 'revenue': 12141122, 'popularity': 12.057, 'release_date': '2017-03-02', 'vote_average': 7.0, 'vote_count': 2281, 'runtime': 98, 'production_country': 'US', 'language': 'en'}
# {397837: ['Drama', 'Mystery', 'Thriller', 'Fantasy']}
# {'id': 420648, 'imdb_id': 'tt5121816', 'name': 'The Bar', 'budget': 0, 'revenue': 0, 'popularity': 8.095, 'release_date': '2017-02-15', 'vote_average': 6.2, 'vote_count': 684, 'runtime': 102, 'production_country': 'non-US', 'language': 'es'}
# {420648: ['Horror', 'Thriller', 'Comedy']}
# {'id': 433808, 'imdb_id': 'tt5638642', 'name': 'The Ritual', 'budget': 10000000, 'revenue': 1056376, 'popularity': 11.948, 'release_date': '2017-10-11', 'vote_average': 6.0, 'vote_count': 1202, 'runtime': 94, 'production_country': 'non-US', 'language': 'en'}
# {433808: ['Horror']}
# {'id': 468202, 'imdb_id': 'tt6892400', 'name': 'The Girl in the Fog', 'budget': 0, 'revenue': 0, 'popularity': 7.597, 'release_date': '2017-10-26', 'vote_average': 6.8, 'vote_count': 400, 'runtime': 128, 'production_country': 'non-US', 'language': 'it'}
# {468202: ['Crime', 'Thriller']}
# {'id': 353569, 'imdb_id': 'tt1412528', 'name': 'Table 19', 'budget': 5000000, 'revenue': 5042014, 'popularity': 10.087, 'release_date': '2017-03-03', 'vote_average': 6.0, 'vote_count': 636, 'runtime': 87, 'production_country': 'US', 'language': 'en'}
# {353569: ['Comedy', 'Drama']}
# {'id': 416477, 'imdb_id': 'tt5462602', 'name': 'The Big Sick', 'budget': 5000000, 'revenue': 56303596, 'popularity': 13.132, 'release_date': '2017-03-30', 'vote_average': 7.5, 'vote_count': 1365, 'runtime': 120, 'production_country': 'US', 'language': 'en'}
# {416477: ['Comedy', 'Drama', 'Romance']}
# {'id': 460846, 'imdb_id': 'tt3501112', 'name': 'Security', 'budget': 15000000, 'revenue': 0, 'popularity': 11.626, 'release_date': '2017-03-04', 'vote_average': 6.0, 'vote_count': 366, 'runtime': 87, 'production_country': 'US', 'language': 'en'}
# {460846: ['Action', 'Thriller', 'Crime']}
# {'id': 455839, 'imdb_id': 'tt4815122', 'name': 'Time Trap', 'budget': 3, 'revenue': 0, 'popularity': 10.711, 'release_date': '2017-05-19', 'vote_average': 6.3, 'vote_count': 86, 'runtime': 95, 'production_country': 'US', 'language': 'en'}
# {455839: ['Adventure', 'Science Fiction']}
# {'id': 395993, 'imdb_id': 'tt3881784', 'name': 'Stronger', 'budget': 30000000, 'revenue': 5796490, 'popularity': 10.829, 'release_date': '2017-09-22', 'vote_average': 7.0, 'vote_count': 825, 'runtime': 119, 'production_country': 'US', 'language': 'en'}
# {395993: ['Drama']}
# {'id': 394117, 'imdb_id': 'tt5649144', 'name': 'The Florida Project', 'budget': 2000000, 'revenue': 11303040, 'popularity': 10.129, 'release_date': '2017-10-06', 'vote_average': 7.4, 'vote_count': 1211, 'runtime': 111, 'production_country': 'US', 'language': 'en'}
# {394117: ['Drama']}
# {'id': 378236, 'imdb_id': 'tt4877122', 'name': 'The Emoji Movie', 'budget': 50000000, 'revenue': 216909830, 'popularity': 12.974, 'release_date': '2017-07-23', 'vote_average': 5.4, 'vote_count': 1568, 'runtime': 86, 'production_country': 'US', 'language': 'en'}
# {378236: ['Animation', 'Family', 'Comedy']}
# {'id': 454699, 'imdb_id': 'tt6572702', 'name': 'Happy Family', 'budget': 0, 'revenue': 26441892, 'popularity': 11.119, 'release_date': '2017-08-24', 'vote_average': 5.5, 'vote_count': 144, 'runtime': 93, 'production_country': 'non-US', 'language': 'en'}
# {454699: ['Animation', 'Family', 'Fantasy', 'Horror', 'Comedy']}
# {'id': 460793, 'imdb_id': 'tt5452780', 'name': "Olaf's Frozen Adventure", 'budget': 0, 'revenue': 0, 'popularity': 11.616, 'release_date': '2017-10-27', 'vote_average': 6.1, 'vote_count': 869, 'runtime': 22, 'production_country': 'US', 'language': 'en'}
# {460793: ['Adventure', 'Animation', 'Comedy', 'Family', 'Fantasy', 'Music']}
# {'id': 435577, 'imdb_id': 'tt3300980', 'name': 'The 12th Man', 'budget': 7806306, 'revenue': 0, 'popularity': 11.368, 'release_date': '2017-12-25', 'vote_average': 7.5, 'vote_count': 163, 'runtime': 136, 'production_country': 'non-US', 'language': 'no'}
# {435577: ['Drama', 'War']}
# {'id': 425980, 'imdb_id': 'tt5884230', 'name': "Brad's Status", 'budget': 0, 'revenue': 2400000, 'popularity': 8.114, 'release_date': '2017-09-14', 'vote_average': 6.1, 'vote_count': 178, 'runtime': 101, 'production_country': 'US', 'language': 'en'}
# {425980: ['Comedy', 'Drama']}
# {'id': 417870, 'imdb_id': 'tt3564472', 'name': 'Girls Trip', 'budget': 19000000, 'revenue': 140376621, 'popularity': 7.86, 'release_date': '2017-07-21', 'vote_average': 6.8, 'vote_count': 997, 'runtime': 122, 'production_country': 'US', 'language': 'en'}
# {417870: ['Comedy']}
# {'id': 355547, 'imdb_id': 'tt4587656', 'name': 'The Star', 'budget': 10000000, 'revenue': 0, 'popularity': 11.863, 'release_date': '2017-11-15', 'vote_average': 5.5, 'vote_count': 247, 'runtime': 86, 'production_country': 'US', 'language': 'en'}
# {355547: ['Comedy', 'Adventure', 'Family', 'Fantasy', 'Animation']}
# {'id': 301355, 'imdb_id': 'tt1712192', 'name': 'Message from the King', 'budget': 0, 'revenue': 0, 'popularity': 9.353, 'release_date': '2017-05-10', 'vote_average': 6.3, 'vote_count': 211, 'runtime': 102, 'production_country': 'non-US', 'language': 'en'}
# {301355: ['Thriller']}
# {'id': 369192, 'imdb_id': 'tt4622512', 'name': 'Battle of the Sexes', 'budget': 25000000, 'revenue': 12638526, 'popularity': 8.602, 'release_date': '2017-09-05', 'vote_average': 6.9, 'vote_count': 1093, 'runtime': 121, 'production_country': 'US', 'language': 'en'}
# {369192: ['Comedy', 'Drama', 'History']}
# {'id': 410554, 'imdb_id': 'tt5884234', 'name': 'First Kill', 'budget': 10000000, 'revenue': 0, 'popularity': 9.596, 'release_date': '2017-07-21', 'vote_average': 5.5, 'vote_count': 267, 'runtime': 97, 'production_country': 'US', 'language': 'en'}
# {410554: ['Action', 'Thriller', 'Crime']}
# {'id': 444458, 'imdb_id': 'tt6637112', 'name': 'Tatlong Bibe', 'budget': 0, 'revenue': 0, 'popularity': 12.339, 'release_date': '2017-03-01', 'vote_average': 0.0, 'vote_count': 0, 'runtime': None, 'production_country': 'non-US', 'language': 'tl'}
# {444458: ['Drama', 'Family']}
# {'id': 334521, 'imdb_id': 'tt4158096', 'name': 'Free Fire', 'budget': 10000000, 'revenue': 1799312, 'popularity': 9.589, 'release_date': '2017-03-31', 'vote_average': 6.3, 'vote_count': 573, 'runtime': 90, 'production_country': 'non-US', 'language': 'en'}
# {334521: ['Action', 'Crime', 'Mystery']}
# {'id': 438347, 'imdb_id': 'tt6009140', 'name': 'Wedding Unplanned', 'budget': 0, 'revenue': 0, 'popularity': 9.834, 'release_date': '2017-04-26', 'vote_average': 6.1, 'vote_count': 262, 'runtime': 94, 'production_country': 'non-US', 'language': 'fr'}
# {438347: ['Romance', 'Comedy']}
# {'id': 430424, 'imdb_id': 'tt5258850', 'name': 'See You Up There', 'budget': 24100000, 'revenue': 0, 'popularity': 10.588, 'release_date': '2017-10-25', 'vote_average': 8.0, 'vote_count': 683, 'runtime': 113, 'production_country': 'non-US', 'language': 'fr'}
# {430424: ['Drama', 'Crime', 'Comedy', 'War']}
# {'id': 444705, 'imdb_id': 'tt6648926', 'name': 'Dave Chappelle: The Age of Spin', 'budget': 0, 'revenue': 0, 'popularity': 6.58, 'release_date': '2017-03-21', 'vote_average': 7.9, 'vote_count': 119, 'runtime': 67, 'production_country': 'US', 'language': 'en'}
# {444705: ['Comedy']}
# {'id': 345938, 'imdb_id': 'tt2872518', 'name': 'The Shack', 'budget': 20000000, 'revenue': 92924405, 'popularity': 9.322, 'release_date': '2017-03-03', 'vote_average': 7.1, 'vote_count': 846, 'runtime': 132, 'production_country': 'US', 'language': 'en'}
# {345938: ['Drama', 'Fantasy']}
# {'id': 375183, 'imdb_id': 'tt1718924', 'name': 'A Family Man', 'budget': 0, 'revenue': 0, 'popularity': 7.572, 'release_date': '2017-05-18', 'vote_average': 6.7, 'vote_count': 263, 'runtime': 108, 'production_country': 'US', 'language': 'en'}
# {375183: ['Drama']}
# {'id': 436931, 'imdb_id': 'tt6595896', 'name': 'Pokémon the Movie: I Choose You!', 'budget': 0, 'revenue': 0, 'popularity': 8.817, 'release_date': '2017-07-15', 'vote_average': 7.0, 'vote_count': 321, 'runtime': 98, 'production_country': 'non-US', 'language': 'ja'}
# {436931: ['Family', 'Fantasy', 'Adventure', 'Animation', 'Drama', 'Comedy']}
# {'id': 401561, 'imdb_id': 'tt5462326', 'name': 'Mom and Dad', 'budget': 0, 'revenue': 169209, 'popularity': 12.068, 'release_date': '2017-09-09', 'vote_average': 5.1, 'vote_count': 410, 'runtime': 84, 'production_country': 'US', 'language': 'en'}
# {401561: ['Thriller', 'Horror', 'Comedy']}
# {'id': 408648, 'imdb_id': 'tt6556890', 'name': 'Batman and Harley Quinn', 'budget': 3500000, 'revenue': 0, 'popularity': 11.565, 'release_date': '2017-08-14', 'vote_average': 5.9, 'vote_count': 311, 'runtime': 74, 'production_country': 'US', 'language': 'en'}
# {408648: ['Adventure', 'Action', 'Animation', 'Science Fiction']}
# {'id': 434203, 'imdb_id': 'tt6408226', 'name': 'Newness', 'budget': 10000000, 'revenue': 0, 'popularity': 10.817, 'release_date': '2017-11-03', 'vote_average': 5.9, 'vote_count': 283, 'runtime': 112, 'production_country': 'US', 'language': 'en'}
# {434203: ['Romance', 'Drama']}
# {'id': 353070, 'imdb_id': 'tt2568862', 'name': 'Going in Style', 'budget': 25000000, 'revenue': 84618541, 'popularity': 9.761, 'release_date': '2017-04-06', 'vote_average': 6.6, 'vote_count': 1417, 'runtime': 96, 'production_country': 'US', 'language': 'en'}
# {353070: ['Crime', 'Comedy']}
# {'id': 429467, 'imdb_id': 'tt4399952', 'name': 'The Lodgers', 'budget': 0, 'revenue': 7362, 'popularity': 9.812, 'release_date': '2017-10-05', 'vote_average': 4.8, 'vote_count': 232, 'runtime': 93, 'production_country': 'non-US', 'language': 'en'}
# {429467: ['Drama', 'Horror', 'Romance', 'Thriller']}
# {'id': 445030, 'imdb_id': 'tt5914996', 'name': 'No Game No Life: Zero', 'budget': 0, 'revenue': 6000000, 'popularity': 8.741, 'release_date': '2017-07-15', 'vote_average': 7.4, 'vote_count': 98, 'runtime': 106, 'production_country': 'non-US', 'language': 'ja'}
# {445030: ['Fantasy', 'Comedy', 'Animation']}
# {'id': 430447, 'imdb_id': 'tt6336356', 'name': "Mary and the Witch's Flower", 'budget': 0, 'revenue': 0, 'popularity': 12.046, 'release_date': '2017-07-08', 'vote_average': 7.1, 'vote_count': 361, 'runtime': 103, 'production_country': 'non-US', 'language': 'ja'}
# {430447: ['Fantasy', 'Adventure', 'Animation']}
# {'id': 387426, 'imdb_id': 'tt3967856', 'name': 'Okja', 'budget': 50000000, 'revenue': 0, 'popularity': 13.494, 'release_date': '2017-06-28', 'vote_average': 7.5, 'vote_count': 2270, 'runtime': 122, 'production_country': 'US', 'language': 'en'}
# {387426: ['Adventure', 'Drama', 'Science Fiction', 'Action']}
# {'id': 180863, 'imdb_id': 'tt2763304', 'name': 'T2 Trainspotting', 'budget': 18000000, 'revenue': 42067430, 'popularity': 8.488, 'release_date': '2017-01-27', 'vote_average': 7.0, 'vote_count': 1834, 'runtime': 117, 'production_country': 'non-US', 'language': 'en'}
# {180863: ['Crime', 'Drama']}
# {'id': 363126, 'imdb_id': 'tt3335606', 'name': 'Berlin Syndrome', 'budget': 0, 'revenue': 201719, 'popularity': 7.539, 'release_date': '2017-04-20', 'vote_average': 6.1, 'vote_count': 363, 'runtime': 116, 'production_country': 'non-US', 'language': 'en'}
# {363126: ['Mystery', 'Thriller', 'Drama']}
# {'id': 435126, 'imdb_id': 'tt6101820', 'name': 'Perfect Strangers', 'budget': 0, 'revenue': 0, 'popularity': 6.746, 'release_date': '2017-12-01', 'vote_average': 6.7, 'vote_count': 342, 'runtime': 101, 'production_country': 'non-US', 'language': 'es'}
# {435126: ['Drama', 'Comedy']}
# {'id': 345922, 'imdb_id': 'tt3401882', 'name': 'Fist Fight', 'budget': 22000000, 'revenue': 41087017, 'popularity': 10.686, 'release_date': '2017-02-16', 'vote_average': 6.0, 'vote_count': 743, 'runtime': 91, 'production_country': 'US', 'language': 'en'}
# {345922: ['Comedy']}
# {'id': 390061, 'imdb_id': 'tt5175450', 'name': 'Mark Felt: The Man Who Brought Down the White House', 'budget': 0, 'revenue': 4372130, 'popularity': 10.736, 'release_date': '2017-09-28', 'vote_average': 5.8, 'vote_count': 234, 'runtime': 103, 'production_country': 'US', 'language': 'en'}
# {390061: ['Drama', 'History', 'Thriller']}
# {'id': 340101, 'imdb_id': 'tt1661275', 'name': 'Their Finest', 'budget': 11795877, 'revenue': 3603484, 'popularity': 11.281, 'release_date': '2017-04-06', 'vote_average': 6.8, 'vote_count': 222, 'runtime': 117, 'production_country': 'non-US', 'language': 'en'}
# {340101: ['Romance', 'War', 'Comedy', 'Drama']}
# {'id': 436343, 'imdb_id': 'tt5607714', 'name': 'On Body and Soul', 'budget': 0, 'revenue': 0, 'popularity': 8.28, 'release_date': '2017-03-02', 'vote_average': 7.4, 'vote_count': 244, 'runtime': 116, 'production_country': 'non-US', 'language': 'hu'}
# {436343: ['Drama', 'Romance']}
# {'id': 403119, 'imdb_id': 'tt2932536', 'name': '47 Meters Down', 'budget': 5500000, 'revenue': 44235023, 'popularity': 9.781, 'release_date': '2017-05-25', 'vote_average': 5.6, 'vote_count': 1627, 'runtime': 89, 'production_country': 'US', 'language': 'en'}
# {403119: ['Drama', 'Thriller', 'Horror', 'Adventure']}
# {'id': 379019, 'imdb_id': 'tt4299300', 'name': 'My Blind Date with Life', 'budget': 0, 'revenue': 0, 'popularity': 6.277, 'release_date': '2017-01-26', 'vote_average': 7.5, 'vote_count': 130, 'runtime': 111, 'production_country': 'non-US', 'language': 'de'}
# {379019: ['Comedy', 'Drama']}
# {'id': 416051, 'imdb_id': 'tt5893264', 'name': 'Based on a True Story', 'budget': 11329550, 'revenue': 0, 'popularity': 11.735, 'release_date': '2017-11-01', 'vote_average': 5.7, 'vote_count': 224, 'runtime': 97, 'production_country': 'non-US', 'language': 'fr'}
# {416051: ['Thriller', 'Mystery', 'Drama']}
# {'id': 340442, 'imdb_id': 'tt3531202', 'name': 'Pilgrimage', 'budget': 0, 'revenue': 0, 'popularity': 10.06, 'release_date': '2017-08-11', 'vote_average': 6.0, 'vote_count': 139, 'runtime': 96, 'production_country': 'non-US', 'language': 'en'}
# {340442: ['Action', 'Adventure', 'Drama']}
# {'id': 335788, 'imdb_id': 'tt4106376', 'name': 'Renegades', 'budget': 66190000, 'revenue': 0, 'popularity': 13.28, 'release_date': '2017-08-21', 'vote_average': 5.7, 'vote_count': 182, 'runtime': 105, 'production_country': 'US', 'language': 'fr'}
# {335788: ['Thriller', 'Action']}
# {'id': 313943, 'imdb_id': 'tt3722614', 'name': 'Revolt', 'budget': 4000000, 'revenue': 0, 'popularity': 12.278, 'release_date': '2017-07-01', 'vote_average': 5.1, 'vote_count': 150, 'runtime': 87, 'production_country': 'non-US', 'language': 'en'}
# {313943: ['Action', 'Science Fiction', 'War']}
# {'id': 339259, 'imdb_id': 'tt3296908', 'name': 'The Man with the Iron Heart', 'budget': 32679734, 'revenue': 0, 'popularity': 12.676, 'release_date': '2017-05-25', 'vote_average': 6.5, 'vote_count': 320, 'runtime': 120, 'production_country': 'US', 'language': 'en'}
# {339259: ['War', 'Action', 'History', 'Thriller']}
# {'id': 382597, 'imdb_id': 'tt5736696', 'name': 'R.A.I.D. Special Unit', 'budget': 32, 'revenue': 0, 'popularity': 9.522, 'release_date': '2017-02-01', 'vote_average': 5.9, 'vote_count': 583, 'runtime': 105, 'production_country': 'non-US', 'language': 'fr'}
# {382597: ['Action', 'Comedy']}
# {'id': 353066, 'imdb_id': 'tt1291566', 'name': 'The Vanishing of Sidney Hall', 'budget': 0, 'revenue': 0, 'popularity': 13.973, 'release_date': '2017-10-06', 'vote_average': 6.7, 'vote_count': 105, 'runtime': 117, 'production_country': 'US', 'language': 'en'}
# {353066: ['Drama', 'Mystery']}
# {'id': 302150, 'imdb_id': 'tt2674358', 'name': "The Hunter's Prayer", 'budget': 17000000, 'revenue': 0, 'popularity': 11.459, 'release_date': '2017-06-08', 'vote_average': 5.7, 'vote_count': 188, 'runtime': 91, 'production_country': 'US', 'language': 'en'}
# {302150: ['Action', 'Thriller']}
# {'id': 428399, 'imdb_id': 'tt1034385', 'name': 'Cold Skin', 'budget': 9831962, 'revenue': 0, 'popularity': 7.905, 'release_date': '2017-10-20', 'vote_average': 6.0, 'vote_count': 216, 'runtime': 106, 'production_country': 'non-US', 'language': 'en'}
# {428399: ['Thriller', 'Science Fiction', 'Horror']}
# {'id': 458353, 'imdb_id': 'tt6752320', 'name': 'High Heel Homicide', 'budget': 0, 'revenue': 0, 'popularity': 7.891, 'release_date': '2017-06-20', 'vote_average': 6.1, 'vote_count': 13, 'runtime': 81, 'production_country': 'US', 'language': 'en'}
# {458353: ['Thriller']}
# {'id': 432976, 'imdb_id': 'tt6333060', 'name': 'Icarus', 'budget': 0, 'revenue': 0, 'popularity': 6.75, 'release_date': '2017-06-03', 'vote_average': 7.8, 'vote_count': 324, 'runtime': 121, 'production_country': 'US', 'language': 'en'}
# {432976: ['Documentary']}
# {'id': 333357, 'imdb_id': 'tt3829378', 'name': 'Stephanie', 'budget': 0, 'revenue': 0, 'popularity': 8.158, 'release_date': '2017-04-27', 'vote_average': 5.7, 'vote_count': 97, 'runtime': 86, 'production_country': 'US', 'language': 'en'}
# {333357: ['Horror', 'Fantasy', 'Drama', 'Mystery']}
# {'id': 397415, 'imdb_id': 'tt5460530', 'name': 'Vengeance: A Love Story', 'budget': 0, 'revenue': 4526, 'popularity': 12.745, 'release_date': '2017-03-16', 'vote_average': 5.6, 'vote_count': 149, 'runtime': 99, 'production_country': 'US', 'language': 'en'}
# {397415: ['Thriller', 'Drama']}
# {'id': 457837, 'imdb_id': 'tt7055592', 'name': 'Brotherhood of Blades II: The Infernal Battlefield', 'budget': 0, 'revenue': 0, 'popularity': 6.658, 'release_date': '2017-08-11', 'vote_average': 6.9, 'vote_count': 22, 'runtime': 120, 'production_country': 'non-US', 'language': 'zh'}
# {457837: ['Romance', 'Action', 'Drama', 'History']}
# {'id': 401513, 'imdb_id': 'tt4731148', 'name': 'Attraction', 'budget': 5027266, 'revenue': 0, 'popularity': 11.738, 'release_date': '2017-01-26', 'vote_average': 5.9, 'vote_count': 220, 'runtime': 117, 'production_country': 'non-US', 'language': 'ru'}
# {401513: ['Drama', 'Romance', 'Science Fiction', 'Adventure']}
# {'id': 365942, 'imdb_id': 'tt3922818', 'name': 'The Space Between Us', 'budget': 30000000, 'revenue': 14793385, 'popularity': 9.179, 'release_date': '2017-01-26', 'vote_average': 7.1, 'vote_count': 1534, 'runtime': 121, 'production_country': 'US', 'language': 'en'}
# {365942: ['Romance', 'Adventure', 'Science Fiction', 'Drama']}
# {'id': 345317, 'imdb_id': 'tt4494718', 'name': 'Final Portrait', 'budget': 0, 'revenue': 1725841, 'popularity': 7.32, 'release_date': '2017-08-03', 'vote_average': 6.0, 'vote_count': 78, 'runtime': 87, 'production_country': 'US', 'language': 'en'}
# {345317: ['Drama', 'Comedy']}
# {'id': 354556, 'imdb_id': 'tt4600952', 'name': 'Guardians', 'budget': 5400000, 'revenue': 4803565, 'popularity': 9.717, 'release_date': '2017-02-14', 'vote_average': 4.5, 'vote_count': 381, 'runtime': 100, 'production_country': 'non-US', 'language': 'ru'}
# {354556: ['Action', 'Fantasy', 'Science Fiction']}
# {'id': 340027, 'imdb_id': 'tt3704700', 'name': 'Brain on Fire', 'budget': 0, 'revenue': 0, 'popularity': 12.223, 'release_date': '2017-02-22', 'vote_average': 7.2, 'vote_count': 739, 'runtime': 88, 'production_country': 'non-US', 'language': 'en'}
# {340027: ['Drama']}
# {'id': 467936, 'imdb_id': 'tt6040662', 'name': 'The Children Act', 'budget': 0, 'revenue': 0, 'popularity': 10.471, 'release_date': '2017-09-09', 'vote_average': 6.6, 'vote_count': 311, 'runtime': 105, 'production_country': 'non-US', 'language': 'en'}
# {467936: ['Drama']}
# {'id': 402529, 'imdb_id': 'tt1666185', 'name': 'All Eyez on Me', 'budget': 40000000, 'revenue': 44922302, 'popularity': 6.417, 'release_date': '2017-06-12', 'vote_average': 6.4, 'vote_count': 713, 'runtime': 139, 'production_country': 'US', 'language': 'en'}
# {402529: ['Drama', 'Music']}
# {'id': 414453, 'imdb_id': 'tt5990474', 'name': 'Columbus', 'budget': 0, 'revenue': 1015744, 'popularity': 11.719, 'release_date': '2017-08-04', 'vote_average': 7.2, 'vote_count': 144, 'runtime': 104, 'production_country': 'US', 'language': 'en'}
# {414453: ['Drama']}
# {'id': 472838, 'imdb_id': 'tt7296862', 'name': 'SPF-18', 'budget': 0, 'revenue': 0, 'popularity': 9.42, 'release_date': '2017-09-29', 'vote_average': 4.5, 'vote_count': 723, 'runtime': 75, 'production_country': 'US', 'language': 'en'}
# {472838: ['Romance', 'Drama']}
# {'id': 437109, 'imdb_id': 'tt6777338', 'name': 'The Villainess', 'budget': 0, 'revenue': 27741, 'popularity': 10.715, 'release_date': '2017-06-08', 'vote_average': 6.8, 'vote_count': 234, 'runtime': 129, 'production_country': 'non-US', 'language': 'ko'}
# {437109: ['Drama', 'Action']}
# {'id': 402897, 'imdb_id': 'tt4686844', 'name': 'The Death of Stalin', 'budget': 0, 'revenue': 24640027, 'popularity': 7.911, 'release_date': '2017-10-20', 'vote_average': 7.0, 'vote_count': 799, 'runtime': 107, 'production_country': 'non-US', 'language': 'en'}
# {402897: ['Comedy', 'History']}
# {'id': 475759, 'imdb_id': 'tt7387408', 'name': '2048: Nowhere to Run', 'budget': 0, 'revenue': 0, 'popularity': 9.957, 'release_date': '2017-09-14', 'vote_average': 6.8, 'vote_count': 138, 'runtime': 6, 'production_country': 'US', 'language': 'en'}
# {475759: ['Science Fiction', 'Thriller', 'Action']}
# {'id': 439584, 'imdb_id': 'tt5897292', 'name': 'I Can Quit Whenever I Want 3: Ad Honorem', 'budget': 0, 'revenue': 0, 'popularity': 8.459, 'release_date': '2017-11-30', 'vote_average': 7.7, 'vote_count': 516, 'runtime': 96, 'production_country': 'non-US', 'language': 'it'}
# {439584: ['Action', 'Comedy']}
# {'id': 513434, 'imdb_id': 'tt7914416', 'name': 'One Cut of the Dead', 'budget': 30000, 'revenue': 200000000, 'popularity': 7.197, 'release_date': '2017-11-04', 'vote_average': 8.3, 'vote_count': 93, 'runtime': 96, 'production_country': 'non-US', 'language': 'ja'}
# {513434: ['Comedy', 'Horror']}
# {'id': 444218, 'imdb_id': 'tt5987402', 'name': 'Three Seconds', 'budget': 0, 'revenue': 51169464, 'popularity': 8.186, 'release_date': '2017-12-28', 'vote_average': 7.9, 'vote_count': 66, 'runtime': 133, 'production_country': 'non-US', 'language': 'ru'}
# {444218: ['Drama']}
# {'id': 423087, 'imdb_id': 'tt5503688', 'name': '6 Below: Miracle on the Mountain', 'budget': 0, 'revenue': 0, 'popularity': 6.446, 'release_date': '2017-10-12', 'vote_average': 5.7, 'vote_count': 183, 'runtime': 97, 'production_country': 'US', 'language': 'en'}
# {423087: ['Thriller', 'Drama']}
# {'id': 419700, 'imdb_id': 'tt5893332', 'name': 'Sandy Wexler', 'budget': 0, 'revenue': 0, 'popularity': 9.19, 'release_date': '2017-04-14', 'vote_average': 5.2, 'vote_count': 231, 'runtime': 130, 'production_country': 'US', 'language': 'en'}
# {419700: ['Comedy']}
# {'id': 413644, 'imdb_id': 'tt5715410', 'name': 'The Son of Bigfoot', 'budget': 30000000, 'revenue': 46372519, 'popularity': 10.687, 'release_date': '2017-07-26', 'vote_average': 6.5, 'vote_count': 175, 'runtime': 92, 'production_country': 'non-US', 'language': 'en'}
# {413644: ['Animation', 'Comedy', 'Family']}
# {'id': 390062, 'imdb_id': 'tt3758172', 'name': 'Jungle', 'budget': 0, 'revenue': 0, 'popularity': 9.39, 'release_date': '2017-06-27', 'vote_average': 6.2, 'vote_count': 870, 'runtime': 115, 'production_country': 'non-US', 'language': 'en'}
# {390062: ['Adventure', 'Drama', 'Thriller']}
# {'id': 334536, 'imdb_id': 'tt3286052', 'name': "The Blackcoat's Daughter", 'budget': 0, 'revenue': 19980, 'popularity': 10.422, 'release_date': '2017-03-31', 'vote_average': 5.7, 'vote_count': 276, 'runtime': 93, 'production_country': 'US', 'language': 'en'}
# {334536: ['Horror', 'Thriller']}
# {'id': 451646, 'imdb_id': 'tt6293032', 'name': 'My Son', 'budget': 0, 'revenue': 0, 'popularity': 9.345, 'release_date': '2017-09-20', 'vote_average': 5.9, 'vote_count': 159, 'runtime': 84, 'production_country': 'non-US', 'language': 'fr'}
# {451646: ['Drama', 'Thriller', 'Mystery']}
# {'id': 403431, 'imdb_id': 'tt5805752', 'name': 'Brigsby Bear', 'budget': 0, 'revenue': 532669, 'popularity': 13.076, 'release_date': '2017-07-27', 'vote_average': 7.3, 'vote_count': 201, 'runtime': 97, 'production_country': 'US', 'language': 'en'}
# {403431: ['Comedy', 'Drama']}
# {'id': 314095, 'imdb_id': 'tt1212428', 'name': 'The Lost City of Z', 'budget': 30000000, 'revenue': 8574339, 'popularity': 11.91, 'release_date': '2017-03-15', 'vote_average': 6.2, 'vote_count': 1476, 'runtime': 140, 'production_country': 'US', 'language': 'en'}
# {314095: ['Adventure', 'Drama', 'History', 'Action']}
# {'id': 416160, 'imdb_id': 'tt1785635', 'name': 'The Vault', 'budget': 5000000, 'revenue': 5728, 'popularity': 10.912, 'release_date': '2017-09-01', 'vote_average': 4.7, 'vote_count': 205, 'runtime': 91, 'production_country': 'US', 'language': 'en'}
# {416160: ['Horror', 'Thriller']}
# ...
# {457262: ['Family', 'Drama']}
# {'id': 475094, 'imdb_id': 'tt6763252', 'name': 'The Captain', 'budget': 0, 'revenue': 0, 'popularity': 11.722, 'release_date': '2017-09-21', 'vote_average': 7.1, 'vote_count': 138, 'runtime': 118, 'production_country': 'non-US', 'language': 'de'}
# {475094: ['War', 'Drama', 'History']}
# {'id': 398177, 'imdb_id': 'tt5721088', 'name': 'Just Getting Started', 'budget': 22000000, 'revenue': 6069605, 'popularity': 8.03, 'release_date': '2017-12-01', 'vote_average': 5.0, 'vote_count': 101, 'runtime': 91, 'production_country': 'US', 'language': 'en'}
# {398177: ['Action', 'Comedy']}
# {'id': 437425, 'imdb_id': 'tt6445396', 'name': 'You Choose!', 'budget': 0, 'revenue': 0, 'popularity': 6.268, 'release_date': '2017-03-15', 'vote_average': 5.9, 'vote_count': 190, 'runtime': 95, 'production_country': 'non-US', 'language': 'fr'}
# {437425: ['Romance', 'Comedy']}
# {'id': 415401, 'imdb_id': 'tt5814592', 'name': 'The Party', 'budget': 0, 'revenue': 3300000, 'popularity': 9.023, 'release_date': '2017-09-13', 'vote_average': 6.4, 'vote_count': 244, 'runtime': 71, 'production_country': 'non-US', 'language': 'en'}
# {415401: ['Comedy', 'Drama']}
# {'id': 437739, 'imdb_id': 'tt7029854', 'name': 'The Mansion', 'budget': 0, 'revenue': 0, 'popularity': 6.52, 'release_date': '2017-06-21', 'vote_average': 5.1, 'vote_count': 242, 'runtime': 100, 'production_country': 'non-US', 'language': 'fr'}
# {437739: ['Horror', 'Comedy']}
# {'id': 346671, 'imdb_id': 'tt2937366', 'name': 'Little Evil', 'budget': 0, 'revenue': 0, 'popularity': 9.515, 'release_date': '2017-08-08', 'vote_average': 5.7, 'vote_count': 560, 'runtime': 94, 'production_country': 'US', 'language': 'en'}
# {346671: ['Comedy', 'Horror']}
# {'id': 351460, 'imdb_id': 'tt1241317', 'name': 'Death Note', 'budget': 40000000, 'revenue': 0, 'popularity': 8.015, 'release_date': '2017-08-25', 'vote_average': 4.2, 'vote_count': 2584, 'runtime': 101, 'production_country': 'US', 'language': 'en'}
# {351460: ['Fantasy', 'Horror', 'Mystery', 'Thriller']}
# {'id': 460790, 'imdb_id': 'tt6977240', 'name': 'Starship Troopers: Traitor of Mars', 'budget': 0, 'revenue': 0, 'popularity': 8.009, 'release_date': '2017-08-21', 'vote_average': 5.6, 'vote_count': 122, 'runtime': 87, 'production_country': 'US', 'language': 'en'}
# {460790: ['Action', 'Animation', 'Science Fiction']}
# {'id': 414190, 'imdb_id': 'tt3171832', 'name': 'iBoy', 'budget': 1500000, 'revenue': 0, 'popularity': 9.255, 'release_date': '2017-01-27', 'vote_average': 6.0, 'vote_count': 727, 'runtime': 90, 'production_country': 'non-US', 'language': 'en'}
# {414190: ['Action', 'Crime', 'Science Fiction']}
# {'id': 429733, 'imdb_id': 'tt4348012', 'name': 'Mayhem', 'budget': 0, 'revenue': 0, 'popularity': 10.256, 'release_date': '2017-03-13', 'vote_average': 6.3, 'vote_count': 238, 'runtime': 86, 'production_country': 'US', 'language': 'en'}
# {429733: ['Action', 'Comedy', 'Horror']}
# {'id': 463602, 'imdb_id': 'tt5181852', 'name': 'Slumber', 'budget': 0, 'revenue': 0, 'popularity': 9.009, 'release_date': '2017-12-01', 'vote_average': 5.0, 'vote_count': 183, 'runtime': 84, 'production_country': 'US', 'language': 'en'}
# {463602: ['Horror']}
# {'id': 429662, 'imdb_id': 'tt4977530', 'name': "Viceroy's House", 'budget': 0, 'revenue': 7823256, 'popularity': 11.495, 'release_date': '2017-03-03', 'vote_average': 6.6, 'vote_count': 156, 'runtime': 106, 'production_country': 'non-US', 'language': 'en'}
# {429662: ['Drama', 'History']}
# {'id': 492282, 'imdb_id': 'tt7129926', 'name': 'Like a Cat on a Highway', 'budget': 0, 'revenue': 0, 'popularity': 11.463, 'release_date': '2017-12-28', 'vote_average': 6.5, 'vote_count': 486, 'runtime': 98, 'production_country': 'non-US', 'language': 'it'}
# {492282: ['Family', 'Comedy']}
# {'id': 397538, 'imdb_id': 'tt5727282', 'name': 'Borg vs McEnroe', 'budget': 7500000, 'revenue': 16657800, 'popularity': 8.0, 'release_date': '2017-09-06', 'vote_average': 7.1, 'vote_count': 593, 'runtime': 108, 'production_country': 'non-US', 'language': 'sv'}
# {397538: ['Drama', 'History']}
# {'id': 242606, 'imdb_id': 'tt2531334', 'name': 'Keep Watching', 'budget': 0, 'revenue': 0, 'popularity': 7.489, 'release_date': '2017-05-04', 'vote_average': 5.1, 'vote_count': 142, 'runtime': 90, 'production_country': 'US', 'language': 'en'}
# {242606: ['Thriller', 'Horror', 'Drama']}
# {'id': 433244, 'imdb_id': 'tt5577742', 'name': 'Clinical', 'budget': 0, 'revenue': 0, 'popularity': 7.237, 'release_date': '2017-01-13', 'vote_average': 5.3, 'vote_count': 217, 'runtime': 104, 'production_country': 'US', 'language': 'en'}
# {433244: ['Thriller', 'Horror']}
# {'id': 406385, 'imdb_id': 'tt5897288', 'name': 'I Can Quit Whenever I Want 2: Masterclass', 'budget': 0, 'revenue': 0, 'popularity': 8.237, 'release_date': '2017-02-02', 'vote_average': 7.5, 'vote_count': 743, 'runtime': 118, 'production_country': 'non-US', 'language': 'it'}
# {406385: ['Action', 'Comedy', 'Crime']}
# {'id': 398920, 'imdb_id': 'tt5256722', 'name': 'He Even Has Your Eyes', 'budget': 0, 'revenue': 0, 'popularity': 7.236, 'release_date': '2017-01-18', 'vote_average': 6.2, 'vote_count': 315, 'runtime': 95, 'production_country': 'non-US', 'language': 'fr'}
# {398920: ['Comedy']}
# {'id': 483104, 'imdb_id': 'tt7608418', 'name': 'A Christmas Prince', 'budget': 0, 'revenue': 0, 'popularity': 7.943, 'release_date': '2017-11-17', 'vote_average': 6.7, 'vote_count': 864, 'runtime': 92, 'production_country': 'US', 'language': 'en'}
# {483104: ['Romance']}
# {'id': 413857, 'imdb_id': 'tt3859272', 'name': 'Tragedy Girls', 'budget': 0, 'revenue': 0, 'popularity': 10.991, 'release_date': '2017-10-20', 'vote_average': 5.9, 'vote_count': 152, 'runtime': 98, 'production_country': 'US', 'language': 'en'}
# {413857: ['Horror', 'Comedy']}
# {'id': 467248, 'imdb_id': 'tt7014110', 'name': 'Bring It On: Worldwide #Cheersmack', 'budget': 0, 'revenue': 0, 'popularity': 6.739, 'release_date': '2017-08-29', 'vote_average': 5.5, 'vote_count': 106, 'runtime': 95, 'production_country': 'US', 'language': 'en'}
# {467248: ['Comedy', 'Romance']}
# {'id': 376540, 'imdb_id': 'tt4419196', 'name': 'Mathilde', 'budget': 25000000, 'revenue': 0, 'popularity': 8.819, 'release_date': '2017-10-25', 'vote_average': 6.3, 'vote_count': 36, 'runtime': 130, 'production_country': 'non-US', 'language': 'ru'}
# {376540: ['History', 'Drama', 'Romance']}
# {'id': 495715, 'imdb_id': 'tt7394406', 'name': 'The Landlord', 'budget': 0, 'revenue': 0, 'popularity': 7.14, 'release_date': '2017-12-26', 'vote_average': 5.1, 'vote_count': 5, 'runtime': 90, 'production_country': 'US', 'language': 'en'}
# {495715: ['Thriller', 'TV Movie']}
# {'id': 419511, 'imdb_id': 'tt6302050', 'name': 'Mister Happiness', 'budget': 0, 'revenue': 0, 'popularity': 6.73, 'release_date': '2017-01-01', 'vote_average': 6.2, 'vote_count': 213, 'runtime': 94, 'production_country': 'non-US', 'language': 'it'}
# {419511: ['Romance', 'Comedy']}
# {'id': 488113, 'imdb_id': 'tt7074092', 'name': 'Christmas Wedding Planner', 'budget': 0, 'revenue': 0, 'popularity': 6.94, 'release_date': '2017-12-14', 'vote_average': 5.5, 'vote_count': 212, 'runtime': 86, 'production_country': 'non-US', 'language': 'en'}
# {488113: ['Romance', 'Family']}
# {'id': 283984, 'imdb_id': 'tt4054952', 'name': "Fate/stay night: Heaven's Feel I. presage flower", 'budget': 0, 'revenue': 8569623, 'popularity': 7.765, 'release_date': '2017-10-14', 'vote_average': 7.4, 'vote_count': 51, 'runtime': 120, 'production_country': 'non-US', 'language': 'ja'}
# {283984: ['Action', 'Animation', 'Drama', 'Fantasy', 'Mystery', 'Thriller']}
# {'id': 383785, 'imdb_id': 'tt4217392', 'name': 'Kung Fu Yoga', 'budget': 65000000, 'revenue': 254212245, 'popularity': 9.977, 'release_date': '2017-01-27', 'vote_average': 5.6, 'vote_count': 155, 'runtime': 130, 'production_country': 'non-US', 'language': 'zh'}
# {383785: ['Mystery', 'Action', 'Adventure', 'Comedy']}
# {'id': 429460, 'imdb_id': 'tt5041296', 'name': 'Muse', 'budget': 0, 'revenue': 0, 'popularity': 9.983, 'release_date': '2017-11-29', 'vote_average': 5.9, 'vote_count': 167, 'runtime': 107, 'production_country': 'non-US', 'language': 'es'}
# {429460: ['Thriller', 'Horror']}
# {'id': 295693, 'imdb_id': 'tt3874544', 'name': 'The Boss Baby', 'budget': 125000000, 'revenue': 498814908, 'popularity': 5.569, 'release_date': '2017-03-23', 'vote_average': 6.4, 'vote_count': 4488, 'runtime': 97, 'production_country': 'US', 'language': 'en'}
# {295693: ['Animation', 'Comedy', 'Family']}
# {'id': 472454, 'imdb_id': 'tt6316138', 'name': 'Ayla: The Daughter of War', 'budget': 4172781, 'revenue': 0, 'popularity': 6.779, 'release_date': '2017-10-27', 'vote_average': 8.3, 'vote_count': 85, 'runtime': 125, 'production_country': 'non-US', 'language': 'tr'}
# {472454: ['Drama', 'War', 'History']}
# {'id': 449664, 'imdb_id': 'tt5159414', 'name': 'Escape Room', 'budget': 0, 'revenue': 0, 'popularity': 8.926, 'release_date': '2017-09-29', 'vote_average': 4.9, 'vote_count': 246, 'runtime': 81, 'production_country': 'US', 'language': 'en'}
# {449664: ['Horror', 'Thriller']}
# {'id': 452068, 'imdb_id': 'tt5352846', 'name': 'Drone', 'budget': 4000000, 'revenue': 0, 'popularity': 9.97, 'release_date': '2017-05-26', 'vote_average': 5.2, 'vote_count': 148, 'runtime': 91, 'production_country': 'non-US', 'language': 'en'}
# {452068: ['Thriller']}
# {'id': 466876, 'imdb_id': 'tt5851786', 'name': 'Gnome Alone', 'budget': 0, 'revenue': 0, 'popularity': 9.271, 'release_date': '2017-11-02', 'vote_average': 6.1, 'vote_count': 85, 'runtime': 85, 'production_country': 'US', 'language': 'en'}
# {466876: ['Adventure', 'Family', 'Animation', 'Comedy', 'Science Fiction', 'Fantasy']}
# {'id': 417830, 'imdb_id': 'tt6003368', 'name': 'Diary of a Wimpy Kid: The Long Haul', 'budget': 22000000, 'revenue': 40120144, 'popularity': 10.216, 'release_date': '2017-05-19', 'vote_average': 5.7, 'vote_count': 210, 'runtime': 91, 'production_country': 'US', 'language': 'en'}
# {417830: ['Comedy', 'Family']}
# {'id': 459928, 'imdb_id': 'tt5143226', 'name': '12 Feet Deep', 'budget': 0, 'revenue': 0, 'popularity': 6.966, 'release_date': '2017-06-20', 'vote_average': 5.3, 'vote_count': 209, 'runtime': 85, 'production_country': 'US', 'language': 'en'}
# {459928: ['Thriller', 'Horror']}
# {'id': 463906, 'imdb_id': 'tt2569088', 'name': 'The Saint', 'budget': 0, 'revenue': 0, 'popularity': 7.966, 'release_date': '2017-07-11', 'vote_average': 5.1, 'vote_count': 137, 'runtime': 92, 'production_country': 'US', 'language': 'en'}
# {463906: ['Action', 'Adventure', 'Crime']}
# {'id': 390054, 'imdb_id': 'tt2582576', 'name': 'Sand Castle', 'budget': 0, 'revenue': 0, 'popularity': 9.212, 'release_date': '2017-04-21', 'vote_average': 6.4, 'vote_count': 366, 'runtime': 113, 'production_country': 'non-US', 'language': 'en'}
# {390054: ['Drama', 'War']}
# {'id': 373546, 'imdb_id': 'tt1610525', 'name': 'Chuck', 'budget': 0, 'revenue': 0, 'popularity': 11.11, 'release_date': '2017-05-05', 'vote_average': 6.4, 'vote_count': 65, 'runtime': 101, 'production_country': 'US', 'language': 'en'}
# {373546: ['Drama']}
# {'id': 382614, 'imdb_id': 'tt4572792', 'name': 'The Book of Henry', 'budget': 10000000, 'revenue': 4504974, 'popularity': 8.211, 'release_date': '2017-06-16', 'vote_average': 7.5, 'vote_count': 635, 'runtime': 105, 'production_country': 'US', 'language': 'en'}
# {382614: ['Drama']}
# {'id': 403867, 'imdb_id': 'tt5460276', 'name': 'Kaabil', 'budget': 5200000, 'revenue': 0, 'popularity': 7.146, 'release_date': '2017-01-26', 'vote_average': 7.1, 'vote_count': 73, 'runtime': 139, 'production_country': 'non-US', 'language': 'hi'}
# {403867: ['Action', 'Thriller', 'Drama']}
# {'id': 472424, 'imdb_id': 'tt7291268', 'name': 'Gaga: Five Foot Two', 'budget': 0, 'revenue': 0, 'popularity': 7.96, 'release_date': '2017-09-08', 'vote_average': 7.7, 'vote_count': 395, 'runtime': 100, 'production_country': 'US', 'language': 'en'}
# {472424: ['Documentary', 'Music']}
# {'id': 440642, 'imdb_id': 'tt6673840', 'name': 'The Spacewalker', 'budget': 7075038, 'revenue': 9868942, 'popularity': 7.451, 'release_date': '2017-04-09', 'vote_average': 7.2, 'vote_count': 153, 'runtime': 140, 'production_country': 'non-US', 'language': 'ru'}
# {440642: ['Adventure', 'Drama', 'History', 'Thriller']}
# {'id': 413594, 'imdb_id': 'tt5544384', 'name': 'Sword Art Online: The Movie - Ordinal Scale', 'budget': 0, 'revenue': 20725409, 'popularity': 10.698, 'release_date': '2017-02-18', 'vote_average': 7.6, 'vote_count': 250, 'runtime': 119, 'production_country': 'non-US', 'language': 'ja'}
# {413594: ['Action', 'Adventure', 'Fantasy', 'Romance', 'Animation', 'Science Fiction']}
# {'id': 362585, 'imdb_id': 'tt5084198', 'name': 'Kizumonogatari Part 3: Reiketsu', 'budget': 0, 'revenue': 0, 'popularity': 5.336, 'release_date': '2017-01-06', 'vote_average': 8.4, 'vote_count': 38, 'runtime': 82, 'production_country': 'non-US', 'language': 'ja'}
# {362585: ['Animation', 'Fantasy', 'Mystery']}
# {'id': 451500, 'imdb_id': 'tt7018010', 'name': 'Christmas & Co.', 'budget': 0, 'revenue': 0, 'popularity': 6.953, 'release_date': '2017-12-06', 'vote_average': 6.3, 'vote_count': 339, 'runtime': 99, 'production_country': 'non-US', 'language': 'fr'}
# {451500: ['Comedy']}
# {'id': 425751, 'imdb_id': 'tt5655222', 'name': 'The Hero', 'budget': 0, 'revenue': 4077333, 'popularity': 9.896, 'release_date': '2017-06-09', 'vote_average': 6.2, 'vote_count': 90, 'runtime': 97, 'production_country': 'US', 'language': 'en'}
# {425751: ['Drama']}
# {'id': 432618, 'imdb_id': 'tt6144762', 'name': 'Coexister', 'budget': 0, 'revenue': 0, 'popularity': 6.949, 'release_date': '2017-10-11', 'vote_average': 6.0, 'vote_count': 231, 'runtime': 90, 'production_country': 'non-US', 'language': 'fr'}
# {432618: ['Comedy']}
# {'id': 411873, 'imdb_id': 'tt5666304', 'name': 'The Little Hours', 'budget': 0, 'revenue': 0, 'popularity': 7.446, 'release_date': '2017-06-30', 'vote_average': 5.6, 'vote_count': 206, 'runtime': 89, 'production_country': 'US', 'language': 'en'}
# {411873: ['Comedy']}
# {'id': 354216, 'imdb_id': 'tt4935372', 'name': "The Devil's Candy", 'budget': 0, 'revenue': 0, 'popularity': 7.942, 'release_date': '2017-03-17', 'vote_average': 6.3, 'vote_count': 361, 'runtime': 79, 'production_country': 'US', 'language': 'en'}
# {354216: ['Horror']}
# {'id': 462883, 'imdb_id': 'tt2114504', 'name': 'Woody Woodpecker', 'budget': 10000000, 'revenue': 0, 'popularity': 6.447, 'release_date': '2017-10-05', 'vote_average': 5.8, 'vote_count': 161, 'runtime': 91, 'production_country': 'US', 'language': 'en'}
# {462883: ['Animation', 'Comedy', 'Family']}
# {'id': 428756, 'imdb_id': 'tt6081632', 'name': 'Marie-Francine', 'budget': 0, 'revenue': 0, 'popularity': 9.942, 'release_date': '2017-05-31', 'vote_average': 5.5, 'vote_count': 133, 'runtime': 95, 'production_country': 'non-US', 'language': 'fr'}
# {428756: ['Comedy']}
# {'id': 426284, 'imdb_id': 'tt5084170', 'name': 'Blade of the Immortal', 'budget': 0, 'revenue': 150532, 'popularity': 10.935, 'release_date': '2017-04-29', 'vote_average': 6.5, 'vote_count': 212, 'runtime': 140, 'production_country': 'non-US', 'language': 'ja'}
# {426284: ['Action', 'Drama']}
# {'id': 439152, 'imdb_id': 'tt5975354', 'name': 'Like Mother, Like Daughter', 'budget': 0, 'revenue': 0, 'popularity': 7.69, 'release_date': '2017-03-29', 'vote_average': 5.6, 'vote_count': 117, 'runtime': 94, 'production_country': 'non-US', 'language': 'fr'}
# {439152: ['Comedy']}
# {'id': 383538, 'imdb_id': 'tt5044656', 'name': 'The Shadow Effect', 'budget': 9000000, 'revenue': 0, 'popularity': 5.119, 'release_date': '2017-05-02', 'vote_average': 4.8, 'vote_count': 81, 'runtime': 93, 'production_country': 'US', 'language': 'en'}
# {383538: ['Science Fiction', 'Action', 'Thriller']}
# {'id': 455558, 'imdb_id': 'tt4917224', 'name': '9/11', 'budget': 0, 'revenue': 0, 'popularity': 6.941, 'release_date': '2017-09-07', 'vote_average': 4.9, 'vote_count': 113, 'runtime': 88, 'production_country': 'US', 'language': 'en'}
# {455558: ['Drama']}

# %%
years = ['2009', '2008']
years completed = 2016, 2018(16-20), 2016(16-20), 2015, 2014, 2013, 2012, 2011, 2010

# %%
def get_and_format_actors():
    movie_ids = get_movie_list()
    actor_tuples = []
    for movie in movie_ids:
        actor_dict = get_actors_api_call(movie[0])
        actor_movie_list = actor_movie_formatting(actor_dict)
        actor_tuples.append(actor_dict)
        add_to_db_actor_movie(actor_movie_list)
    return actor_tuples

# %%
get_and_format_actors()
# Out:
# [[],
#  [{'movie_id': 96936, 'actor_id': 1053170, 'order': 0, 'name': 'Katie Chang'},
#   {'movie_id': 96936,
#    'actor_id': 969140,
#    'order': 1,
#    'name': 'Israel Broussard'},
#   {'movie_id': 96936, 'actor_id': 10990, 'order': 2, 'name': 'Emma Watson'},
#   {'movie_id': 96936,
#    'actor_id': 1172491,
#    'order': 3,
#    'name': 'Claire Julien'},
#   {'movie_id': 96936,
#    'actor_id': 527313,
#    'order': 4,
#    'name': 'Taissa Farmiga'}],
#  [{'movie_id': 97020, 'actor_id': 92404, 'order': 0, 'name': 'Joel Kinnaman'},
#   {'movie_id': 97020, 'actor_id': 64, 'order': 1, 'name': 'Gary Oldman'},
#   {'movie_id': 97020, 'actor_id': 2232, 'order': 2, 'name': 'Michael Keaton'},
#   {'movie_id': 97020, 'actor_id': 37260, 'order': 3, 'name': 'Abbie Cornish'},
#   {'movie_id': 97020,
#    'actor_id': 17183,
#    'order': 4,
#    'name': 'Jackie Earle Haley'}],
#  [{'movie_id': 97051, 'actor_id': 29221, 'order': 0, 'name': 'Brittany Snow'},
#   {'movie_id': 97051, 'actor_id': 27993, 'order': 1, 'name': 'Jeffrey Combs'},
#   {'movie_id': 97051, 'actor_id': 1323612, 'order': 2, 'name': 'Jonny Coyne'},
#   {'movie_id': 97051, 'actor_id': 74251, 'order': 3, 'name': 'Sasha Grey'},
#   {'movie_id': 97051,
#    'actor_id': 37947,
#    'order': 4,
#    'name': 'Lawrence Gilliard Jr.'}],
#  [{'movie_id': 97365,
#    'actor_id': 8293,
#    'order': 0,
#    'name': 'Marion Cotillard'},
#   {'movie_id': 97365,
#    'actor_id': 73381,
#    'order': 1,
#    'name': 'Matthias Schoenaerts'},
#   {'movie_id': 97365, 'actor_id': 47822, 'order': 2, 'name': 'Bouli Lanners'},
#   {'movie_id': 97365,
#    'actor_id': 72255,
#    'order': 3,
#    'name': 'Céline Sallette'},
#   {'movie_id': 97365,
#    'actor_id': 1033671,
#    'order': 4,
#    'name': 'Corinne Masiero'}],
#  [{'movie_id': 97367, 'actor_id': 30614, 'order': 0, 'name': 'Ryan Gosling'},
#   {'movie_id': 97367, 'actor_id': 51329, 'order': 1, 'name': 'Bradley Cooper'},
#   {'movie_id': 97367, 'actor_id': 8170, 'order': 2, 'name': 'Eva Mendes'},
#   {'movie_id': 97367, 'actor_id': 122889, 'order': 3, 'name': 'Dane DeHaan'},
#   {'movie_id': 97367, 'actor_id': 1041440, 'order': 4, 'name': 'Emory Cohen'}],
#  [{'movie_id': 97370,
#    'actor_id': 1245,
#    'order': 0,
#    'name': 'Scarlett Johansson'},
#   {'movie_id': 97370, 'actor_id': 136796, 'order': 1, 'name': 'Kryštof Hádek'},
#   {'movie_id': 97370,
#    'actor_id': 1034704,
#    'order': 2,
#    'name': 'Paul Brannigan'},
#   {'movie_id': 97370,
#    'actor_id': 1047642,
#    'order': 3,
#    'name': 'Michael Moreland'},
#   {'movie_id': 97370,
#    'actor_id': 1047643,
#    'order': 4,
#    'name': 'Scott Dymond'}],
#  [{'movie_id': 97430, 'actor_id': 934, 'order': 0, 'name': 'Russell Crowe'},
#   {'movie_id': 97430, 'actor_id': 140, 'order': 1, 'name': 'Lucy Liu'},
#   {'movie_id': 97430, 'actor_id': 78324, 'order': 2, 'name': 'Jamie Chung'},
#   {'movie_id': 97430, 'actor_id': 150, 'order': 3, 'name': 'RZA'},
#   {'movie_id': 97430, 'actor_id': 1077356, 'order': 4, 'name': 'Zhu Zhu'}],
#  [{'movie_id': 97434, 'actor_id': 5472, 'order': 0, 'name': 'Colin Firth'},
#   {'movie_id': 97434, 'actor_id': 14011, 'order': 1, 'name': 'Tom Courtenay'},
#   {'movie_id': 97434, 'actor_id': 4566, 'order': 2, 'name': 'Alan Rickman'},
#   {'movie_id': 97434, 'actor_id': 2283, 'order': 3, 'name': 'Stanley Tucci'},
#   {'movie_id': 97434, 'actor_id': 6941, 'order': 4, 'name': 'Cameron Diaz'}],
#  [{'movie_id': 97512,
#    'actor_id': 47296,
#    'order': 0,
#    'name': 'Jeffrey Dean Morgan'},
#   {'movie_id': 97512, 'actor_id': 78429, 'order': 1, 'name': 'Josie Ho'},
#   {'movie_id': 97512, 'actor_id': 1844, 'order': 2, 'name': 'Til Schweiger'},
#   {'movie_id': 97512, 'actor_id': 15860, 'order': 3, 'name': 'Miguel Ferrer'},
#   {'movie_id': 97512, 'actor_id': 3127, 'order': 4, 'name': 'Lili Taylor'}],
#  [{'movie_id': 97614, 'actor_id': 8783, 'order': 0, 'name': 'Eric Bana'},
#   {'movie_id': 97614, 'actor_id': 59315, 'order': 1, 'name': 'Olivia Wilde'},
#   {'movie_id': 97614, 'actor_id': 56365, 'order': 2, 'name': 'Charlie Hunnam'},
#   {'movie_id': 97614,
#    'actor_id': 207818,
#    'order': 3,
#    'name': 'Patrick Kerton'},
#   {'movie_id': 97614,
#    'actor_id': 10823,
#    'order': 4,
#    'name': 'Kris Kristofferson'}],
#  [{'movie_id': 97630,
#    'actor_id': 83002,
#    'order': 0,
#    'name': 'Jessica Chastain'},
#   {'movie_id': 97630, 'actor_id': 76512, 'order': 1, 'name': 'Jason Clarke'},
#   {'movie_id': 97630, 'actor_id': 2983, 'order': 2, 'name': 'Mark Strong'},
#   {'movie_id': 97630, 'actor_id': 33192, 'order': 3, 'name': 'Joel Edgerton'},
#   {'movie_id': 97630, 'actor_id': 73457, 'order': 4, 'name': 'Chris Pratt'}],
#  [{'movie_id': 97690, 'actor_id': 1357356, 'order': 1, 'name': 'Anon2World'},
#   {'movie_id': 97690, 'actor_id': 1357357, 'order': 2, 'name': 'Anonyops'},
#   {'movie_id': 97690,
#    'actor_id': 150882,
#    'order': 3,
#    'name': 'Julian Assange'},
#   {'movie_id': 97690, 'actor_id': 1357358, 'order': 4, 'name': 'Aaron Barr'},
#   {'movie_id': 97690,
#    'actor_id': 1357363,
#    'order': 5,
#    'name': 'Barrett Brown'}],
#  [{'movie_id': 97795, 'actor_id': 21633, 'order': 0, 'name': 'Kai Lennox'},
#   {'movie_id': 97795, 'actor_id': 53184, 'order': 1, 'name': 'Rick Gonzalez'},
#   {'movie_id': 97795, 'actor_id': 43135, 'order': 2, 'name': 'Fiona Glascott'},
#   {'movie_id': 97795, 'actor_id': 137424, 'order': 3, 'name': 'Gia Mantegna'},
#   {'movie_id': 97795,
#    'actor_id': 38085,
#    'order': 4,
#    'name': "Michael O'Keefe"}],
#  [{'movie_id': 98066, 'actor_id': 15684, 'order': 0, 'name': 'Paul Schneider'},
#   {'movie_id': 98066, 'actor_id': 81364, 'order': 1, 'name': 'Olivia Munn'},
#   {'movie_id': 98066,
#    'actor_id': 56251,
#    'order': 2,
#    'name': 'Kevin Heffernan'},
#   {'movie_id': 98066, 'actor_id': 65829, 'order': 3, 'name': 'Wood Harris'},
#   {'movie_id': 98066, 'actor_id': 105648, 'order': 4, 'name': 'Nat Faxon'}],
#  [{'movie_id': 98120,
#    'actor_id': 56843,
#    'order': 0,
#    'name': 'Valerio Mastandrea'},
#   {'movie_id': 98120,
#    'actor_id': 17839,
#    'order': 1,
#    'name': 'Pierfrancesco Favino'},
#   {'movie_id': 98120, 'actor_id': 1872711, 'order': 2, 'name': 'Bob Marchese'},
#   {'movie_id': 98120,
#    'actor_id': 105871,
#    'order': 3,
#    'name': 'Michela Cescon'},
#   {'movie_id': 98120, 'actor_id': 88081, 'order': 4, 'name': 'Laura Chiatti'}],
#  [{'movie_id': 98339,
#    'actor_id': 2231,
#    'order': 0,
#    'name': 'Samuel L. Jackson'},
#   {'movie_id': 98339, 'actor_id': 7002, 'order': 1, 'name': 'Luke Kirby'},
#   {'movie_id': 98339, 'actor_id': 17018, 'order': 2, 'name': 'Ruth Negga'},
#   {'movie_id': 98339, 'actor_id': 207, 'order': 3, 'name': 'Tom Wilkinson'},
#   {'movie_id': 98339,
#    'actor_id': 52703,
#    'order': 4,
#    'name': 'Alan C. Peterson'}],
#  [{'movie_id': 98357, 'actor_id': 13240, 'order': 0, 'name': 'Mark Wahlberg'},
#   {'movie_id': 98357, 'actor_id': 934, 'order': 1, 'name': 'Russell Crowe'},
#   {'movie_id': 98357,
#    'actor_id': 1922,
#    'order': 2,
#    'name': 'Catherine Zeta-Jones'},
#   {'movie_id': 98357, 'actor_id': 2954, 'order': 3, 'name': 'Jeffrey Wright'},
#   {'movie_id': 98357, 'actor_id': 12834, 'order': 4, 'name': 'Barry Pepper'}],
#  [{'movie_id': 98545, 'actor_id': 6352, 'order': 0, 'name': 'Jane Fonda'},
#   {'movie_id': 98545,
#    'actor_id': 2229,
#    'order': 1,
#    'name': 'Catherine Keener'},
#   {'movie_id': 98545,
#    'actor_id': 550843,
#    'order': 2,
#    'name': 'Elizabeth Olsen'},
#   {'movie_id': 98545, 'actor_id': 60899, 'order': 3, 'name': 'Chace Crawford'},
#   {'movie_id': 98545,
#    'actor_id': 47296,
#    'order': 4,
#    'name': 'Jeffrey Dean Morgan'}],
#  [{'movie_id': 98548, 'actor_id': 62064, 'order': 0, 'name': 'Chris Pine'},
#   {'movie_id': 98548, 'actor_id': 9281, 'order': 1, 'name': 'Elizabeth Banks'},
#   {'movie_id': 98548, 'actor_id': 59315, 'order': 2, 'name': 'Olivia Wilde'},
#   {'movie_id': 98548,
#    'actor_id': 1160,
#    'order': 3,
#    'name': 'Michelle Pfeiffer'},
#   {'movie_id': 98548, 'actor_id': 45407, 'order': 4, 'name': 'Mark Duplass'}],
#  [{'movie_id': 98566, 'actor_id': 19537, 'order': 0, 'name': 'Megan Fox'},
#   {'movie_id': 98566, 'actor_id': 21200, 'order': 1, 'name': 'Will Arnett'},
#   {'movie_id': 98566, 'actor_id': 886, 'order': 2, 'name': 'William Fichtner'},
#   {'movie_id': 98566, 'actor_id': 64295, 'order': 3, 'name': 'Alan Ritchson'},
#   {'movie_id': 98566, 'actor_id': 80352, 'order': 4, 'name': 'Noel Fisher'}],
#  [{'movie_id': 99770,
#    'actor_id': 16927,
#    'order': 0,
#    'name': 'Gérard Depardieu'},
#   {'movie_id': 99770, 'actor_id': 41035, 'order': 1, 'name': 'Edouard Baer'},
#   {'movie_id': 99770,
#    'actor_id': 6554,
#    'order': 2,
#    'name': 'Guillaume Gallienne'},
#   {'movie_id': 99770,
#    'actor_id': 83797,
#    'order': 3,
#    'name': 'Vincent Lacoste'},
#   {'movie_id': 99770,
#    'actor_id': 62531,
#    'order': 4,
#    'name': 'Valérie Lemercier'}],
#  [{'movie_id': 99861,
#    'actor_id': 3223,
#    'order': 0,
#    'name': 'Robert Downey Jr.'},
#   {'movie_id': 99861, 'actor_id': 16828, 'order': 1, 'name': 'Chris Evans'},
#   {'movie_id': 99861,
#    'actor_id': 74568,
#    'order': 2,
#    'name': 'Chris Hemsworth'},
#   {'movie_id': 99861, 'actor_id': 103, 'order': 3, 'name': 'Mark Ruffalo'},
#   {'movie_id': 99861,
#    'actor_id': 1245,
#    'order': 4,
#    'name': 'Scarlett Johansson'}],
#  [{'movie_id': 100042, 'actor_id': 206, 'order': 0, 'name': 'Jim Carrey'},
#   {'movie_id': 100042, 'actor_id': 8447, 'order': 1, 'name': 'Jeff Daniels'},
#   {'movie_id': 100042,
#    'actor_id': 176497,
#    'order': 2,
#    'name': 'Rachel Melvin'},
#   {'movie_id': 100042,
#    'actor_id': 3391,
#    'order': 3,
#    'name': 'Kathleen Turner'},
#   {'movie_id': 100042, 'actor_id': 77547, 'order': 4, 'name': 'Brady Bluhm'}],
#  [{'movie_id': 100241, 'actor_id': 6383, 'order': 0, 'name': 'Aaron Eckhart'},
#   {'movie_id': 100241,
#    'actor_id': 63312,
#    'order': 1,
#    'name': 'Yvonne Strahovski'},
#   {'movie_id': 100241, 'actor_id': 2440, 'order': 2, 'name': 'Bill Nighy'},
#   {'movie_id': 100241, 'actor_id': 224181, 'order': 3, 'name': 'Jai Courtney'},
#   {'movie_id': 100241, 'actor_id': 502, 'order': 4, 'name': 'Miranda Otto'}],
#  [{'movie_id': 100402, 'actor_id': 16828, 'order': 0, 'name': 'Chris Evans'},
#   {'movie_id': 100402,
#    'actor_id': 2231,
#    'order': 1,
#    'name': 'Samuel L. Jackson'},
#   {'movie_id': 100402,
#    'actor_id': 1245,
#    'order': 2,
#    'name': 'Scarlett Johansson'},
#   {'movie_id': 100402, 'actor_id': 4135, 'order': 3, 'name': 'Robert Redford'},
#   {'movie_id': 100402,
#    'actor_id': 60898,
#    'order': 4,
#    'name': 'Sebastian Stan'}],
#  [{'movie_id': 100683,
#    'actor_id': 15111,
#    'order': 0,
#    'name': 'Jean-Claude Van Damme'},
#   {'movie_id': 100683, 'actor_id': 27811, 'order': 1, 'name': 'Peter Weller'},
#   {'movie_id': 100683, 'actor_id': 116637, 'order': 2, 'name': 'Cung Le'},
#   {'movie_id': 100683,
#    'actor_id': 37149,
#    'order': 3,
#    'name': 'Luis Da Silva Jr.'},
#   {'movie_id': 100683,
#    'actor_id': 208259,
#    'order': 4,
#    'name': 'Crystal Mantecon'}],
#  [{'movie_id': 100898,
#    'actor_id': 1026090,
#    'order': 0,
#    'name': 'Jelle Florizoone'},
#   {'movie_id': 100898,
#    'actor_id': 1026091,
#    'order': 1,
#    'name': 'Mathias Vergels'},
#   {'movie_id': 100898,
#    'actor_id': 228589,
#    'order': 2,
#    'name': 'Eva van der Gucht'},
#   {'movie_id': 100898,
#    'actor_id': 1026092,
#    'order': 3,
#    'name': 'Thomas Coumans'},
#   {'movie_id': 100898, 'actor_id': 218933, 'order': 4, 'name': 'Luk Wyns'}],
#  [{'movie_id': 101173, 'actor_id': 17276, 'order': 0, 'name': 'Gerard Butler'},
#   {'movie_id': 101173, 'actor_id': 5469, 'order': 1, 'name': 'Ralph Fiennes'},
#   {'movie_id': 101173, 'actor_id': 77498, 'order': 2, 'name': 'Lubna Azabal'},
#   {'movie_id': 101173, 'actor_id': 766, 'order': 3, 'name': 'Ashraf Barhom'},
#   {'movie_id': 101173,
#    'actor_id': 83002,
#    'order': 4,
#    'name': 'Jessica Chastain'}],
#  [{'movie_id': 101179, 'actor_id': 88322, 'order': 0, 'name': 'Liam Boyle'},
#   {'movie_id': 101179, 'actor_id': 97505, 'order': 1, 'name': 'Jack Gordon'},
#   {'movie_id': 101179,
#    'actor_id': 1037691,
#    'order': 2,
#    'name': 'Florence Hall'},
#   {'movie_id': 101179, 'actor_id': 500045, 'order': 3, 'name': 'David Oakes'},
#   {'movie_id': 101179,
#    'actor_id': 126173,
#    'order': 4,
#    'name': 'Jennie Jacques'}],
#  [{'movie_id': 101267, 'actor_id': 111455, 'order': 0, 'name': 'Katy Perry'},
#   {'movie_id': 101267, 'actor_id': 59919, 'order': 1, 'name': 'Russell Brand'},
#   {'movie_id': 101267,
#    'actor_id': 82663,
#    'order': 2,
#    'name': 'Shannon Woodward'},
#   {'movie_id': 101267,
#    'actor_id': 143742,
#    'order': 3,
#    'name': 'Rachael Markarian'},
#   {'movie_id': 101267,
#    'actor_id': 1070777,
#    'order': 4,
#    'name': 'Mia Moretti'}],
#  [{'movie_id': 101299,
#    'actor_id': 72129,
#    'order': 0,
#    'name': 'Jennifer Lawrence'},
#   {'movie_id': 101299,
#    'actor_id': 27972,
#    'order': 1,
#    'name': 'Josh Hutcherson'},
#   {'movie_id': 101299,
#    'actor_id': 96066,
#    'order': 2,
#    'name': 'Liam Hemsworth'},
#   {'movie_id': 101299,
#    'actor_id': 57755,
#    'order': 3,
#    'name': 'Woody Harrelson'},
#   {'movie_id': 101299,
#    'actor_id': 9281,
#    'order': 4,
#    'name': 'Elizabeth Banks'}],
#  [{'movie_id': 101519, 'actor_id': 11108, 'order': 0, 'name': 'Simon Pegg'},
#   {'movie_id': 101519, 'actor_id': 652, 'order': 1, 'name': 'Paul Freeman'},
#   {'movie_id': 101519, 'actor_id': 45588, 'order': 2, 'name': 'Clare Higgins'},
#   {'movie_id': 101519, 'actor_id': 66443, 'order': 3, 'name': 'Amara Karan'},
#   {'movie_id': 101519, 'actor_id': 1277052, 'order': 4, 'name': 'Alan Drake'}],
#  [{'movie_id': 101669,
#    'actor_id': 28412,
#    'order': 0,
#    'name': 'Rebecca De Mornay'},
#   {'movie_id': 101669, 'actor_id': 5915, 'order': 1, 'name': 'Jaime King'},
#   {'movie_id': 101669,
#    'actor_id': 115730,
#    'order': 2,
#    'name': 'Patrick John Flueger'},
#   {'movie_id': 101669,
#    'actor_id': 212154,
#    'order': 3,
#    'name': 'Deborah Ann Woll'},
#   {'movie_id': 101669, 'actor_id': 81685, 'order': 4, 'name': 'Frank Grillo'}],
#  [{'movie_id': 101731, 'actor_id': 192, 'order': 0, 'name': 'Morgan Freeman'},
#   {'movie_id': 101731,
#    'actor_id': 12519,
#    'order': 1,
#    'name': 'Virginia Madsen'},
#   {'movie_id': 101731,
#    'actor_id': 62564,
#    'order': 2,
#    'name': 'Madeline Carroll'},
#   {'movie_id': 101731,
#    'actor_id': 1028454,
#    'order': 3,
#    'name': 'Emma Fuhrmann'},
#   {'movie_id': 101731,
#    'actor_id': 1028458,
#    'order': 4,
#    'name': 'Nicolette Pierini'}],
#  [{'movie_id': 102001,
#    'actor_id': 1029801,
#    'order': 0,
#    'name': 'Rin Takanashi'},
#   {'movie_id': 102001,
#    'actor_id': 1029802,
#    'order': 1,
#    'name': 'Tadashi Okuno'},
#   {'movie_id': 102001, 'actor_id': 33517, 'order': 2, 'name': 'Ryo Kase'},
#   {'movie_id': 102001, 'actor_id': 137028, 'order': 3, 'name': 'Denden'},
#   {'movie_id': 102001,
#    'actor_id': 2037512,
#    'order': 4,
#    'name': 'Tomoaki Tatsumi'}],
#  [{'movie_id': 102197,
#    'actor_id': 562730,
#    'order': 0,
#    'name': 'Danila Kozlovsky'},
#   {'movie_id': 102197,
#    'actor_id': 80999,
#    'order': 1,
#    'name': 'Fyodor Bondarchuk'},
#   {'movie_id': 102197,
#    'actor_id': 29832,
#    'order': 2,
#    'name': 'Viktor Verzhbitskiy'},
#   {'movie_id': 102197,
#    'actor_id': 582512,
#    'order': 3,
#    'name': 'Anna Chipovskaya'},
#   {'movie_id': 102197,
#    'actor_id': 30405,
#    'order': 4,
#    'name': 'Sergey Gazarov'}],
#  [{'movie_id': 102207, 'actor_id': 4275, 'order': 0, 'name': 'Alain Chabat'},
#   {'movie_id': 102207, 'actor_id': 2408, 'order': 1, 'name': 'Jamel Debbouze'},
#   {'movie_id': 102207, 'actor_id': 84100, 'order': 2, 'name': 'Fred Testot'},
#   {'movie_id': 102207, 'actor_id': 2192, 'order': 3, 'name': 'Lambert Wilson'},
#   {'movie_id': 102207,
#    'actor_id': 41526,
#    'order': 4,
#    'name': 'Patrick Timsit'}],
#  [{'movie_id': 102362, 'actor_id': 72466, 'order': 0, 'name': 'Colin Farrell'},
#   {'movie_id': 102362, 'actor_id': 87722, 'order': 1, 'name': 'Noomi Rapace'},
#   {'movie_id': 102362,
#    'actor_id': 18288,
#    'order': 2,
#    'name': 'Terrence Howard'},
#   {'movie_id': 102362,
#    'actor_id': 55470,
#    'order': 3,
#    'name': 'Dominic Cooper'},
#   {'movie_id': 102362,
#    'actor_id': 17882,
#    'order': 4,
#    'name': 'Isabelle Huppert'}],
#  [{'movie_id': 102382,
#    'actor_id': 37625,
#    'order': 0,
#    'name': 'Andrew Garfield'},
#   {'movie_id': 102382, 'actor_id': 54693, 'order': 1, 'name': 'Emma Stone'},
#   {'movie_id': 102382, 'actor_id': 134, 'order': 2, 'name': 'Jamie Foxx'},
#   {'movie_id': 102382, 'actor_id': 122889, 'order': 3, 'name': 'Dane DeHaan'},
#   {'movie_id': 102382,
#    'actor_id': 55152,
#    'order': 4,
#    'name': 'Campbell Scott'}],
#  [{'movie_id': 102651,
#    'actor_id': 11701,
#    'order': 0,
#    'name': 'Angelina Jolie'},
#   {'movie_id': 102651, 'actor_id': 18050, 'order': 1, 'name': 'Elle Fanning'},
#   {'movie_id': 102651,
#    'actor_id': 82191,
#    'order': 2,
#    'name': 'Sharlto Copley'},
#   {'movie_id': 102651,
#    'actor_id': 72305,
#    'order': 3,
#    'name': 'Lesley Manville'},
#   {'movie_id': 102651,
#    'actor_id': 11356,
#    'order': 4,
#    'name': 'Imelda Staunton'}],
#  [{'movie_id': 102780,
#    'actor_id': 59620,
#    'order': 0,
#    'name': 'Gemma Arterton'},
#   {'movie_id': 102780, 'actor_id': 36592, 'order': 1, 'name': 'Saoirse Ronan'},
#   {'movie_id': 102780, 'actor_id': 32987, 'order': 2, 'name': 'Sam Riley'},
#   {'movie_id': 102780,
#    'actor_id': 9012,
#    'order': 3,
#    'name': 'Jonny Lee Miller'},
#   {'movie_id': 102780, 'actor_id': 1670, 'order': 4, 'name': 'Daniel Mays'}],
#  [{'movie_id': 102899, 'actor_id': 22226, 'order': 0, 'name': 'Paul Rudd'},
#   {'movie_id': 102899,
#    'actor_id': 3392,
#    'order': 1,
#    'name': 'Michael Douglas'},
#   {'movie_id': 102899,
#    'actor_id': 19034,
#    'order': 2,
#    'name': 'Evangeline Lilly'},
#   {'movie_id': 102899, 'actor_id': 74541, 'order': 3, 'name': 'Corey Stoll'},
#   {'movie_id': 102899,
#    'actor_id': 21127,
#    'order': 4,
#    'name': 'Bobby Cannavale'}],
#  [{'movie_id': 103243,
#    'actor_id': 1033157,
#    'order': 0,
#    'name': 'Ayushmann Khurrana'},
#   {'movie_id': 103243, 'actor_id': 1115720, 'order': 1, 'name': 'Yami Gautam'},
#   {'movie_id': 103243, 'actor_id': 110199, 'order': 2, 'name': 'Annu Kapoor'},
#   {'movie_id': 103243,
#    'actor_id': 85877,
#    'order': 3,
#    'name': 'Dolly Ahluwalia'},
#   {'movie_id': 103243,
#    'actor_id': 2236119,
#    'order': 4,
#    'name': 'Kamlesh Gill'}],
#  [{'movie_id': 103269,
#    'actor_id': 11680,
#    'order': 0,
#    'name': 'Pauley Perrette'},
#   {'movie_id': 103269,
#    'actor_id': 59222,
#    'order': 1,
#    'name': 'George Newbern'},
#   {'movie_id': 103269,
#    'actor_id': 130081,
#    'order': 2,
#    'name': 'Robin Atkin Downes'},
#   {'movie_id': 103269,
#    'actor_id': 157536,
#    'order': 3,
#    'name': 'David Kaufman'},
#   {'movie_id': 103269,
#    'actor_id': 23680,
#    'order': 4,
#    'name': 'Dee Bradley Baker'}],
#  [{'movie_id': 103328, 'actor_id': 27978, 'order': 0, 'name': 'Denis Lavant'},
#   {'movie_id': 103328, 'actor_id': 8170, 'order': 1, 'name': 'Eva Mendes'},
#   {'movie_id': 103328, 'actor_id': 12207, 'order': 2, 'name': 'Kylie Minogue'},
#   {'movie_id': 103328, 'actor_id': 3784, 'order': 3, 'name': 'Michel Piccoli'},
#   {'movie_id': 103328, 'actor_id': 27980, 'order': 4, 'name': 'Edith Scob'}],
#  [{'movie_id': 103332, 'actor_id': 17142, 'order': 0, 'name': 'Paul Dano'},
#   {'movie_id': 103332, 'actor_id': 35028, 'order': 1, 'name': 'Zoe Kazan'},
#   {'movie_id': 103332, 'actor_id': 61659, 'order': 2, 'name': 'Chris Messina'},
#   {'movie_id': 103332, 'actor_id': 516, 'order': 3, 'name': 'Annette Bening'},
#   {'movie_id': 103332,
#    'actor_id': 3131,
#    'order': 4,
#    'name': 'Antonio Banderas'}],
#  [{'movie_id': 103370, 'actor_id': 80602, 'order': 0, 'name': 'Tyler Perry'},
#   {'movie_id': 103370, 'actor_id': 26510, 'order': 1, 'name': 'Eugene Levy'},
#   {'movie_id': 103370,
#    'actor_id': 9205,
#    'order': 2,
#    'name': 'Denise Richards'},
#   {'movie_id': 103370, 'actor_id': 45863, 'order': 3, 'name': 'Doris Roberts'},
#   {'movie_id': 103370, 'actor_id': 1034513, 'order': 4, 'name': 'Devan Leos'}],
#  [{'movie_id': 103620, 'actor_id': 109, 'order': 0, 'name': 'Elijah Wood'},
#   {'movie_id': 103620, 'actor_id': 78434, 'order': 1, 'name': 'America Olivo'},
#   {'movie_id': 103620,
#    'actor_id': 453272,
#    'order': 2,
#    'name': 'Nora Arnezeder'},
#   {'movie_id': 103620, 'actor_id': 932095, 'order': 3, 'name': 'Zoe Aggeliki'},
#   {'movie_id': 103620, 'actor_id': 430313, 'order': 4, 'name': 'Jan Broberg'}],
#  [{'movie_id': 103663, 'actor_id': 1019, 'order': 0, 'name': 'Mads Mikkelsen'},
#   {'movie_id': 103663,
#    'actor_id': 4457,
#    'order': 1,
#    'name': 'Thomas Bo Larsen'},
#   {'movie_id': 103663,
#    'actor_id': 1112385,
#    'order': 2,
#    'name': 'Annika Wedderkopp'},
#   {'movie_id': 103663,
#    'actor_id': 1188827,
#    'order': 3,
#    'name': 'Lasse Fogelstrøm'},
#   {'movie_id': 103663, 'actor_id': 47156, 'order': 4, 'name': 'Susse Wold'}],
#  [{'movie_id': 103686,
#    'actor_id': 238260,
#    'order': 0,
#    'name': 'Margarethe Tiesel'},
#   {'movie_id': 103686,
#    'actor_id': 1034596,
#    'order': 1,
#    'name': 'Peter Kazungu'},
#   {'movie_id': 103686, 'actor_id': 1034595, 'order': 2, 'name': 'Inge Maux'},
#   {'movie_id': 103686,
#    'actor_id': 1169614,
#    'order': 3,
#    'name': 'Dunja Sowinetz'},
#   {'movie_id': 103686,
#    'actor_id': 1169615,
#    'order': 4,
#    'name': 'Helen Brugat'}],
#  [{'movie_id': 103731,
#    'actor_id': 10297,
#    'order': 0,
#    'name': 'Matthew McConaughey'},
#   {'movie_id': 103731,
#    'actor_id': 1034681,
#    'order': 1,
#    'name': 'Tye Sheridan'},
#   {'movie_id': 103731,
#    'actor_id': 1171570,
#    'order': 2,
#    'name': 'Jacob Lofland'},
#   {'movie_id': 103731, 'actor_id': 9880, 'order': 3, 'name': 'Sam Shepard'},
#   {'movie_id': 103731,
#    'actor_id': 368,
#    'order': 4,
#    'name': 'Reese Witherspoon'}],
#  [{'movie_id': 103740,
#    'actor_id': 1034685,
#    'order': 0,
#    'name': 'Cosmina Stratan'},
#   {'movie_id': 103740,
#    'actor_id': 1034686,
#    'order': 1,
#    'name': 'Cristina Flutur'},
#   {'movie_id': 103740,
#    'actor_id': 1034687,
#    'order': 2,
#    'name': 'Valeriu Andriuță'},
#   {'movie_id': 103740,
#    'actor_id': 1034688,
#    'order': 3,
#    'name': 'Dana Tapalagă'},
#   {'movie_id': 103740,
#    'actor_id': 1034689,
#    'order': 4,
#    'name': 'Cătălina Harabagiu'}],
#  [{'movie_id': 103747,
#    'actor_id': 1034704,
#    'order': 0,
#    'name': 'Paul Brannigan'},
#   {'movie_id': 103747,
#    'actor_id': 1034708,
#    'order': 1,
#    'name': 'Siobhan Reilly'},
#   {'movie_id': 103747, 'actor_id': 83816, 'order': 2, 'name': 'John Henshaw'},
#   {'movie_id': 103747,
#    'actor_id': 1077236,
#    'order': 3,
#    'name': 'Gary Maitland'},
#   {'movie_id': 103747,
#    'actor_id': 15501,
#    'order': 4,
#    'name': 'William Ruane'}],
#  [{'movie_id': 104755,
#    'actor_id': 21319,
#    'order': 0,
#    'name': 'Sheri Moon Zombie'},
#   {'movie_id': 104755, 'actor_id': 52374, 'order': 1, 'name': 'Bruce Davison'},
#   {'movie_id': 104755,
#    'actor_id': 59673,
#    'order': 2,
#    'name': 'Jeff Daniel Phillips'},
#   {'movie_id': 104755, 'actor_id': 41234, 'order': 3, 'name': 'Judy Geeson'},
#   {'movie_id': 104755, 'actor_id': 41229, 'order': 4, 'name': 'Meg Foster'}],
#  [{'movie_id': 104859, 'actor_id': 19767, 'order': 0, 'name': 'Snoop Dogg'},
#   {'movie_id': 104859, 'actor_id': 51944, 'order': 1, 'name': 'Mike Epps'},
#   {'movie_id': 104859,
#    'actor_id': 52940,
#    'order': 2,
#    'name': 'Andy Milonakis'},
#   {'movie_id': 104859,
#    'actor_id': 1037299,
#    'order': 4,
#    'name': 'Teairra Mari'},
#   {'movie_id': 104859,
#    'actor_id': 1037300,
#    'order': 5,
#    'name': 'Samantha Cope'}],
#  [{'movie_id': 105864,
#    'actor_id': 963134,
#    'order': 0,
#    'name': 'Raymond Ochoa'},
#   {'movie_id': 105864, 'actor_id': 1476748, 'order': 1, 'name': 'Jack Bright'},
#   {'movie_id': 105864, 'actor_id': 2954, 'order': 2, 'name': 'Jeffrey Wright'},
#   {'movie_id': 105864,
#    'actor_id': 3910,
#    'order': 3,
#    'name': 'Frances McDormand'},
#   {'movie_id': 105864,
#    'actor_id': 1540680,
#    'order': 4,
#    'name': 'Maleah Nipay-Padilla'}],
#  [{'movie_id': 106021,
#    'actor_id': 18182,
#    'order': 0,
#    'name': 'Olga Kurylenko'},
#   {'movie_id': 106021, 'actor_id': 6383, 'order': 1, 'name': 'Aaron Eckhart'},
#   {'movie_id': 106021,
#    'actor_id': 60458,
#    'order': 2,
#    'name': 'Liana Liberato'},
#   {'movie_id': 106021, 'actor_id': 1039359, 'order': 3, 'name': 'Kate Linder'},
#   {'movie_id': 106021, 'actor_id': 105496, 'order': 4, 'name': 'Neil Napier'}],
#  [{'movie_id': 106646,
#    'actor_id': 6193,
#    'order': 0,
#    'name': 'Leonardo DiCaprio'},
#   {'movie_id': 106646, 'actor_id': 21007, 'order': 1, 'name': 'Jonah Hill'},
#   {'movie_id': 106646,
#    'actor_id': 234352,
#    'order': 2,
#    'name': 'Margot Robbie'},
#   {'movie_id': 106646, 'actor_id': 3497, 'order': 3, 'name': 'Kyle Chandler'},
#   {'movie_id': 106646, 'actor_id': 3026, 'order': 4, 'name': 'Rob Reiner'}],
#  [{'movie_id': 106747, 'actor_id': 11160, 'order': 0, 'name': 'Danny Trejo'},
#   {'movie_id': 106747, 'actor_id': 2461, 'order': 1, 'name': 'Mel Gibson'},
#   {'movie_id': 106747, 'actor_id': 76961, 'order': 2, 'name': 'Demián Bichir'},
#   {'movie_id': 106747, 'actor_id': 55085, 'order': 3, 'name': 'Amber Heard'},
#   {'movie_id': 106747,
#    'actor_id': 17647,
#    'order': 4,
#    'name': 'Michelle Rodriguez'}],
#  [{'movie_id': 107257,
#    'actor_id': 104646,
#    'order': 0,
#    'name': 'Barbara Niven'},
#   {'movie_id': 107257,
#    'actor_id': 138690,
#    'order': 1,
#    'name': 'Jessica Clark'},
#   {'movie_id': 107257, 'actor_id': 11512, 'order': 2, 'name': 'John Heard'},
#   {'movie_id': 107257,
#    'actor_id': 14990,
#    'order': 3,
#    'name': 'Morgan Fairchild'},
#   {'movie_id': 107257,
#    'actor_id': 88168,
#    'order': 4,
#    'name': 'Rebecca Staab'}],
#  [{'movie_id': 107811, 'actor_id': 996701, 'order': 0, 'name': 'Miles Teller'},
#   {'movie_id': 107811, 'actor_id': 73128, 'order': 1, 'name': 'Skylar Astin'},
#   {'movie_id': 107811, 'actor_id': 65225, 'order': 2, 'name': 'Justin Chon'},
#   {'movie_id': 107811, 'actor_id': 131723, 'order': 3, 'name': 'Sarah Wright'},
#   {'movie_id': 107811,
#    'actor_id': 95137,
#    'order': 4,
#    'name': 'Jonathan Keltz'}],
#  [{'movie_id': 107846,
#    'actor_id': 16483,
#    'order': 0,
#    'name': 'Sylvester Stallone'},
#   {'movie_id': 107846,
#    'actor_id': 1100,
#    'order': 1,
#    'name': 'Arnold Schwarzenegger'},
#   {'movie_id': 107846, 'actor_id': 8767, 'order': 2, 'name': 'Jim Caviezel'},
#   {'movie_id': 107846, 'actor_id': 980, 'order': 3, 'name': 'Vinnie Jones'},
#   {'movie_id': 107846,
#    'actor_id': 7132,
#    'order': 4,
#    'name': "Vincent D'Onofrio"}],
#  [{'movie_id': 107985, 'actor_id': 11108, 'order': 0, 'name': 'Simon Pegg'},
#   {'movie_id': 107985, 'actor_id': 11109, 'order': 1, 'name': 'Nick Frost'},
#   {'movie_id': 107985,
#    'actor_id': 14887,
#    'order': 2,
#    'name': 'Paddy Considine'},
#   {'movie_id': 107985, 'actor_id': 7060, 'order': 3, 'name': 'Martin Freeman'},
#   {'movie_id': 107985, 'actor_id': 1665, 'order': 4, 'name': 'Eddie Marsan'}],
#  [{'movie_id': 109091,
#    'actor_id': 17288,
#    'order': 0,
#    'name': 'Michael Fassbender'},
#   {'movie_id': 109091, 'actor_id': 6941, 'order': 1, 'name': 'Cameron Diaz'},
#   {'movie_id': 109091, 'actor_id': 3810, 'order': 2, 'name': 'Javier Bardem'},
#   {'movie_id': 109091, 'actor_id': 955, 'order': 3, 'name': 'Penélope Cruz'},
#   {'movie_id': 109091, 'actor_id': 287, 'order': 4, 'name': 'Brad Pitt'}],
#  [{'movie_id': 109099,
#    'actor_id': 53714,
#    'order': 0,
#    'name': 'Rachel McAdams'},
#   {'movie_id': 109099, 'actor_id': 87722, 'order': 1, 'name': 'Noomi Rapace'},
#   {'movie_id': 109099,
#    'actor_id': 17067,
#    'order': 2,
#    'name': 'Karoline Herfurth'},
#   {'movie_id': 109099,
#    'actor_id': 220448,
#    'order': 3,
#    'name': 'Paul Anderson'},
#   {'movie_id': 109099, 'actor_id': 65054, 'order': 4, 'name': 'Rainer Bock'}],
#  [{'movie_id': 109410,
#    'actor_id': 172069,
#    'order': 0,
#    'name': 'Chadwick Boseman'},
#   {'movie_id': 109410, 'actor_id': 164205, 'order': 1, 'name': 'T.R. Knight'},
#   {'movie_id': 109410, 'actor_id': 3, 'order': 2, 'name': 'Harrison Ford'},
#   {'movie_id': 109410,
#    'actor_id': 87243,
#    'order': 3,
#    'name': 'Nicole Beharie'},
#   {'movie_id': 109410,
#    'actor_id': 22227,
#    'order': 4,
#    'name': 'Christopher Meloni'}],
#  [{'movie_id': 109414, 'actor_id': 17051, 'order': 0, 'name': 'James Franco'},
#   {'movie_id': 109414, 'actor_id': 21007, 'order': 1, 'name': 'Jonah Hill'},
#   {'movie_id': 109414, 'actor_id': 19274, 'order': 2, 'name': 'Seth Rogen'},
#   {'movie_id': 109414, 'actor_id': 449, 'order': 3, 'name': 'Jay Baruchel'},
#   {'movie_id': 109414,
#    'actor_id': 62862,
#    'order': 4,
#    'name': 'Danny McBride'}],
#  [{'movie_id': 109418, 'actor_id': 19292, 'order': 0, 'name': 'Adam Sandler'},
#   {'movie_id': 109418, 'actor_id': 32895, 'order': 1, 'name': 'Kevin James'},
#   {'movie_id': 109418, 'actor_id': 2632, 'order': 2, 'name': 'Chris Rock'},
#   {'movie_id': 109418, 'actor_id': 60950, 'order': 3, 'name': 'David Spade'},
#   {'movie_id': 109418, 'actor_id': 3136, 'order': 4, 'name': 'Salma Hayek'}],
#  [{'movie_id': 109421, 'actor_id': 9642, 'order': 0, 'name': 'Jude Law'},
#   {'movie_id': 109421, 'actor_id': 108916, 'order': 1, 'name': 'Rooney Mara'},
#   {'movie_id': 109421,
#    'actor_id': 1922,
#    'order': 2,
#    'name': 'Catherine Zeta-Jones'},
#   {'movie_id': 109421,
#    'actor_id': 38673,
#    'order': 3,
#    'name': 'Channing Tatum'},
#   {'movie_id': 109421, 'actor_id': 5025, 'order': 4, 'name': 'Vinessa Shaw'}],
#  [{'movie_id': 109424, 'actor_id': 31, 'order': 0, 'name': 'Tom Hanks'},
#   {'movie_id': 109424,
#    'actor_id': 2229,
#    'order': 1,
#    'name': 'Catherine Keener'},
#   {'movie_id': 109424, 'actor_id': 94864, 'order': 2, 'name': 'Max Martini'},
#   {'movie_id': 109424, 'actor_id': 15824, 'order': 3, 'name': 'Chris Mulkey'},
#   {'movie_id': 109424, 'actor_id': 75604, 'order': 4, 'name': 'Yul Vazquez'}],
#  [{'movie_id': 109428, 'actor_id': 530618, 'order': 0, 'name': 'Jane Levy'},
#   {'movie_id': 109428,
#    'actor_id': 79795,
#    'order': 1,
#    'name': 'Shiloh Fernandez'},
#   {'movie_id': 109428,
#    'actor_id': 17441,
#    'order': 2,
#    'name': 'Lou Taylor Pucci'},
#   {'movie_id': 109428, 'actor_id': 51989, 'order': 3, 'name': 'Jessica Lucas'},
#   {'movie_id': 109428,
#    'actor_id': 1046233,
#    'order': 4,
#    'name': 'Elizabeth Blackmore'}],
#  [{'movie_id': 109431, 'actor_id': 23532, 'order': 0, 'name': 'Jason Bateman'},
#   {'movie_id': 109431,
#    'actor_id': 55536,
#    'order': 1,
#    'name': 'Melissa McCarthy'},
#   {'movie_id': 109431, 'actor_id': 15277, 'order': 2, 'name': 'Jon Favreau'},
#   {'movie_id': 109431, 'actor_id': 2956, 'order': 3, 'name': 'Amanda Peet'},
#   {'movie_id': 109431, 'actor_id': 76126, 'order': 4, 'name': 'T.I.'}],
#  [{'movie_id': 109439,
#    'actor_id': 51329,
#    'order': 0,
#    'name': 'Bradley Cooper'},
#   {'movie_id': 109439, 'actor_id': 27105, 'order': 1, 'name': 'Ed Helms'},
#   {'movie_id': 109439,
#    'actor_id': 58225,
#    'order': 2,
#    'name': 'Zach Galifianakis'},
#   {'movie_id': 109439, 'actor_id': 21180, 'order': 3, 'name': 'Justin Bartha'},
#   {'movie_id': 109439, 'actor_id': 83586, 'order': 4, 'name': 'Ken Jeong'}],
#  [{'movie_id': 109443, 'actor_id': 23659, 'order': 0, 'name': 'Will Ferrell'},
#   {'movie_id': 109443, 'actor_id': 4495, 'order': 1, 'name': 'Steve Carell'},
#   {'movie_id': 109443, 'actor_id': 22226, 'order': 2, 'name': 'Paul Rudd'},
#   {'movie_id': 109443,
#    'actor_id': 18979,
#    'order': 3,
#    'name': 'Christina Applegate'},
#   {'movie_id': 109443,
#    'actor_id': 28638,
#    'order': 4,
#    'name': 'David Koechner'}],
#  [{'movie_id': 109445, 'actor_id': 40462, 'order': 0, 'name': 'Kristen Bell'},
#   {'movie_id': 109445, 'actor_id': 19394, 'order': 1, 'name': 'Idina Menzel'},
#   {'movie_id': 109445,
#    'actor_id': 221611,
#    'order': 2,
#    'name': 'Jonathan Groff'},
#   {'movie_id': 109445, 'actor_id': 54415, 'order': 3, 'name': 'Josh Gad'},
#   {'movie_id': 109445,
#    'actor_id': 1188241,
#    'order': 4,
#    'name': 'Santino Fontana'}],
#  [{'movie_id': 109451, 'actor_id': 19278, 'order': 0, 'name': 'Bill Hader'},
#   {'movie_id': 109451, 'actor_id': 1772, 'order': 1, 'name': 'Anna Faris'},
#   {'movie_id': 109451, 'actor_id': 3085, 'order': 2, 'name': 'James Caan'},
#   {'movie_id': 109451, 'actor_id': 62831, 'order': 3, 'name': 'Will Forte'},
#   {'movie_id': 109451, 'actor_id': 62861, 'order': 4, 'name': 'Andy Samberg'}],
#  [{'movie_id': 109491,
#    'actor_id': 71375,
#    'order': 0,
#    'name': 'Alden Ehrenreich'},
#   {'movie_id': 109491,
#    'actor_id': 587823,
#    'order': 1,
#    'name': 'Alice Englert'},
#   {'movie_id': 109491, 'actor_id': 16940, 'order': 2, 'name': 'Jeremy Irons'},
#   {'movie_id': 109491, 'actor_id': 19492, 'order': 3, 'name': 'Viola Davis'},
#   {'movie_id': 109491, 'actor_id': 4730, 'order': 4, 'name': 'Emmy Rossum'}],
#  [{'movie_id': 109513, 'actor_id': 40462, 'order': 0, 'name': 'Kristen Bell'},
#   {'movie_id': 109513, 'actor_id': 51298, 'order': 1, 'name': 'Dax Shepard'},
#   {'movie_id': 109513, 'actor_id': 74036, 'order': 2, 'name': 'Tom Arnold'},
#   {'movie_id': 109513,
#    'actor_id': 52775,
#    'order': 3,
#    'name': 'Kristin Chenoweth'},
#   {'movie_id': 109513,
#    'actor_id': 19975,
#    'order': 4,
#    'name': 'Michael Rosenbaum'}],
#  [{'movie_id': 109520, 'actor_id': 231075, 'order': 0, 'name': 'Mary Carey'},
#   {'movie_id': 109520, 'actor_id': 112298, 'order': 1, 'name': 'Amber Lynn'},
#   {'movie_id': 109520, 'actor_id': 132232, 'order': 2, 'name': 'Asia Carrera'},
#   {'movie_id': 109520, 'actor_id': 589456, 'order': 3, 'name': 'Crissy Moran'},
#   {'movie_id': 109520, 'actor_id': 140082, 'order': 4, 'name': 'Raylene'}],
#  [{'movie_id': 109584, 'actor_id': 3129, 'order': 0, 'name': 'Tim Roth'},
#   {'movie_id': 109584,
#    'actor_id': 1046865,
#    'order': 1,
#    'name': 'Eloise Laurence'},
#   {'movie_id': 109584, 'actor_id': 2037, 'order': 2, 'name': 'Cillian Murphy'},
#   {'movie_id': 109584,
#    'actor_id': 588671,
#    'order': 3,
#    'name': 'Zana Marjanović'},
#   {'movie_id': 109584, 'actor_id': 589652, 'order': 4, 'name': 'Robert Emms'}],
#  [{'movie_id': 109689, 'actor_id': 82700, 'order': 0, 'name': 'Mario Casas'},
#   {'movie_id': 109689, 'actor_id': 224731, 'order': 1, 'name': 'Clara Lago'},
#   {'movie_id': 109689,
#    'actor_id': 77122,
#    'order': 2,
#    'name': 'María Valverde'},
#   {'movie_id': 109689,
#    'actor_id': 224874,
#    'order': 3,
#    'name': 'Álvaro Cervantes'},
#   {'movie_id': 109689,
#    'actor_id': 126771,
#    'order': 4,
#    'name': 'Diego Martín'}],
#  [{'movie_id': 109729, 'actor_id': 49265, 'order': 0, 'name': 'Lindsay Lohan'},
#   {'movie_id': 109729, 'actor_id': 124097, 'order': 1, 'name': 'James Deen'},
#   {'movie_id': 109729, 'actor_id': 5216, 'order': 2, 'name': 'Gus Van Sant'},
#   {'movie_id': 109729,
#    'actor_id': 82819,
#    'order': 3,
#    'name': 'Nolan Gerard Funk'},
#   {'movie_id': 109729,
#    'actor_id': 64341,
#    'order': 4,
#    'name': 'Amanda Brooks'}],
#  [{'movie_id': 110160,
#    'actor_id': 26100,
#    'order': 0,
#    'name': 'Melvil Poupaud'},
#   {'movie_id': 110160,
#    'actor_id': 142689,
#    'order': 1,
#    'name': 'Suzanne Clément'},
#   {'movie_id': 110160,
#    'actor_id': 136761,
#    'order': 2,
#    'name': 'Nathalie Baye'},
#   {'movie_id': 110160, 'actor_id': 143595, 'order': 3, 'name': 'Monia Chokri'},
#   {'movie_id': 110160, 'actor_id': 38529, 'order': 4, 'name': 'Yves Jacques'}],
#  [{'movie_id': 110354, 'actor_id': 6384, 'order': 0, 'name': 'Keanu Reeves'},
#   {'movie_id': 110354,
#    'actor_id': 1032,
#    'order': 1,
#    'name': 'Martin Scorsese'},
#   {'movie_id': 110354, 'actor_id': 2710, 'order': 2, 'name': 'James Cameron'},
#   {'movie_id': 110354, 'actor_id': 7467, 'order': 3, 'name': 'David Fincher'},
#   {'movie_id': 110354, 'actor_id': 5602, 'order': 4, 'name': 'David Lynch'}],
#  [{'movie_id': 110390,
#    'actor_id': 1310733,
#    'order': 1,
#    'name': 'Holger Andersson'},
#   {'movie_id': 110390,
#    'actor_id': 1310734,
#    'order': 2,
#    'name': 'Nisse Vestblom'},
#   {'movie_id': 110390,
#    'actor_id': 1424918,
#    'order': 3,
#    'name': 'Viktor Gyllenberg'},
#   {'movie_id': 110390,
#    'actor_id': 1105513,
#    'order': 4,
#    'name': 'Lotti Törnros'},
#   {'movie_id': 110390,
#    'actor_id': 1424919,
#    'order': 5,
#    'name': 'Jonas Gerholm'}],
#  [{'movie_id': 110398,
#    'actor_id': 258,
#    'order': 0,
#    'name': 'Gael García Bernal'},
#   {'movie_id': 110398,
#    'actor_id': 225011,
#    'order': 1,
#    'name': 'Alfredo Castro'},
#   {'movie_id': 110398,
#    'actor_id': 66901,
#    'order': 2,
#    'name': 'Néstor Cantillana'},
#   {'movie_id': 110398, 'actor_id': 127248, 'order': 3, 'name': 'Luis Gnecco'},
#   {'movie_id': 110398,
#    'actor_id': 141624,
#    'order': 4,
#    'name': 'Antonia Zegers'}],
#  [{'movie_id': 110402,
#    'actor_id': 99269,
#    'order': 0,
#    'name': 'Leonid Yarmolnik'},
#   {'movie_id': 110402,
#    'actor_id': 143667,
#    'order': 1,
#    'name': 'Yuriy Tsurilo'},
#   {'movie_id': 110402,
#    'actor_id': 1272797,
#    'order': 2,
#    'name': 'Natalya Moteva'},
#   {'movie_id': 110402,
#    'actor_id': 1337024,
#    'order': 3,
#    'name': 'Aleksandr Chutko'},
#   {'movie_id': 110402,
#    'actor_id': 579743,
#    'order': 4,
#    'name': 'Aleksandr Ilin'}],
#  [{'movie_id': 110415, 'actor_id': 16828, 'order': 0, 'name': 'Chris Evans'},
#   {'movie_id': 110415, 'actor_id': 20738, 'order': 1, 'name': 'Song Kang-ho'},
#   {'movie_id': 110415, 'actor_id': 228, 'order': 2, 'name': 'Ed Harris'},
#   {'movie_id': 110415, 'actor_id': 5049, 'order': 3, 'name': 'John Hurt'},
#   {'movie_id': 110415, 'actor_id': 3063, 'order': 4, 'name': 'Tilda Swinton'}],
#  [{'movie_id': 110416,
#    'actor_id': 2039,
#    'order': 0,
#    'name': 'Brendan Gleeson'},
#   {'movie_id': 110416,
#    'actor_id': 58068,
#    'order': 1,
#    'name': 'Fionnula Flanagan'},
#   {'movie_id': 110416, 'actor_id': 1326568, 'order': 2, 'name': 'David Rawle'},
#   {'movie_id': 110416, 'actor_id': 83278, 'order': 3, 'name': 'Pat Shortt'},
#   {'movie_id': 110416, 'actor_id': 37169, 'order': 4, 'name': 'Jon Kenny'}],
#  [{'movie_id': 110420, 'actor_id': 104522, 'order': 0, 'name': 'Aoi Miyazaki'},
#   {'movie_id': 110420, 'actor_id': 45999, 'order': 1, 'name': 'Takao Osawa'},
#   {'movie_id': 110420, 'actor_id': 1054260, 'order': 2, 'name': 'Haru Kuroki'},
#   {'movie_id': 110420,
#    'actor_id': 559411,
#    'order': 3,
#    'name': 'Yukito Nishii'},
#   {'movie_id': 110420, 'actor_id': 225662, 'order': 4, 'name': 'Momoka Ohno'}],
#  [{'movie_id': 110552, 'actor_id': 57207, 'order': 0, 'name': 'Tony Jaa'},
#   {'movie_id': 110552,
#    'actor_id': 57208,
#    'order': 1,
#    'name': 'Petchtai Wongkamlao'},
#   {'movie_id': 110552,
#    'actor_id': 1267619,
#    'order': 2,
#    'name': 'Marrese Crump'},
#   {'movie_id': 110552, 'actor_id': 135347, 'order': 3, 'name': 'JeeJa Yanin'},
#   {'movie_id': 110552, 'actor_id': 150, 'order': 4, 'name': 'RZA'}],
#  [{'movie_id': 111083,
#    'actor_id': 110129,
#    'order': 0,
#    'name': 'José Coronado'},
#   {'movie_id': 111083, 'actor_id': 112901, 'order': 1, 'name': 'Hugo Silva'},
#   {'movie_id': 111083, 'actor_id': 19907, 'order': 2, 'name': 'Belén Rueda'},
#   {'movie_id': 111083, 'actor_id': 566544, 'order': 3, 'name': 'Aura Garrido'},
#   {'movie_id': 111083,
#    'actor_id': 1276266,
#    'order': 4,
#    'name': 'Miquel Gelabert'}],
#  [{'movie_id': 111190, 'actor_id': 3489, 'order': 0, 'name': 'Naomi Watts'},
#   {'movie_id': 111190, 'actor_id': 32, 'order': 1, 'name': 'Robin Wright'},
#   {'movie_id': 111190,
#    'actor_id': 109438,
#    'order': 2,
#    'name': 'Xavier Samuel'},
#   {'movie_id': 111190,
#    'actor_id': 968863,
#    'order': 3,
#    'name': 'James Frecheville'},
#   {'movie_id': 111190,
#    'actor_id': 77335,
#    'order': 4,
#    'name': 'Ben Mendelsohn'}],
#  [{'movie_id': 111440, 'actor_id': 1046143, 'order': 0, 'name': 'Caity Lotz'},
#   {'movie_id': 111440,
#    'actor_id': 27763,
#    'order': 1,
#    'name': 'Casper Van Dien'},
#   {'movie_id': 111440,
#    'actor_id': 51536,
#    'order': 2,
#    'name': 'Agnes Bruckner'},
#   {'movie_id': 111440, 'actor_id': 1052211, 'order': 3, 'name': 'Mark Steger'},
#   {'movie_id': 111440,
#    'actor_id': 159985,
#    'order': 4,
#    'name': 'Haley Hudson'}],
#  [{'movie_id': 111473, 'actor_id': 5469, 'order': 0, 'name': 'Ralph Fiennes'},
#   {'movie_id': 111473,
#    'actor_id': 72855,
#    'order': 1,
#    'name': 'Felicity Jones'},
#   {'movie_id': 111473,
#    'actor_id': 33450,
#    'order': 2,
#    'name': 'Joanna Scanlan'},
#   {'movie_id': 111473,
#    'actor_id': 5470,
#    'order': 3,
#    'name': 'Kristin Scott Thomas'},
#   {'movie_id': 111473, 'actor_id': 2441, 'order': 4, 'name': 'Tom Hollander'}],
#  [{'movie_id': 111839, 'actor_id': 2227, 'order': 0, 'name': 'Nicole Kidman'},
#   {'movie_id': 111839, 'actor_id': 2296, 'order': 1, 'name': 'Clive Owen'},
#   {'movie_id': 111839,
#    'actor_id': 17289,
#    'order': 2,
#    'name': 'Rodrigo Santoro'},
#   {'movie_id': 111839, 'actor_id': 3087, 'order': 3, 'name': 'Robert Duvall'},
#   {'movie_id': 111839, 'actor_id': 935, 'order': 4, 'name': 'Connie Nielsen'}],
#  [{'movie_id': 111969, 'actor_id': 17141, 'order': 0, 'name': 'Greg Kinnear'},
#   {'movie_id': 111969,
#    'actor_id': 6161,
#    'order': 1,
#    'name': 'Jennifer Connelly'},
#   {'movie_id': 111969, 'actor_id': 112561, 'order': 2, 'name': 'Lily Collins'},
#   {'movie_id': 111969, 'actor_id': 232006, 'order': 3, 'name': 'Nat Wolff'},
#   {'movie_id': 111969, 'actor_id': 33235, 'order': 4, 'name': 'Logan Lerman'}],
#  [{'movie_id': 112090, 'actor_id': 6640, 'order': 0, 'name': 'Ed Stoppard'},
#   {'movie_id': 112090,
#    'actor_id': 22290,
#    'order': 1,
#    'name': 'Leelee Sobieski'},
#   {'movie_id': 112090, 'actor_id': 4175, 'order': 2, 'name': 'Jeffrey Tambor'},
#   {'movie_id': 112090, 'actor_id': 2201, 'order': 3, 'name': 'Max von Sydow'},
#   {'movie_id': 112090,
#    'actor_id': 1056174,
#    'order': 4,
#    'name': 'Mariya Ignatova'}],
#  [{'movie_id': 112160,
#    'actor_id': 1114607,
#    'order': 0,
#    'name': 'Mathias Melloul'},
#   {'movie_id': 112160,
#    'actor_id': 1114608,
#    'order': 1,
#    'name': 'Valérie Maës'},
#   {'movie_id': 112160,
#    'actor_id': 1114611,
#    'order': 2,
#    'name': 'Stephan Hersoen'},
#   {'movie_id': 112160,
#    'actor_id': 191503,
#    'order': 3,
#    'name': 'Pierre Perrier'},
#   {'movie_id': 112160, 'actor_id': 1114614, 'order': 4, 'name': 'Yan Brian'}],
#  [{'movie_id': 112198, 'actor_id': 73827, 'order': 0, 'name': 'Patrick Bruel'},
#   {'movie_id': 112198,
#    'actor_id': 136489,
#    'order': 1,
#    'name': 'Valérie Benguigui'},
#   {'movie_id': 112198,
#    'actor_id': 48576,
#    'order': 2,
#    'name': 'Charles Berling'},
#   {'movie_id': 112198,
#    'actor_id': 17896,
#    'order': 3,
#    'name': 'Guillaume de Tonquédec'},
#   {'movie_id': 112198,
#    'actor_id': 64590,
#    'order': 4,
#    'name': 'Judith El Zein'}],
#  [{'movie_id': 112200, 'actor_id': 103, 'order': 0, 'name': 'Mark Ruffalo'},
#   {'movie_id': 112200,
#    'actor_id': 12052,
#    'order': 1,
#    'name': 'Gwyneth Paltrow'},
#   {'movie_id': 112200, 'actor_id': 504, 'order': 2, 'name': 'Tim Robbins'},
#   {'movie_id': 112200, 'actor_id': 54415, 'order': 3, 'name': 'Josh Gad'},
#   {'movie_id': 112200, 'actor_id': 77271, 'order': 4, 'name': 'Pink'}],
#  [{'movie_id': 112205, 'actor_id': 380, 'order': 0, 'name': 'Robert De Niro'},
#   {'movie_id': 112205,
#    'actor_id': 1160,
#    'order': 1,
#    'name': 'Michelle Pfeiffer'},
#   {'movie_id': 112205, 'actor_id': 141687, 'order': 2, 'name': 'Dianna Agron'},
#   {'movie_id': 112205, 'actor_id': 1056523, 'order': 3, 'name': "John D'Leo"},
#   {'movie_id': 112205,
#    'actor_id': 2176,
#    'order': 4,
#    'name': 'Tommy Lee Jones'}],
#  [{'movie_id': 112336,
#    'actor_id': 4173,
#    'order': 0,
#    'name': 'Anthony Hopkins'},
#   {'movie_id': 112336, 'actor_id': 15735, 'order': 1, 'name': 'Helen Mirren'},
#   {'movie_id': 112336,
#    'actor_id': 1245,
#    'order': 2,
#    'name': 'Scarlett Johansson'},
#   {'movie_id': 112336, 'actor_id': 19655, 'order': 3, 'name': "James D'Arcy"},
#   {'movie_id': 112336, 'actor_id': 10860, 'order': 4, 'name': 'Jessica Biel'}],
#  [{'movie_id': 112454, 'actor_id': 53, 'order': 0, 'name': 'Peter Stormare'},
#   {'movie_id': 112454, 'actor_id': 79792, 'order': 1, 'name': 'Laura Allen'},
#   {'movie_id': 112454,
#    'actor_id': 127612,
#    'order': 2,
#    'name': 'Elizabeth Whitmere'},
#   {'movie_id': 112454,
#    'actor_id': 1381786,
#    'order': 3,
#    'name': 'Christian Distefano'},
#   {'movie_id': 112454,
#    'actor_id': 1366350,
#    'order': 4,
#    'name': 'John MacDonald'}],
#  [{'movie_id': 112949,
#    'actor_id': 143240,
#    'order': 0,
#    'name': 'Julianne Hough'},
#   {'movie_id': 112949, 'actor_id': 19536, 'order': 1, 'name': 'Josh Duhamel'},
#   {'movie_id': 112949,
#    'actor_id': 71189,
#    'order': 2,
#    'name': 'Cobie Smulders'},
#   {'movie_id': 112949, 'actor_id': 76941, 'order': 3, 'name': 'David Lyons'},
#   {'movie_id': 112949,
#    'actor_id': 65423,
#    'order': 4,
#    'name': 'Mike Pniewski'}],
#  [{'movie_id': 113082,
#    'actor_id': 1056310,
#    'order': 0,
#    'name': 'Hiroaki Iwanaga'},
#   {'movie_id': 113082,
#    'actor_id': 9705,
#    'order': 1,
#    'name': 'Takahiro Sakurai'},
#   {'movie_id': 113082, 'actor_id': 149894, 'order': 2, 'name': 'Yuuki Kaji'},
#   {'movie_id': 113082,
#    'actor_id': 1284669,
#    'order': 3,
#    'name': 'Takahiro Fujiwara'},
#   {'movie_id': 113082,
#    'actor_id': 1139912,
#    'order': 4,
#    'name': 'Toa Yukinari'}],
#  [{'movie_id': 113148, 'actor_id': 46593, 'order': 0, 'name': 'Emile Hirsch'},
#   {'movie_id': 113148, 'actor_id': 22226, 'order': 1, 'name': 'Paul Rudd'},
#   {'movie_id': 113148,
#    'actor_id': 119776,
#    'order': 2,
#    'name': 'Lance LeGault'},
#   {'movie_id': 113148, 'actor_id': 1173618, 'order': 3, 'name': 'Joyce Payne'},
#   {'movie_id': 113148,
#    'actor_id': 1015925,
#    'order': 4,
#    'name': 'Gina Grande'}],
#  [{'movie_id': 113594,
#    'actor_id': 141775,
#    'order': 0,
#    'name': 'Kaitlyn Maher'},
#   {'movie_id': 113594,
#    'actor_id': 1141501,
#    'order': 1,
#    'name': 'Carter Hastings'},
#   {'movie_id': 113594, 'actor_id': 52327, 'order': 2, 'name': 'Alan Shearman'},
#   {'movie_id': 113594, 'actor_id': 65640, 'order': 3, 'name': 'Khary Payton'},
#   {'movie_id': 113594,
#    'actor_id': 59784,
#    'order': 4,
#    'name': 'Carlos Alazraqui'}],
#  [{'movie_id': 113833, 'actor_id': 103, 'order': 0, 'name': 'Mark Ruffalo'},
#   {'movie_id': 113833, 'actor_id': 5374, 'order': 1, 'name': 'Jim Parsons'},
#   {'movie_id': 113833, 'actor_id': 66743, 'order': 2, 'name': 'Matt Bomer'},
#   {'movie_id': 113833, 'actor_id': 1204, 'order': 3, 'name': 'Julia Roberts'},
#   {'movie_id': 113833,
#    'actor_id': 221611,
#    'order': 5,
#    'name': 'Jonathan Groff'}],
#  [{'movie_id': 113947, 'actor_id': 16861, 'order': 0, 'name': 'John Hawkes'},
#   {'movie_id': 113947, 'actor_id': 9994, 'order': 1, 'name': 'Helen Hunt'},
#   {'movie_id': 113947,
#    'actor_id': 3905,
#    'order': 2,
#    'name': 'William H. Macy'},
#   {'movie_id': 113947,
#    'actor_id': 56455,
#    'order': 3,
#    'name': 'Moon Bloodgood'},
#   {'movie_id': 113947,
#    'actor_id': 1099170,
#    'order': 4,
#    'name': 'Annika Marks'}],
#  [{'movie_id': 114150, 'actor_id': 84223, 'order': 0, 'name': 'Anna Kendrick'},
#   {'movie_id': 114150, 'actor_id': 73128, 'order': 1, 'name': 'Skylar Astin'},
#   {'movie_id': 114150, 'actor_id': 29221, 'order': 2, 'name': 'Brittany Snow'},
#   {'movie_id': 114150, 'actor_id': 221098, 'order': 3, 'name': 'Anna Camp'},
#   {'movie_id': 114150,
#    'actor_id': 221581,
#    'order': 4,
#    'name': 'Rebel Wilson'}],
#  [{'movie_id': 114478,
#    'actor_id': 201838,
#    'order': 0,
#    'name': 'Luci Christian'},
#   {'movie_id': 114478, 'actor_id': 149565, 'order': 1, 'name': 'Justin Doran'},
#   {'movie_id': 114478,
#    'actor_id': 207012,
#    'order': 2,
#    'name': 'David Matranga'},
#   {'movie_id': 114478, 'actor_id': 159277, 'order': 3, 'name': 'David Wald'},
#   {'movie_id': 114478,
#    'actor_id': 1081918,
#    'order': 4,
#    'name': 'Emily Neves'}],
#  [{'movie_id': 114606, 'actor_id': 73525, 'order': 0, 'name': 'Michelle Ryan'},
#   {'movie_id': 114606, 'actor_id': 73462, 'order': 1, 'name': 'Georgia King'},
#   {'movie_id': 114606, 'actor_id': 1116, 'order': 2, 'name': 'Alan Ford'},
#   {'movie_id': 114606,
#    'actor_id': 45051,
#    'order': 3,
#    'name': 'Harry Treadaway'},
#   {'movie_id': 114606,
#    'actor_id': 29859,
#    'order': 4,
#    'name': 'Richard Briers'}],
#  [{'movie_id': 114750,
#    'actor_id': 62561,
#    'order': 0,
#    'name': 'Tessa Thompson'},
#   {'movie_id': 114750,
#    'actor_id': 1214870,
#    'order': 1,
#    'name': 'Tyler James Williams'},
#   {'movie_id': 114750, 'actor_id': 59219, 'order': 2, 'name': 'Kyle Gallner'},
#   {'movie_id': 114750,
#    'actor_id': 970219,
#    'order': 3,
#    'name': 'Teyonah Parris'},
#   {'movie_id': 114750,
# ...
#    'order': 2,
#    'name': 'Jackson Nicoll'},
#   {'movie_id': 273641,
#    'actor_id': 2229,
#    'order': 3,
#    'name': 'Catherine Keener'},
#   {'movie_id': 273641,
#    'actor_id': 95789,
#    'order': 5,
#    'name': 'Georgina Cates'}],
#  [{'movie_id': 273895, 'actor_id': 35013, 'order': 0, 'name': 'David Oyelowo'},
#   {'movie_id': 273895, 'actor_id': 207, 'order': 1, 'name': 'Tom Wilkinson'},
#   {'movie_id': 273895, 'actor_id': 37158, 'order': 2, 'name': 'Carmen Ejogo'},
#   {'movie_id': 273895, 'actor_id': 3129, 'order': 3, 'name': 'Tim Roth'},
#   {'movie_id': 273895,
#    'actor_id': 13309,
#    'order': 4,
#    'name': 'Oprah Winfrey'}],
#  [{'movie_id': 274109, 'actor_id': 82700, 'order': 0, 'name': 'Mario Casas'},
#   {'movie_id': 274109,
#    'actor_id': 130260,
#    'order': 1,
#    'name': 'Adriana Ugarte'},
#   {'movie_id': 274109,
#    'actor_id': 1091128,
#    'order': 2,
#    'name': 'Macarena García'},
#   {'movie_id': 274109,
#    'actor_id': 1110505,
#    'order': 3,
#    'name': 'Alain Hernández'},
#   {'movie_id': 274109,
#    'actor_id': 1457340,
#    'order': 4,
#    'name': 'Berta Vázquez'}],
#  [{'movie_id': 274167, 'actor_id': 23659, 'order': 0, 'name': 'Will Ferrell'},
#   {'movie_id': 274167, 'actor_id': 13240, 'order': 1, 'name': 'Mark Wahlberg'},
#   {'movie_id': 274167,
#    'actor_id': 1817,
#    'order': 2,
#    'name': 'Linda Cardellini'},
#   {'movie_id': 274167,
#    'actor_id': 19159,
#    'order': 3,
#    'name': 'Thomas Haden Church'},
#   {'movie_id': 274167,
#    'actor_id': 1512021,
#    'order': 4,
#    'name': 'Scarlett Estevez'}],
#  [{'movie_id': 274479,
#    'actor_id': 72129,
#    'order': 0,
#    'name': 'Jennifer Lawrence'},
#   {'movie_id': 274479,
#    'actor_id': 51329,
#    'order': 1,
#    'name': 'Bradley Cooper'},
#   {'movie_id': 274479, 'actor_id': 380, 'order': 2, 'name': 'Robert De Niro'},
#   {'movie_id': 274479,
#    'actor_id': 1026947,
#    'order': 3,
#    'name': 'Dascha Polanco'},
#   {'movie_id': 274479,
#    'actor_id': 25616,
#    'order': 4,
#    'name': 'Edgar Ramírez'}],
#  [{'movie_id': 274854, 'actor_id': 12835, 'order': 0, 'name': 'Vin Diesel'},
#   {'movie_id': 274854, 'actor_id': 1223793, 'order': 1, 'name': 'Rose Leslie'},
#   {'movie_id': 274854, 'actor_id': 109, 'order': 2, 'name': 'Elijah Wood'},
#   {'movie_id': 274854,
#    'actor_id': 110902,
#    'order': 3,
#    'name': 'Ólafur Darri Ólafsson'},
#   {'movie_id': 274854, 'actor_id': 7241, 'order': 4, 'name': 'Rena Owen'}],
#  [{'movie_id': 274862, 'actor_id': 54697, 'order': 0, 'name': 'Dave Franco'},
#   {'movie_id': 274862,
#    'actor_id': 15009,
#    'order': 1,
#    'name': 'Justin Theroux'},
#   {'movie_id': 274862, 'actor_id': 61110, 'order': 2, 'name': 'Fred Armisen'},
#   {'movie_id': 274862,
#    'actor_id': 1325731,
#    'order': 3,
#    'name': 'Abbi Jacobson'},
#   {'movie_id': 274862, 'actor_id': 81364, 'order': 4, 'name': 'Olivia Munn'}],
#  [{'movie_id': 274870,
#    'actor_id': 72129,
#    'order': 0,
#    'name': 'Jennifer Lawrence'},
#   {'movie_id': 274870, 'actor_id': 73457, 'order': 1, 'name': 'Chris Pratt'},
#   {'movie_id': 274870, 'actor_id': 3968, 'order': 2, 'name': 'Michael Sheen'},
#   {'movie_id': 274870,
#    'actor_id': 2975,
#    'order': 3,
#    'name': 'Laurence Fishburne'},
#   {'movie_id': 274870, 'actor_id': 1271, 'order': 4, 'name': 'Andy García'}],
#  [{'movie_id': 275601, 'actor_id': 5064, 'order': 0, 'name': 'Meryl Streep'},
#   {'movie_id': 275601, 'actor_id': 8945, 'order': 1, 'name': 'Kevin Kline'},
#   {'movie_id': 275601, 'actor_id': 47281, 'order': 2, 'name': 'Mamie Gummer'},
#   {'movie_id': 275601,
#    'actor_id': 60898,
#    'order': 3,
#    'name': 'Sebastian Stan'},
#   {'movie_id': 275601,
#    'actor_id': 187565,
#    'order': 4,
#    'name': 'Audra McDonald'}],
#  [{'movie_id': 276401, 'actor_id': 5530, 'order': 0, 'name': 'James McAvoy'},
#   {'movie_id': 276401,
#    'actor_id': 83002,
#    'order': 1,
#    'name': 'Jessica Chastain'},
#   {'movie_id': 276401, 'actor_id': 19278, 'order': 2, 'name': 'Bill Hader'},
#   {'movie_id': 276401, 'actor_id': 8785, 'order': 3, 'name': 'Ciarán Hinds'},
#   {'movie_id': 276401,
#    'actor_id': 971329,
#    'order': 4,
#    'name': 'Nina Arianda'}],
#  [{'movie_id': 276488,
#    'actor_id': 15498,
#    'order': 1,
#    'name': 'Liam Cunningham'},
#   {'movie_id': 276488,
#    'actor_id': 122648,
#    'order': 2,
#    'name': 'Niall Greig Fulton'},
#   {'movie_id': 276488,
#    'actor_id': 92730,
#    'order': 4,
#    'name': 'Pollyanna McIntosh'},
#   {'movie_id': 276488,
#    'actor_id': 119095,
#    'order': 5,
#    'name': 'Douglas Russell'},
#   {'movie_id': 276488,
#    'actor_id': 567086,
#    'order': 7,
#    'name': 'Bryan Larkin'}],
#  [{'movie_id': 276839,
#    'actor_id': 25541,
#    'order': 0,
#    'name': 'Katherine Heigl'},
#   {'movie_id': 276839,
#    'actor_id': 17178,
#    'order': 1,
#    'name': 'Patrick Wilson'},
#   {'movie_id': 276839,
#    'actor_id': 22123,
#    'order': 2,
#    'name': 'Jordana Brewster'},
#   {'movie_id': 276839, 'actor_id': 9013, 'order': 4, 'name': 'Kevin McKidd'},
#   {'movie_id': 276839,
#    'actor_id': 65769,
#    'order': 5,
#    'name': 'Bryce Johnson'}],
#  [{'movie_id': 276843, 'actor_id': 20049, 'order': 0, 'name': 'David Tennant'},
#   {'movie_id': 276843, 'actor_id': 10882, 'order': 1, 'name': 'Rosamund Pike'},
#   {'movie_id': 276843, 'actor_id': 9188, 'order': 2, 'name': 'Billy Connolly'},
#   {'movie_id': 276843, 'actor_id': 18025, 'order': 3, 'name': 'Ben Miller'},
#   {'movie_id': 276843,
#    'actor_id': 93713,
#    'order': 4,
#    'name': 'Amelia Bullmore'}],
#  [{'movie_id': 276844, 'actor_id': 189230, 'order': 1, 'name': 'Josh Lawson'},
#   {'movie_id': 276844,
#    'actor_id': 81682,
#    'order': 2,
#    'name': 'Bojana Novaković'},
#   {'movie_id': 276844,
#    'actor_id': 62752,
#    'order': 3,
#    'name': 'Damon Herriman'},
#   {'movie_id': 276844, 'actor_id': 123884, 'order': 4, 'name': 'Kate Mulvany'},
#   {'movie_id': 276844, 'actor_id': 61633, 'order': 5, 'name': 'Lisa McCune'}],
#  [{'movie_id': 276902,
#    'actor_id': 96066,
#    'order': 0,
#    'name': 'Liam Hemsworth'},
#   {'movie_id': 276902, 'actor_id': 20374, 'order': 1, 'name': 'Teresa Palmer'},
#   {'movie_id': 276902, 'actor_id': 6949, 'order': 2, 'name': 'John Malkovich'},
#   {'movie_id': 276902, 'actor_id': 6905, 'order': 3, 'name': 'Bruce Dern'},
#   {'movie_id': 276902,
#    'actor_id': 879,
#    'order': 4,
#    'name': 'Billy Bob Thornton'}],
#  [{'movie_id': 276905, 'actor_id': 60949, 'order': 1, 'name': 'Rob Schneider'},
#   {'movie_id': 276905, 'actor_id': 83586, 'order': 2, 'name': 'Ken Jeong'},
#   {'movie_id': 276905,
#    'actor_id': 18284,
#    'order': 3,
#    'name': 'Loretta Devine'},
#   {'movie_id': 276905,
#    'actor_id': 69122,
#    'order': 4,
#    'name': 'Heather Graham'},
#   {'movie_id': 276905, 'actor_id': 2440, 'order': 5, 'name': 'Bill Nighy'}],
#  [{'movie_id': 276907, 'actor_id': 2524, 'order': 0, 'name': 'Tom Hardy'},
#   {'movie_id': 276907,
#    'actor_id': 70456,
#    'order': 1,
#    'name': 'Emily Browning'},
#   {'movie_id': 276907,
#    'actor_id': 2040,
#    'order': 2,
#    'name': 'Christopher Eccleston'},
#   {'movie_id': 276907, 'actor_id': 11207, 'order': 3, 'name': 'David Thewlis'},
#   {'movie_id': 276907,
#    'actor_id': 1303037,
#    'order': 4,
#    'name': 'Taron Egerton'}],
#  [{'movie_id': 276908, 'actor_id': 15033, 'order': 0, 'name': 'Justin Long'},
#   {'movie_id': 276908, 'actor_id': 4730, 'order': 1, 'name': 'Emmy Rossum'},
#   {'movie_id': 276908, 'actor_id': 1395049, 'order': 2, 'name': 'Kayla Servi'},
#   {'movie_id': 276908, 'actor_id': 74409, 'order': 3, 'name': 'Eric Winter'},
#   {'movie_id': 276908, 'actor_id': 1395059, 'order': 4, 'name': 'Ben Scott'}],
#  [{'movie_id': 276909, 'actor_id': 2710, 'order': 0, 'name': 'James Cameron'},
#   {'movie_id': 276909, 'actor_id': 2179, 'order': 1, 'name': 'Suzy Amis'},
#   {'movie_id': 276909,
#    'actor_id': 1002001,
#    'order': 2,
#    'name': 'Frank Lotito'},
#   {'movie_id': 276909,
#    'actor_id': 1351681,
#    'order': 3,
#    'name': 'Lachlan Woods'},
#   {'movie_id': 276909, 'actor_id': 1351682, 'order': 4, 'name': 'Paul Henri'}],
#  [{'movie_id': 277154, 'actor_id': 43643, 'order': 0, 'name': 'Frank Lammers'},
#   {'movie_id': 277154,
#    'actor_id': 1390085,
#    'order': 1,
#    'name': 'Sanne Langelaar'},
#   {'movie_id': 277154, 'actor_id': 585, 'order': 2, 'name': 'Rutger Hauer'},
#   {'movie_id': 277154,
#    'actor_id': 73507,
#    'order': 3,
#    'name': 'Aurélie Meriel'},
#   {'movie_id': 277154, 'actor_id': 4391, 'order': 4, 'name': 'Charles Dance'}],
#  [{'movie_id': 277216,
#    'actor_id': 1371398,
#    'order': 0,
#    'name': "O'Shea Jackson Jr."},
#   {'movie_id': 277216,
#    'actor_id': 1154054,
#    'order': 1,
#    'name': 'Corey Hawkins'},
#   {'movie_id': 277216,
#    'actor_id': 1115984,
#    'order': 2,
#    'name': 'Jason Mitchell'},
#   {'movie_id': 277216,
#    'actor_id': 55091,
#    'order': 3,
#    'name': 'Neil Brown Jr.'},
#   {'movie_id': 277216, 'actor_id': 83860, 'order': 4, 'name': 'Aldis Hodge'}],
#  [{'movie_id': 277217,
#    'actor_id': 1098962,
#    'order': 0,
#    'name': 'Dove Cameron'},
#   {'movie_id': 277217, 'actor_id': 75041, 'order': 1, 'name': 'Cameron Boyce'},
#   {'movie_id': 277217,
#    'actor_id': 121868,
#    'order': 2,
#    'name': 'Booboo Stewart'},
#   {'movie_id': 277217,
#    'actor_id': 1331457,
#    'order': 3,
#    'name': 'Sofia Carson'},
#   {'movie_id': 277217,
#    'actor_id': 1421393,
#    'order': 4,
#    'name': 'Mitchell Hope'}],
#  [{'movie_id': 277355, 'actor_id': 3136, 'order': 1, 'name': 'Salma Hayek'},
#   {'movie_id': 277355,
#    'actor_id': 554073,
#    'order': 2,
#    'name': 'Hiroyuki Watanabe'},
#   {'movie_id': 277355,
#    'actor_id': 130024,
#    'order': 3,
#    'name': 'Jennifer Blanc'},
#   {'movie_id': 277355, 'actor_id': 9192, 'order': 4, 'name': 'Togo Igawa'},
#   {'movie_id': 277355,
#    'actor_id': 25448,
#    'order': 5,
#    'name': 'Caroline Chikezie'}],
#  [{'movie_id': 277432,
#    'actor_id': 35742,
#    'order': 1,
#    'name': 'Shah Rukh Khan'},
#   {'movie_id': 277432,
#    'actor_id': 53975,
#    'order': 2,
#    'name': 'Deepika Padukone'},
#   {'movie_id': 277432,
#    'actor_id': 35793,
#    'order': 3,
#    'name': 'Abhishek Bachchan'},
#   {'movie_id': 277432, 'actor_id': 86014, 'order': 4, 'name': 'Jackie Shroff'},
#   {'movie_id': 277432, 'actor_id': 35779, 'order': 5, 'name': 'Boman Irani'}],
#  [{'movie_id': 277547, 'actor_id': 16828, 'order': 0, 'name': 'Chris Evans'},
#   {'movie_id': 277547,
#    'actor_id': 11705,
#    'order': 1,
#    'name': 'Michelle Monaghan'},
#   {'movie_id': 277547, 'actor_id': 17052, 'order': 2, 'name': 'Topher Grace'},
#   {'movie_id': 277547, 'actor_id': 119592, 'order': 3, 'name': 'Aubrey Plaza'},
#   {'movie_id': 277547, 'actor_id': 36422, 'order': 4, 'name': 'Luke Wilson'}],
#  [{'movie_id': 277685,
#    'actor_id': 444211,
#    'order': 0,
#    'name': 'Shelley Hennig'},
#   {'movie_id': 277685, 'actor_id': 1385058, 'order': 1, 'name': 'Moses Storm'},
#   {'movie_id': 277685,
#    'actor_id': 155621,
#    'order': 2,
#    'name': 'Renee Olstead'},
#   {'movie_id': 277685,
#    'actor_id': 1011103,
#    'order': 3,
#    'name': 'William Peltz'},
#   {'movie_id': 277685,
#    'actor_id': 145131,
#    'order': 4,
#    'name': 'Jacob Wysocki'}],
#  [{'movie_id': 277710, 'actor_id': 8975, 'order': 0, 'name': 'Sam Waterston'},
#   {'movie_id': 277710,
#    'actor_id': 1462,
#    'order': 1,
#    'name': 'Tim Blake Nelson'},
#   {'movie_id': 277710,
#    'actor_id': 37917,
#    'order': 2,
#    'name': 'Kristen Stewart'},
#   {'movie_id': 277710, 'actor_id': 515, 'order': 3, 'name': 'Glenn Close'},
#   {'movie_id': 277710, 'actor_id': 74541, 'order': 4, 'name': 'Corey Stoll'}],
#  [{'movie_id': 278154, 'actor_id': 15757, 'order': 0, 'name': 'Ray Romano'},
#   {'movie_id': 278154, 'actor_id': 5723, 'order': 1, 'name': 'John Leguizamo'},
#   {'movie_id': 278154, 'actor_id': 5724, 'order': 2, 'name': 'Denis Leary'},
#   {'movie_id': 278154, 'actor_id': 15758, 'order': 3, 'name': 'Queen Latifah'},
#   {'movie_id': 278154,
#    'actor_id': 57599,
#    'order': 4,
#    'name': 'Seann William Scott'}],
#  [{'movie_id': 278427,
#    'actor_id': 52139,
#    'order': 0,
#    'name': 'Seth MacFarlane'},
#   {'movie_id': 278427, 'actor_id': 24357, 'order': 1, 'name': 'Alex Borstein'},
#   {'movie_id': 278427, 'actor_id': 13922, 'order': 2, 'name': 'Seth Green'},
#   {'movie_id': 278427, 'actor_id': 18973, 'order': 3, 'name': 'Mila Kunis'},
#   {'movie_id': 278427, 'actor_id': 4, 'order': 4, 'name': 'Carrie Fisher'}],
#  [{'movie_id': 278774, 'actor_id': 505710, 'order': 0, 'name': 'Zendaya'},
#   {'movie_id': 278774,
#    'actor_id': 1255071,
#    'order': 1,
#    'name': 'Chanelle Peloso'},
#   {'movie_id': 278774,
#    'actor_id': 984680,
#    'order': 2,
#    'name': 'Spencer Boldman'},
#   {'movie_id': 278774,
#    'actor_id': 1361975,
#    'order': 3,
#    'name': 'Emilia McCarthy'},
#   {'movie_id': 278774,
#    'actor_id': 936932,
#    'order': 4,
#    'name': 'Adam DiMarco'}],
#  [{'movie_id': 278924, 'actor_id': 976, 'order': 0, 'name': 'Jason Statham'},
#   {'movie_id': 278924, 'actor_id': 56731, 'order': 1, 'name': 'Jessica Alba'},
#   {'movie_id': 278924,
#    'actor_id': 2176,
#    'order': 2,
#    'name': 'Tommy Lee Jones'},
#   {'movie_id': 278924, 'actor_id': 1620, 'order': 3, 'name': 'Michelle Yeoh'},
#   {'movie_id': 278924,
#    'actor_id': 1317159,
#    'order': 4,
#    'name': 'Natalie Burn'}],
#  [{'movie_id': 278927, 'actor_id': 1414734, 'order': 0, 'name': 'Neel Sethi'},
#   {'movie_id': 278927, 'actor_id': 1532, 'order': 1, 'name': 'Bill Murray'},
#   {'movie_id': 278927, 'actor_id': 2282, 'order': 2, 'name': 'Ben Kingsley'},
#   {'movie_id': 278927, 'actor_id': 17605, 'order': 3, 'name': 'Idris Elba'},
#   {'movie_id': 278927,
#    'actor_id': 1245,
#    'order': 4,
#    'name': 'Scarlett Johansson'}],
#  [{'movie_id': 279229, 'actor_id': 70459, 'order': 0, 'name': 'Maria Ehrich'},
#   {'movie_id': 279229,
#    'actor_id': 54676,
#    'order': 1,
#    'name': 'Jannis Niewöhner'},
#   {'movie_id': 279229,
#    'actor_id': 25401,
#    'order': 2,
#    'name': 'Josefine Preuß'},
#   {'movie_id': 279229,
#    'actor_id': 231835,
#    'order': 3,
#    'name': 'Florian Bartholomäi'},
#   {'movie_id': 279229,
#    'actor_id': 49795,
#    'order': 4,
#    'name': 'Peter Simonischek'}],
#  [{'movie_id': 279641, 'actor_id': 56323, 'order': 0, 'name': 'Tina Fey'},
#   {'movie_id': 279641,
#    'actor_id': 234352,
#    'order': 1,
#    'name': 'Margot Robbie'},
#   {'movie_id': 279641,
#    'actor_id': 879,
#    'order': 2,
#    'name': 'Billy Bob Thornton'},
#   {'movie_id': 279641, 'actor_id': 7060, 'order': 3, 'name': 'Martin Freeman'},
#   {'movie_id': 279641, 'actor_id': 2694, 'order': 4, 'name': 'Josh Charles'}],
#  [{'movie_id': 279690, 'actor_id': 9290, 'order': 0, 'name': 'Henry Rollins'},
#   {'movie_id': 279690,
#    'actor_id': 121868,
#    'order': 1,
#    'name': 'Booboo Stewart'},
#   {'movie_id': 279690,
#    'actor_id': 11884,
#    'order': 2,
#    'name': 'Kate Greenhouse'},
#   {'movie_id': 279690,
#    'actor_id': 1228361,
#    'order': 3,
#    'name': 'Jordan Todosey'},
#   {'movie_id': 279690,
#    'actor_id': 46906,
#    'order': 4,
#    'name': 'David Richmond-Peck'}],
#  [{'movie_id': 280092,
#    'actor_id': 106490,
#    'order': 0,
#    'name': 'Stefanie Scott'},
#   {'movie_id': 280092, 'actor_id': 7401, 'order': 1, 'name': 'Lin Shaye'},
#   {'movie_id': 280092,
#    'actor_id': 20212,
#    'order': 2,
#    'name': 'Dermot Mulroney'},
#   {'movie_id': 280092, 'actor_id': 2128, 'order': 3, 'name': 'Leigh Whannell'},
#   {'movie_id': 280092,
#    'actor_id': 59117,
#    'order': 4,
#    'name': 'Angus Sampson'}],
#  [{'movie_id': 280795, 'actor_id': 78245, 'order': 1, 'name': 'Shahid Kapoor'},
#   {'movie_id': 280795, 'actor_id': 55062, 'order': 2, 'name': 'Tabu'},
#   {'movie_id': 280795,
#    'actor_id': 130991,
#    'order': 3,
#    'name': 'Shraddha Kapoor'},
#   {'movie_id': 280795, 'actor_id': 86020, 'order': 4, 'name': 'Kay Kay Menon'},
#   {'movie_id': 280795, 'actor_id': 76793, 'order': 5, 'name': 'Irrfan Khan'}],
#  [{'movie_id': 280960,
#    'actor_id': 1033632,
#    'order': 0,
#    'name': 'Victória Guerra'},
#   {'movie_id': 280960,
#    'actor_id': 1339554,
#    'order': 1,
#    'name': 'Arminda Badaló'},
#   {'movie_id': 280960,
#    'actor_id': 1339555,
#    'order': 2,
#    'name': 'Rui Porto Nunes'},
#   {'movie_id': 280960,
#    'actor_id': 1051816,
#    'order': 3,
#    'name': 'Cândido Ferreira'},
#   {'movie_id': 280960,
#    'actor_id': 1159858,
#    'order': 4,
#    'name': 'Philippe Leroux'}],
#  ...]

# %%
def get_actors_api_call(movie):
    api_url = 'https://api.themoviedb.org/3/movie/'
    api_call = api_url + str(movie) + '/credits' + config.api_key
    response = requests.get(api_call)
    if response.status_code == 200:
        result = response.json()
        actor_results = []
        for person in result['cast'][:5]:
            actor_dict = {}
            actor_dict['movie_id']  = movie
            actor_dict['actor_id'] = person['id']
            actor_dict['order'] = person['order']
            actor_dict['name'] =  person['name']
            actor_results.append(actor_dict)

# %%
get_actors_api_call(189)
# Out:
# [{'movie_id': 189, 'actor_id': 2295, 'order': 0, 'name': 'Mickey Rourke'},
#  {'movie_id': 189, 'actor_id': 56731, 'order': 1, 'name': 'Jessica Alba'},
#  {'movie_id': 189, 'actor_id': 16851, 'order': 2, 'name': 'Josh Brolin'},
#  {'movie_id': 189,
#   'actor_id': 24045,
#   'order': 3,
#   'name': 'Joseph Gordon-Levitt'},
#  {'movie_id': 189, 'actor_id': 5916, 'order': 4, 'name': 'Rosario Dawson'}]

# %%
def get_movie_list():
    import pandas as pd
    import mysql.connector
    import config
    cnx = mysql.connector.connect(
    host = config.host,
    user = config.user,
    password = config.password,
    database = config.database)
    c = cnx.cursor()
#     q = """SELECT id FROM details;"""
    
    q =  """SELECT movies.details.id FROM movies.movie_actors
RIGHT JOIN movies.details
ON movies.details.id = movies.movie_actors.id
WHERE ISNULL(actor);"""
    c.execute(q)
    movie_ids = c.fetchall()
    return movie_ids

# %%
def actor_movie_formatting(actor_dict):
    formatted_actor_movies = []
    for actor_movie in actor_dict:
        actor_movie_tuple = (actor_movie['movie_id'], actor_movie['name'])
        formatted_actor_movies.append(actor_movie_tuple)
    return formatted_actor_movies

# %%
def add_to_db_actor_movie(actor_movie_list):
    cnx = mysql.connector.connect(
    host = config.host,
    user = config.user,
    password = config.password,
    database = config.database)
    c = cnx.cursor()    
    stmt = """INSERT INTO movie_actors (id, actor) VALUES (%s, %s)"""
    c.executemany(stmt, actor_movie_list)
    cnx.commit()
    c.close()
    cnx.close()

# %%
# Original Code to pull movie details
api_url = 'https://api.themoviedb.org/3/movie/'
movie_details = []
for movie in movie_ids[:2]:
    api_call = api_url + str(movie) + config.api_key
    print(api_call)
    response = requests.get(api_call)
    result = response.json()
    movie_details.append(result)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-43-abebc6da04fd> in <module>
#       2 api_url = 'https://api.themoviedb.org/3/movie/'
#       3 movie_details = []
# ----> 4 for movie in movie_ids[:2]:
#       5     api_call = api_url + str(movie) + config.api_key
#       6     print(api_call)
#
# NameError: name 'movie_ids' is not defined

# %%
movies_missing_details = []
movie_details = []
movie_genres = []

for movie in movie_ids:
    movie_dict = {}
    genres_dict = {}
    
    api_call = api_url + str(movie) + config.api_key
    response = requests.get(api_call)
    if response.status_code != 200:
        movies_missing_details.append(movie)
    else:
        result = response.json()
        movie_dict['id'] = result['id']
        movie_dict['imdb_id'] = result['imdb_id']
        movie_dict['name'] = result['title']
#         print(result['title'])
        movie_dict['budget'] = result['budget']
        movie_dict['revenue'] = result['revenue']
        movie_dict['popularity'] = result['popularity']
        movie_dict['release_date'] = result['release_date']
        movie_dict['vote_average'] = result['vote_average']
        movie_dict['vote_count'] = result['vote_count']
        movie_dict['runtime'] = result['runtime']
        for country in result['production_countries']:
#             print(country)
            if country['name'] == 'United States of America':
#                 print(country['name'])
                movie_dict['production_country'] = 'US'
        if 'production_country' not in movie_dict:
            movie_dict['production_country'] = 'non-US'
        movie_dict['language'] = result['original_language']
        
        genres_list = []
        for genre in result['genres']:
            genres_list.append(genre['name'])
        genres_dict[movie] = genres_list
        movie_genres.append(genres_dict)
        movie_details.append(movie_dict)

# %%
import pandas as pd
import mysql.connector
import config
cnx = mysql.connector.connect(
    host = config.host,
    user = config.user,
    password = config.password,
    database = config.database)
c = cnx.cursor()

# %%
q = """CREATE TABLE details (
       id int(6) PRIMARY KEY,
       imdb_id TEXT,
       name TEXT,
       budget REAL,
       revenue REAL,
       popularity REAL,
       release_date DATE,
       vote_average REAL,
       vote_count INTEGER,
       runtime REAL,
       production_country TEXT,
       language TEXT
     ) ENGINE=InnoDB"""

# %%
c = cnx.cursor()
c.execute(q)
cnx.commit()
# Out:
# ---------------------------------------------------------------------------
# MySQLInterfaceError                       Traceback (most recent call last)
# ~/anaconda3/lib/python3.7/site-packages/mysql/connector/connection_cext.py in cmd_query(self, query, raw, buffered, raw_as_string)
#     471                                raw=raw, buffered=buffered,
# --> 472                                raw_as_string=raw_as_string)
#     473         except MySQLInterfaceError as exc:
#
# MySQLInterfaceError: Table 'details' already exists
#
# During handling of the above exception, another exception occurred:
#
# ProgrammingError                          Traceback (most recent call last)
# <ipython-input-56-ea61b11638ac> in <module>
#       1 c = cnx.cursor()
# ----> 2 c.execute(q)
#       3 cnx.commit()
#
# ~/anaconda3/lib/python3.7/site-packages/mysql/connector/cursor_cext.py in execute(self, operation, params, multi)
#     264             result = self._cnx.cmd_query(stmt, raw=self._raw,
#     265                                          buffered=self._buffered,
# --> 266                                          raw_as_string=self._raw_as_string)
#     267         except MySQLInterfaceError as exc:
#     268             raise errors.get_mysql_exception(msg=exc.msg, errno=exc.errno,
#
# ~/anaconda3/lib/python3.7/site-packages/mysql/connector/connection_cext.py in cmd_query(self, query, raw, buffered, raw_as_string)
#     473         except MySQLInterfaceError as exc:
#     474             raise errors.get_mysql_exception(exc.errno, msg=exc.msg,
# --> 475                                              sqlstate=exc.sqlstate)
#     476         except AttributeError:
#     477             if self._unix_socket:
#
# ProgrammingError: 1050 (42S01): Table 'details' already exists

# %%
def movie_formatting(details):
    formatted_movies = []
    for movie in details:
        movie_tuple = (movie['id'], movie['imdb_id'], movie['name'], movie['budget'], 
        movie['revenue'], movie['popularity'], 
        movie['release_date'], movie['vote_average'], movie['vote_count'], movie['runtime'], movie['production_country'], movie['language'])
        formatted_movies.append(movie_tuple)
    return formatted_movies

# %%
def add_to_db_movies(movie_list):
    cnx = mysql.connector.connect(
    host = config.host,
    user = config.user,
    password = config.password,
    database = config.database)
    c = cnx.cursor()    
    stmt = """INSERT INTO details (id,
       imdb_id,
       name,
       budget,
       revenue,
       popularity,
       release_date,
       vote_average,
       vote_count,
       runtime,
       production_country,
       language) VALUES (%s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s)"""
    c.executemany(stmt, movie_list)
    cnx.commit()
    c.close()
    cnx.close()

# %%
movie_formatting(movie_details)
# Out:
# [(429203,
#   'tt2837574',
#   'The Old Man & the Gun',
#   0,
#   11277120,
#   261.026,
#   '2018-09-27',
#   6.4,
#   515,
#   93,
#   'US',
#   'en'),
#  (299536,
#   'tt4154756',
#   'Avengers: Infinity War',
#   300000000,
#   2046239637,
#   67.449,
#   '2018-04-25',
#   8.3,
#   15210,
#   149,
#   'US',
#   'en'),
#  (324857,
#   'tt4633694',
#   'Spider-Man: Into the Spider-Verse',
#   90000000,
#   375450417,
#   49.565,
#   '2018-12-06',
#   8.4,
#   5132,
#   117,
#   'US',
#   'en'),
#  (363088,
#   'tt5095030',
#   'Ant-Man and the Wasp',
#   140000000,
#   622674139,
#   40.387,
#   '2018-07-04',
#   7.0,
#   6988,
#   119,
#   'US',
#   'en'),
#  (404368,
#   'tt5848272',
#   'Ralph Breaks the Internet',
#   175000000,
#   529221154,
#   36.15,
#   '2018-11-20',
#   7.2,
#   3206,
#   112,
#   'US',
#   'en'),
#  (284054,
#   'tt1825683',
#   'Black Panther',
#   200000000,
#   1346739107,
#   39.031,
#   '2018-02-13',
#   7.4,
#   13224,
#   134,
#   'US',
#   'en'),
#  (383498,
#   'tt5463162',
#   'Deadpool 2',
#   110000000,
#   741547413,
#   39.787,
#   '2018-05-10',
#   7.5,
#   9509,
#   121,
#   'US',
#   'en'),
#  (424783,
#   'tt4701182',
#   'Bumblebee',
#   135000000,
#   465895025,
#   32.911,
#   '2018-12-15',
#   6.5,
#   2836,
#   114,
#   'US',
#   'en'),
#  (335983,
#   'tt1270797',
#   'Venom',
#   116000000,
#   855013954,
#   39.739,
#   '2018-09-28',
#   6.6,
#   7076,
#   112,
#   'US',
#   'en'),
#  (440471,
#   'tt6513656',
#   'Escape Plan 2: Hades',
#   0,
#   0,
#   27.584,
#   '2018-06-05',
#   4.7,
#   597,
#   93,
#   'US',
#   'en'),
#  (338952,
#   'tt4123430',
#   'Fantastic Beasts: The Crimes of Grindelwald',
#   200000000,
#   653355901,
#   36.264,
#   '2018-11-14',
#   6.9,
#   5469,
#   134,
#   'US',
#   'en'),
#  (428078,
#   'tt1571234',
#   'Mortal Engines',
#   100000000,
#   104236467,
#   33.002,
#   '2018-11-27',
#   6.0,
#   2115,
#   129,
#   'US',
#   'en'),
#  (424694,
#   'tt1727824',
#   'Bohemian Rhapsody',
#   52000000,
#   894027543,
#   37.693,
#   '2018-10-24',
#   8.1,
#   8619,
#   135,
#   'US',
#   'en'),
#  (297802,
#   'tt1477834',
#   'Aquaman',
#   160000000,
#   1143689193,
#   32.792,
#   '2018-12-07',
#   6.8,
#   6967,
#   144,
#   'US',
#   'en'),
#  (351286,
#   'tt4881806',
#   'Jurassic World: Fallen Kingdom',
#   170000000,
#   1303459585,
#   39.126,
#   '2018-06-06',
#   6.5,
#   6413,
#   129,
#   'US',
#   'en'),
#  (260513,
#   'tt3606756',
#   'Incredibles 2',
#   200000000,
#   1241891456,
#   32.162,
#   '2018-06-14',
#   7.6,
#   6949,
#   118,
#   'US',
#   'en'),
#  (399402,
#   'tt1846589',
#   'Hunter Killer',
#   0,
#   0,
#   31.59,
#   '2018-10-19',
#   6.4,
#   806,
#   122,
#   'US',
#   'en'),
#  (332562,
#   'tt1517451',
#   'A Star Is Born',
#   36000000,
#   433888866,
#   32.477,
#   '2018-10-03',
#   7.5,
#   6423,
#   135,
#   'US',
#   'en'),
#  (353081,
#   'tt4912910',
#   'Mission: Impossible - Fallout',
#   178000000,
#   791017452,
#   28.553,
#   '2018-07-13',
#   7.3,
#   4157,
#   148,
#   'US',
#   'en'),
#  (375588,
#   'tt4532826',
#   'Robin Hood',
#   100000000,
#   73260114,
#   36.171,
#   '2018-11-21',
#   5.8,
#   1431,
#   116,
#   'US',
#   'en')]

# %%
# add_to_db_movies(movie_formatting(movie_details))

# %%
import pandas as pd
import mysql.connector
import config
cnx = mysql.connector.connect(
    host = config.host,
    user = config.user,
    password = config.password,
    database = config.database)
c = cnx.cursor()

# %%
q = """CREATE TABLE genre (
       id int(6),
       genre VARCHAR(255),
       PRIMARY KEY (id, genre)
     ) ENGINE=InnoDB"""

# %%
q = """ DROP TABLE genre;"""

# %%
c.execute(q)
cnx.commit()

# %%
def genre_formatting(details):
    formatted_genres = []
    for genre in details:
        for key, value in genre.items():
            for genre in value:
                genre_tuple = ( key ,genre )
                formatted_genres.append(genre_tuple)
    return formatted_genres

# %%
def add_to_db_genres(genres_list):
    cnx = mysql.connector.connect(
    host = config.host,
    user = config.user,
    password = config.password,
    database = config.database)
    c = cnx.cursor()    
    stmt = """INSERT INTO genre (id, genre)
       VALUES (%s, %s)"""
    c.executemany(stmt, genres_list)
    cnx.commit()
    c.close()
    cnx.close()

# %%
add_to_db_genres(genre_formatting(movie_genres))

# %%
movie_ids = []

for movie in result['results']:
    movie_ids.append(movie['id'])

# %%
movie_ids
# Out:
# [429203,
#  299536,
#  324857,
#  363088,
#  404368,
#  284054,
#  383498,
#  424783,
#  335983,
#  440471,
#  338952,
#  428078,
#  424694,
#  297802,
#  351286,
#  260513,
#  399402,
#  332562,
#  353081,
#  375588]

# %%
# Original Code to pull movie details
movie_details = []
for movie in movie_ids[:2]:
    api_call = api_url + str(movie) + config.api_key
    print(api_call)
    response = requests.get(api_call)
    result = response.json()
    movie_details.append(result)

# %%
movies_missing_cast = []
api_url = 'https://api.themoviedb.org/3/movie/'
api_call = api_url + str(movie_ids[0]) + '/credits' + config.api_key
response = requests.get(api_call)
if response.status_code != 200:
    movies_missing_cast.append(movie)
else:
    result = response.json()

# %%
api_call
# Out:
# 'https://api.themoviedb.org/3/movie/429203/credits?api_key=09788a07dd795fd26ca2bc24e9a61cb0'

# %%
result.keys()
# Out:
# dict_keys(['id', 'cast', 'crew'])

# %%
result['id']
# Out:
# 429203

# %%
result['cast'][3]
# Out:
# {'cast_id': 4,
#  'character': 'Teddy',
#  'credit_id': '58d4254b9251411f900193cb',
#  'gender': 2,
#  'id': 2047,
#  'name': 'Danny Glover',
#  'order': 3,
#  'profile_path': '/jSNTEnm0Sxm8FRtoBfJmhmQyozH.jpg'}

# %%
movies_missing_cast = []
movie_actors = []

for movie in movie_ids:

    api_url = 'https://api.themoviedb.org/3/movie/'
    api_call = api_url + str(movie) + '/credits' + config.api_key
    response = requests.get(api_call)
    if response.status_code != 200:
        movies_missing_cast.append(movie)
    else:
        result = response.json()
        for person in result['cast']:
            actor_dict = {}
            actor_dict['movie_id']  = movie
            actor_dict['actor_id'] = person['id']
            actor_dict['order'] = person['order']
            actor_dict['name'] =  person['name']
            movie_actors.append(actor_dict)

# %%
movie_actors
# Out:
# [{'movie_id': 429203, 'actor_id': 4135, 'order': 0, 'name': 'Robert Redford'},
#  {'movie_id': 429203, 'actor_id': 5606, 'order': 1, 'name': 'Sissy Spacek'},
#  {'movie_id': 429203, 'actor_id': 1893, 'order': 2, 'name': 'Casey Affleck'},
#  {'movie_id': 429203, 'actor_id': 2047, 'order': 3, 'name': 'Danny Glover'},
#  {'movie_id': 429203, 'actor_id': 2887, 'order': 4, 'name': 'Tom Waits'},
#  {'movie_id': 429203, 'actor_id': 110742, 'order': 5, 'name': 'Tika Sumpter'},
#  {'movie_id': 429203,
#   'actor_id': 2200140,
#   'order': 6,
#   'name': 'Ari Elizabeth Johnson'},
#  {'movie_id': 429203,
#   'actor_id': 2200141,
#   'order': 7,
#   'name': 'Teagan Johnson'},
#  {'movie_id': 429203, 'actor_id': 1194944, 'order': 8, 'name': 'Gene Jones'},
#  {'movie_id': 429203,
#   'actor_id': 1117313,
#   'order': 9,
#   'name': 'John David Washington'},
#  {'movie_id': 429203, 'actor_id': 71885, 'order': 10, 'name': 'Barlow Jacobs'},
#  {'movie_id': 429203,
#   'actor_id': 1285848,
#   'order': 11,
#   'name': 'Augustine Frizzell'},
#  {'movie_id': 429203,
#   'actor_id': 2200151,
#   'order': 12,
#   'name': 'Jennifer Joplin'},
#  {'movie_id': 429203,
#   'actor_id': 17490,
#   'order': 13,
#   'name': 'Isiah Whitlock Jr.'},
#  {'movie_id': 429203,
#   'actor_id': 32798,
#   'order': 14,
#   'name': 'Elisabeth Moss'},
#  {'movie_id': 429203,
#   'actor_id': 30613,
#   'order': 15,
#   'name': 'Keith Carradine'},
#  {'movie_id': 429203,
#   'actor_id': 79416,
#   'order': 16,
#   'name': 'Robert Longstreet'},
#  {'movie_id': 299536,
#   'actor_id': 3223,
#   'order': 0,
#   'name': 'Robert Downey Jr.'},
#  {'movie_id': 299536,
#   'actor_id': 74568,
#   'order': 1,
#   'name': 'Chris Hemsworth'},
#  {'movie_id': 299536, 'actor_id': 16828, 'order': 2, 'name': 'Chris Evans'},
#  {'movie_id': 299536, 'actor_id': 103, 'order': 3, 'name': 'Mark Ruffalo'},
#  {'movie_id': 299536,
#   'actor_id': 1245,
#   'order': 4,
#   'name': 'Scarlett Johansson'},
#  {'movie_id': 299536,
#   'actor_id': 71580,
#   'order': 5,
#   'name': 'Benedict Cumberbatch'},
#  {'movie_id': 299536, 'actor_id': 1136406, 'order': 6, 'name': 'Tom Holland'},
#  {'movie_id': 299536,
#   'actor_id': 172069,
#   'order': 7,
#   'name': 'Chadwick Boseman'},
#  {'movie_id': 299536, 'actor_id': 1896, 'order': 8, 'name': 'Don Cheadle'},
#  {'movie_id': 299536, 'actor_id': 8691, 'order': 9, 'name': 'Zoe Saldana'},
#  {'movie_id': 299536, 'actor_id': 543261, 'order': 10, 'name': 'Karen Gillan'},
#  {'movie_id': 299536,
#   'actor_id': 550843,
#   'order': 11,
#   'name': 'Elizabeth Olsen'},
#  {'movie_id': 299536, 'actor_id': 6162, 'order': 12, 'name': 'Paul Bettany'},
#  {'movie_id': 299536,
#   'actor_id': 53650,
#   'order': 13,
#   'name': 'Anthony Mackie'},
#  {'movie_id': 299536,
#   'actor_id': 60898,
#   'order': 14,
#   'name': 'Sebastian Stan'},
#  {'movie_id': 299536,
#   'actor_id': 91606,
#   'order': 15,
#   'name': 'Tom Hiddleston'},
#  {'movie_id': 299536, 'actor_id': 17605, 'order': 16, 'name': 'Idris Elba'},
#  {'movie_id': 299536, 'actor_id': 82104, 'order': 17, 'name': 'Danai Gurira'},
#  {'movie_id': 299536,
#   'actor_id': 22970,
#   'order': 18,
#   'name': 'Peter Dinklage'},
#  {'movie_id': 299536, 'actor_id': 30082, 'order': 19, 'name': 'Benedict Wong'},
#  {'movie_id': 299536,
#   'actor_id': 139820,
#   'order': 20,
#   'name': 'Pom Klementieff'},
#  {'movie_id': 299536,
#   'actor_id': 543530,
#   'order': 21,
#   'name': 'Dave Bautista'},
#  {'movie_id': 299536, 'actor_id': 12835, 'order': 22, 'name': 'Vin Diesel'},
#  {'movie_id': 299536,
#   'actor_id': 51329,
#   'order': 23,
#   'name': 'Bradley Cooper'},
#  {'movie_id': 299536,
#   'actor_id': 12052,
#   'order': 24,
#   'name': 'Gwyneth Paltrow'},
#  {'movie_id': 299536,
#   'actor_id': 1121,
#   'order': 25,
#   'name': 'Benicio del Toro'},
#  {'movie_id': 299536, 'actor_id': 16851, 'order': 26, 'name': 'Josh Brolin'},
#  {'movie_id': 299536, 'actor_id': 73457, 'order': 27, 'name': 'Chris Pratt'},
#  {'movie_id': 299536, 'actor_id': 51663, 'order': 28, 'name': 'Sean Gunn'},
#  {'movie_id': 299536, 'actor_id': 227, 'order': 29, 'name': 'William Hurt'},
#  {'movie_id': 299536,
#   'actor_id': 1083010,
#   'order': 30,
#   'name': 'Letitia Wright'},
#  {'movie_id': 299536, 'actor_id': 236696, 'order': 31, 'name': 'Terry Notary'},
#  {'movie_id': 299536,
#   'actor_id': 29240,
#   'order': 32,
#   'name': 'Tom Vaughan-Lawlor'},
#  {'movie_id': 299536, 'actor_id': 1308445, 'order': 33, 'name': 'Carrie Coon'},
#  {'movie_id': 299536,
#   'actor_id': 1379821,
#   'order': 34,
#   'name': 'Michael James Shaw'},
#  {'movie_id': 299536, 'actor_id': 7624, 'order': 35, 'name': 'Stan Lee'},
#  {'movie_id': 299536,
#   'actor_id': 1447932,
#   'order': 36,
#   'name': 'Winston Duke'},
#  {'movie_id': 299536,
#   'actor_id': 139900,
#   'order': 37,
#   'name': 'Florence Kasumba'},
#  {'movie_id': 299536, 'actor_id': 62105, 'order': 38, 'name': 'Kerry Condon'},
#  {'movie_id': 299536,
#   'actor_id': 102744,
#   'order': 39,
#   'name': 'Monique Ganderton'},
#  {'movie_id': 299536,
#   'actor_id': 1649152,
#   'order': 40,
#   'name': 'Jacob Batalon'},
#  {'movie_id': 299536,
#   'actor_id': 211937,
#   'order': 41,
#   'name': 'Tiffany Espensen'},
#  {'movie_id': 299536,
#   'actor_id': 1517836,
#   'order': 42,
#   'name': 'Isabella Amara'},
#  {'movie_id': 299536, 'actor_id': 212003, 'order': 43, 'name': 'Ethan Dizon'},
#  {'movie_id': 299536,
#   'actor_id': 1767250,
#   'order': 44,
#   'name': 'Ariana Greenblatt'},
#  {'movie_id': 299536,
#   'actor_id': 1448180,
#   'order': 45,
#   'name': 'Ameenah Kaplan'},
#  {'movie_id': 299536,
#   'actor_id': 555249,
#   'order': 46,
#   'name': 'Ross Marquand'},
#  {'movie_id': 299536,
#   'actor_id': 1779567,
#   'order': 47,
#   'name': 'Michael Anthony Rogers'},
#  {'movie_id': 299536,
#   'actor_id': 5552,
#   'order': 48,
#   'name': 'Stephen McFeely'},
#  {'movie_id': 299536, 'actor_id': 964421, 'order': 49, 'name': 'Aaron Lazar'},
#  {'movie_id': 299536, 'actor_id': 97844, 'order': 50, 'name': 'Robert Pralgo'},
#  {'movie_id': 299536,
#   'actor_id': 2031105,
#   'order': 51,
#   'name': 'Olaniyan Thurmon'},
#  {'movie_id': 299536, 'actor_id': 1003792, 'order': 52, 'name': 'Blair Jasin'},
#  {'movie_id': 299536, 'actor_id': 1480027, 'order': 53, 'name': 'Matthew Zuk'},
#  {'movie_id': 299536,
#   'actor_id': 2105647,
#   'order': 54,
#   'name': 'Laura Miller'},
#  {'movie_id': 299536,
#   'actor_id': 11181,
#   'order': 55,
#   'name': 'Kenneth Branagh'},
#  {'movie_id': 299536,
#   'actor_id': 2231,
#   'order': 56,
#   'name': 'Samuel L. Jackson'},
#  {'movie_id': 299536,
#   'actor_id': 71189,
#   'order': 57,
#   'name': 'Cobie Smulders'},
#  {'movie_id': 324857, 'actor_id': 587506, 'order': 0, 'name': 'Shameik Moore'},
#  {'movie_id': 324857, 'actor_id': 543505, 'order': 1, 'name': 'Jake Johnson'},
#  {'movie_id': 324857,
#   'actor_id': 130640,
#   'order': 2,
#   'name': 'Hailee Steinfeld'},
#  {'movie_id': 324857,
#   'actor_id': 932967,
#   'order': 3,
#   'name': 'Mahershala Ali'},
#  {'movie_id': 324857,
#   'actor_id': 226366,
#   'order': 4,
#   'name': 'Brian Tyree Henry'},
#  {'movie_id': 324857, 'actor_id': 10437, 'order': 5, 'name': 'Lily Tomlin'},
#  {'movie_id': 324857, 'actor_id': 141610, 'order': 6, 'name': 'Lauren Vélez'},
#  {'movie_id': 324857, 'actor_id': 37153, 'order': 7, 'name': 'Zoë Kravitz'},
#  {'movie_id': 324857, 'actor_id': 933558, 'order': 8, 'name': 'John Mulaney'},
#  {'movie_id': 324857, 'actor_id': 1443708, 'order': 9, 'name': 'Kimiko Glenn'},
#  {'movie_id': 324857, 'actor_id': 2963, 'order': 10, 'name': 'Nicolas Cage'},
#  {'movie_id': 324857, 'actor_id': 17696, 'order': 11, 'name': 'Kathryn Hahn'},
#  {'movie_id': 324857,
#   'actor_id': 23626,
#   'order': 12,
#   'name': 'Liev Schreiber'},
#  {'movie_id': 324857, 'actor_id': 62064, 'order': 13, 'name': 'Chris Pine'},
#  {'movie_id': 324857,
#   'actor_id': 118752,
#   'order': 14,
#   'name': 'Natalie Morales'},
#  {'movie_id': 324857,
#   'actor_id': 1746631,
#   'order': 15,
#   'name': 'Edwin H. Bravo'},
#  {'movie_id': 324857, 'actor_id': 25072, 'order': 16, 'name': 'Oscar Isaac'},
#  {'movie_id': 324857, 'actor_id': 1260481, 'order': 17, 'name': 'Greta Lee'},
#  {'movie_id': 324857, 'actor_id': 7624, 'order': 18, 'name': 'Stan Lee'},
#  {'movie_id': 324857, 'actor_id': 62863, 'order': 19, 'name': 'Jorma Taccone'},
#  {'movie_id': 324857, 'actor_id': 76857, 'order': 20, 'name': 'Joaquín Cosio'},
#  {'movie_id': 324857,
#   'actor_id': 1962692,
#   'order': 21,
#   'name': "Marvin 'Krondon' Jones III"},
#  {'movie_id': 324857,
#   'actor_id': 1252472,
#   'order': 22,
#   'name': 'Kim Yarbrough'},
#  {'movie_id': 324857, 'actor_id': 25703, 'order': 23, 'name': 'Lake Bell'},
#  {'movie_id': 324857, 'actor_id': 159468, 'order': 26, 'name': 'Nick Jaine'},
#  {'movie_id': 324857,
#   'actor_id': 2060803,
#   'order': 27,
#   'name': 'Muneeb Rehman'},
#  {'movie_id': 324857, 'actor_id': 1821863, 'order': 28, 'name': 'Post Malone'},
#  {'movie_id': 324857,
#   'actor_id': 1476863,
#   'order': 29,
#   'name': 'Melanie Haynes'},
#  {'movie_id': 324857, 'actor_id': 571309, 'order': 30, 'name': 'Lex Lang'},
#  {'movie_id': 324857,
#   'actor_id': 155267,
#   'order': 31,
#   'name': 'Christopher Miller'},
#  {'movie_id': 324857,
#   'actor_id': 113916,
#   'order': 32,
#   'name': 'Scott Menville'},
#  {'movie_id': 324857,
#   'actor_id': 1363155,
#   'order': 33,
#   'name': 'Juan Pacheco'},
#  {'movie_id': 324857,
#   'actor_id': 1703174,
#   'order': 34,
#   'name': 'Miguel Jiron'},
#  {'movie_id': 363088, 'actor_id': 22226, 'order': 0, 'name': 'Paul Rudd'},
#  {'movie_id': 363088,
#   'actor_id': 19034,
#   'order': 1,
#   'name': 'Evangeline Lilly'},
#  {'movie_id': 363088, 'actor_id': 454, 'order': 2, 'name': 'Michael Peña'},
#  {'movie_id': 363088, 'actor_id': 27740, 'order': 3, 'name': 'Walton Goggins'},
#  {'movie_id': 363088,
#   'actor_id': 21127,
#   'order': 4,
#   'name': 'Bobby Cannavale'},
#  {'movie_id': 363088, 'actor_id': 20750, 'order': 5, 'name': 'Judy Greer'},
#  {'movie_id': 363088, 'actor_id': 76126, 'order': 6, 'name': 'T.I.'},
#  {'movie_id': 363088,
#   'actor_id': 83854,
#   'order': 7,
#   'name': 'David Dastmalchian'},
#  {'movie_id': 363088,
#   'actor_id': 1408809,
#   'order': 8,
#   'name': 'Hannah John-Kamen'},
#  {'movie_id': 363088,
#   'actor_id': 1360010,
#   'order': 9,
#   'name': 'Abby Ryder Fortson'},
#  {'movie_id': 363088, 'actor_id': 79082, 'order': 10, 'name': 'Randall Park'},
#  {'movie_id': 363088,
#   'actor_id': 1160,
#   'order': 11,
#   'name': 'Michelle Pfeiffer'},
#  {'movie_id': 363088,
#   'actor_id': 2975,
#   'order': 12,
#   'name': 'Laurence Fishburne'},
#  {'movie_id': 363088,
#   'actor_id': 3392,
#   'order': 13,
#   'name': 'Michael Douglas'},
#  {'movie_id': 363088,
#   'actor_id': 1285715,
#   'order': 14,
#   'name': 'Divian Ladwa'},
#  {'movie_id': 363088, 'actor_id': 44736, 'order': 15, 'name': 'Goran Kostić'},
#  {'movie_id': 363088, 'actor_id': 1024492, 'order': 16, 'name': 'Rob Archer'},
#  {'movie_id': 363088, 'actor_id': 1425463, 'order': 17, 'name': 'Sean Kleier'},
#  {'movie_id': 363088,
#   'actor_id': 1356013,
#   'order': 18,
#   'name': 'Benjamin Byron Davis'},
#  {'movie_id': 363088,
#   'actor_id': 49827,
#   'order': 19,
#   'name': 'Michael Cerveris'},
#  {'movie_id': 363088, 'actor_id': 587115, 'order': 20, 'name': 'Riann Steele'},
#  {'movie_id': 363088, 'actor_id': 1224311, 'order': 21, 'name': 'Dax Griffin'},
#  {'movie_id': 363088,
#   'actor_id': 1156046,
#   'order': 22,
#   'name': 'Hayley Lovitt'},
#  {'movie_id': 363088,
#   'actor_id': 1632945,
#   'order': 23,
#   'name': 'Langston Fishburne'},
#  {'movie_id': 363088,
#   'actor_id': 1951080,
#   'order': 24,
#   'name': 'RaeLynn Bratten'},
#  {'movie_id': 363088,
#   'actor_id': 1530558,
#   'order': 25,
#   'name': 'Madeleine McGraw'},
#  {'movie_id': 363088,
#   'actor_id': 132856,
#   'order': 26,
#   'name': 'Tim Heidecker'},
#  {'movie_id': 363088, 'actor_id': 7624, 'order': 27, 'name': 'Stan Lee'},
#  {'movie_id': 363088,
#   'actor_id': 1923570,
#   'order': 28,
#   'name': 'Charles Justo'},
#  {'movie_id': 363088, 'actor_id': 54728, 'order': 29, 'name': 'Brian Huskey'},
#  {'movie_id': 363088,
#   'actor_id': 74135,
#   'order': 30,
#   'name': 'Suehyla El-Attar'},
#  {'movie_id': 363088, 'actor_id': 168881, 'order': 31, 'name': 'Julia Vera'},
#  {'movie_id': 363088,
#   'actor_id': 2141040,
#   'order': 32,
#   'name': 'Jessica Winther'},
#  {'movie_id': 363088,
#   'actor_id': 2141041,
#   'order': 33,
#   'name': 'Norwood J. Cheek Jr.'},
#  {'movie_id': 363088, 'actor_id': 1367121, 'order': 34, 'name': 'Bryan Lugo'},
#  {'movie_id': 363088, 'actor_id': 194493, 'order': 35, 'name': 'Darcy Shean'},
#  {'movie_id': 363088,
#   'actor_id': 1049137,
#   'order': 36,
#   'name': 'Torrey Vogel'},
#  {'movie_id': 363088, 'actor_id': 150195, 'order': 37, 'name': 'Simon Potter'},
#  {'movie_id': 363088, 'actor_id': 206226, 'order': 38, 'name': 'Jon Wurster'},
#  {'movie_id': 363088,
#   'actor_id': 1226513,
#   'order': 39,
#   'name': 'Tom Scharpling'},
#  {'movie_id': 363088,
#   'actor_id': 1393910,
#   'order': 40,
#   'name': 'Virginia Hamilton'},
#  {'movie_id': 363088,
#   'actor_id': 2141042,
#   'order': 41,
#   'name': 'Natasha Zouves'},
#  {'movie_id': 363088, 'actor_id': 2221430, 'order': 42, 'name': 'Mika Kubo'},
#  {'movie_id': 363088,
#   'actor_id': 1046665,
#   'order': 43,
#   'name': 'Joshua Mikel'},
#  {'movie_id': 363088, 'actor_id': 154837, 'order': 45, 'name': 'Chris Gann'},
#  {'movie_id': 363088,
#   'actor_id': 1923571,
#   'order': 46,
#   'name': 'Sergio Briones'},
#  {'movie_id': 363088,
#   'actor_id': 159264,
#   'order': 47,
#   'name': 'Denney Pierce'},
#  {'movie_id': 363088,
#   'actor_id': 1422991,
#   'order': 48,
#   'name': 'Vanessa Ross'},
#  {'movie_id': 363088,
#   'actor_id': 1278365,
#   'order': 49,
#   'name': 'Zachary Culbertson'},
#  {'movie_id': 363088, 'actor_id': 928577, 'order': 50, 'name': 'Steven Wiig'},
#  {'movie_id': 363088,
#   'actor_id': 1787405,
#   'order': 51,
#   'name': 'Timothy Carr'},
#  {'movie_id': 363088,
#   'actor_id': 1923580,
#   'order': 52,
#   'name': 'Sawyer Jones'},
#  {'movie_id': 363088,
#   'actor_id': 1923577,
#   'order': 53,
#   'name': 'Rick Richardson'},
#  {'movie_id': 363088,
#   'actor_id': 1206829,
#   'order': 54,
#   'name': 'Benjamin Weaver'},
#  {'movie_id': 363088,
#   'actor_id': 1787403,
#   'order': 55,
#   'name': 'Jamel Chambers'},
#  {'movie_id': 363088,
#   'actor_id': 1923575,
#   'order': 56,
#   'name': 'Jennifer Black'},
#  {'movie_id': 363088,
#   'actor_id': 1833388,
#   'order': 57,
#   'name': 'Sandra Dee Richardson'},
#  {'movie_id': 363088,
#   'actor_id': 1767219,
#   'order': 58,
#   'name': 'Tahseen Ghauri'},
#  {'movie_id': 363088, 'actor_id': 1923572, 'order': 59, 'name': 'Dale Liner'},
#  {'movie_id': 363088, 'actor_id': 1923578, 'order': 60, 'name': 'John Ozuna'},
#  {'movie_id': 363088,
#   'actor_id': 1923569,
#   'order': 61,
#   'name': 'Marcella Bragio'},
#  {'movie_id': 363088,
#   'actor_id': 1923576,
#   'order': 62,
#   'name': 'Sophia Marcs'},
#  {'movie_id': 363088,
#   'actor_id': 1923573,
#   'order': 63,
#   'name': 'William W. Barbour'},
#  {'movie_id': 363088,
#   'actor_id': 1923581,
#   'order': 64,
#   'name': 'Kevin Carscallen'},
#  {'movie_id': 363088,
#   'actor_id': 1923579,
#   'order': 65,
#   'name': 'Seth McCracken'},
#  {'movie_id': 404368, 'actor_id': 4764, 'order': 0, 'name': 'John C. Reilly'},
#  {'movie_id': 404368, 'actor_id': 7404, 'order': 1, 'name': 'Sarah Silverman'},
#  {'movie_id': 404368, 'actor_id': 90633, 'order': 2, 'name': 'Gal Gadot'},
#  {'movie_id': 404368,
#   'actor_id': 40036,
#   'order': 3,
#   'name': 'Taraji P. Henson'},
#  {'movie_id': 404368, 'actor_id': 58737, 'order': 4, 'name': 'Jack McBrayer'},
#  {'movie_id': 404368, 'actor_id': 43775, 'order': 5, 'name': 'Jane Lynch'},
#  {'movie_id': 404368, 'actor_id': 21088, 'order': 6, 'name': 'Alan Tudyk'},
#  {'movie_id': 404368, 'actor_id': 658, 'order': 7, 'name': 'Alfred Molina'},
#  {'movie_id': 404368, 'actor_id': 18977, 'order': 8, 'name': "Ed O'Neill"},
#  {'movie_id': 404368, 'actor_id': 19278, 'order': 9, 'name': 'Bill Hader'},
#  {'movie_id': 404368,
#   'actor_id': 1258699,
#   'order': 10,
#   'name': 'Sean Giambrone'},
#  {'movie_id': 404368, 'actor_id': 1471841, 'order': 11, 'name': 'Flula Borg'},
#  {'movie_id': 404368,
#   'actor_id': 1181329,
#   'order': 12,
#   'name': 'Timothy Simons'},
#  {'movie_id': 404368, 'actor_id': 591835, 'order': 13, 'name': 'Ali Wong'},
#  {'movie_id': 404368, 'actor_id': 220877, 'order': 14, 'name': 'Hamish Blake'},
#  {'movie_id': 404368,
#   'actor_id': 60632,
#   'order': 15,
#   'name': 'Rebecca Wisocky'},
#  {'movie_id': 404368,
#   'actor_id': 1429453,
#   'order': 16,
#   'name': 'Sam Richardson'},
#  {'movie_id': 404368,
#   'actor_id': 1998733,
#   'order': 17,
#   'name': 'Jaboukie Young-White'},
#  {'movie_id': 404368,
#   'actor_id': 34521,
#   'order': 18,
#   'name': 'Maurice LaMarche'},
#  {'movie_id': 404368,
#   'actor_id': 1695631,
#   'order': 19,
#   'name': 'Melissa Villaseñor'},
#  {'movie_id': 404368, 'actor_id': 108253, 'order': 20, 'name': 'Katie Lowes'},
#  {'movie_id': 404368, 'actor_id': 95002, 'order': 21, 'name': 'Jamie Elman'},
#  {'movie_id': 404368, 'actor_id': 52117, 'order': 22, 'name': 'Horatio Sanz'},
#  {'movie_id': 404368, 'actor_id': 1424111, 'order': 23, 'name': 'Alex Moffat'},
#  {'movie_id': 404368, 'actor_id': 35515, 'order': 24, 'name': 'June Squibb'},
#  {'movie_id': 404368, 'actor_id': 1610446, 'order': 25, 'name': 'Della Saba'},
#  {'movie_id': 404368,
#   'actor_id': 2122126,
#   'order': 26,
#   'name': 'Michaela Zee'},
#  {'movie_id': 404368,
#   'actor_id': 567562,
#   'order': 27,
#   'name': 'Phil Johnston'},
#  {'movie_id': 404368, 'actor_id': 31531, 'order': 28, 'name': 'John DiMaggio'},
#  {'movie_id': 404368, 'actor_id': 165787, 'order': 29, 'name': 'Rich Moore'},
#  {'movie_id': 404368,
#   'actor_id': 1255816,
#   'order': 30,
#   'name': 'Colleen Ballinger'},
#  {'movie_id': 404368,
#   'actor_id': 2153569,
#   'order': 31,
#   'name': 'Dani Fernandez'},
#  {'movie_id': 404368,
#   'actor_id': 2153573,
#   'order': 32,
#   'name': 'Tiffany Herrera'},
#  {'movie_id': 404368, 'actor_id': 38333, 'order': 33, 'name': 'Ana Ortiz'},
#  {'movie_id': 404368, 'actor_id': 141687, 'order': 34, 'name': 'Dianna Agron'},
#  {'movie_id': 404368,
#   'actor_id': 111683,
#   'order': 35,
#   'name': 'Jason Mantzoukas'},
#  {'movie_id': 404368,
#   'actor_id': 1223658,
#   'order': 36,
#   'name': 'Raymond S. Persi'},
#  {'movie_id': 404368, 'actor_id': 1643257, 'order': 37, 'name': 'Fuschia!'},
#  {'movie_id': 404368,
#   'actor_id': 75038,
#   'order': 38,
#   'name': 'Roger Craig Smith'},
#  {'movie_id': 404368, 'actor_id': 12898, 'order': 39, 'name': 'Tim Allen'},
#  {'movie_id': 404368, 'actor_id': 18, 'order': 40, 'name': 'Brad Garrett'},
#  {'movie_id': 404368, 'actor_id': 6, 'order': 41, 'name': 'Anthony Daniels'},
#  {'movie_id': 404368, 'actor_id': 35219, 'order': 42, 'name': 'Corey Burton'},
#  {'movie_id': 404368, 'actor_id': 12835, 'order': 43, 'name': 'Vin Diesel'},
#  {'movie_id': 404368,
#   'actor_id': 1720506,
#   'order': 44,
#   'name': 'Jason Hightower'},
#  {'movie_id': 404368,
#   'actor_id': 2224931,
#   'order': 45,
#   'name': 'Brian Curless'},
#  {'movie_id': 404368,
#   'actor_id': 2224932,
#   'order': 46,
#   'name': 'Ann Barry Colgin'},
#  {'movie_id': 404368,
#   'actor_id': 2224933,
#   'order': 47,
#   'name': 'Viveca Paulin'},
#  {'movie_id': 404368,
#   'actor_id': 15347,
#   'order': 48,
#   'name': 'Michael Giacchino'},
#  {'movie_id': 404368, 'actor_id': 137194, 'order': 49, 'name': 'Kevin Deters'},
#  {'movie_id': 404368,
#   'actor_id': 967699,
#   'order': 50,
#   'name': 'Jeremy Milton'},
#  {'movie_id': 404368,
#   'actor_id': 2009789,
#   'order': 51,
#   'name': 'Jesse Averna'},
#  {'movie_id': 404368,
#   'actor_id': 151246,
#   'order': 52,
#   'name': 'Nicole Scherzinger'},
#  {'movie_id': 404368,
#   'actor_id': 2224935,
#   'order': 53,
#   'name': 'Brittany Kikuchi'},
#  {'movie_id': 404368,
#   'actor_id': 1453312,
#   'order': 54,
#   'name': 'Olivier Bénard'},
#  {'movie_id': 404368, 'actor_id': 1314953, 'order': 55, 'name': 'Ben McKee'},
#  {'movie_id': 404368,
#   'actor_id': 1314955,
#   'order': 56,
#   'name': 'Daniel "Z" Platzman'},
#  {'movie_id': 404368,
#   'actor_id': 1314952,
#   'order': 57,
#   'name': 'Dan Reynolds'},
#  {'movie_id': 404368,
#   'actor_id': 1314954,
#   'order': 58,
#   'name': 'Wayne Sermon'},
#  {'movie_id': 404368, 'actor_id': 65529, 'order': 59, 'name': 'Irene Bedard'},
#  {'movie_id': 404368, 'actor_id': 40462, 'order': 60, 'name': 'Kristen Bell'},
#  {'movie_id': 404368, 'actor_id': 63978, 'order': 61, 'name': 'Jodi Benson'},
#  {'movie_id': 404368,
#   'actor_id': 1564846,
#   'order': 62,
#   'name': "Auli'i Cravalho"},
#  {'movie_id': 404368, 'actor_id': 81667, 'order': 63, 'name': 'Jennifer Hale'},
#  {'movie_id': 404368, 'actor_id': 191855, 'order': 64, 'name': 'Kate Higgins'},
#  {'movie_id': 404368, 'actor_id': 15829, 'order': 65, 'name': 'Linda Larkin'},
#  {'movie_id': 404368,
#   'actor_id': 9015,
#   'order': 66,
#   'name': 'Kelly Macdonald'},
#  {'movie_id': 404368, 'actor_id': 19394, 'order': 67, 'name': 'Idina Menzel'},
#  {'movie_id': 404368, 'actor_id': 16855, 'order': 68, 'name': 'Mandy Moore'},
#  {'movie_id': 404368, 'actor_id': 62050, 'order': 69, 'name': "Paige O'Hara"},
#  {'movie_id': 404368,
#   'actor_id': 1232621,
#   'order': 70,
#   'name': 'Pamela Ribon'},
#  {'movie_id': 404368,
#   'actor_id': 15563,
#   'order': 71,
#   'name': 'Anika Noni Rose'},
#  {'movie_id': 404368, 'actor_id': 21702, 'order': 72, 'name': 'Ming-Na Wen'},
#  {'movie_id': 404368, 'actor_id': 1214974, 'order': 73, 'name': 'Mark Smith'},
#  {'movie_id': 404368,
#   'actor_id': 1255817,
#   'order': 74,
#   'name': 'Glozell Green'},
#  {'movie_id': 404368, 'actor_id': 1426657, 'order': 75, 'name': 'Kent Boyd'},
#  {'movie_id': 404368, 'actor_id': 1335646, 'order': 76, 'name': 'Rachel Crow'},
#  {'movie_id': 404368,
#   'actor_id': 113818,
#   'order': 77,
#   'name': 'Jenica Bergere'},
#  {'movie_id': 404368,
#   'actor_id': 1340677,
#   'order': 78,
#   'name': 'John Lavelle'},
#  {'movie_id': 404368,
#   'actor_id': 1447307,
#   'order': 79,
#   'name': 'Josie Trinidad'},
#  {'movie_id': 404368,
#   'actor_id': 1742303,
#   'order': 80,
#   'name': 'Ruth Strother'},
#  {'movie_id': 404368,
#   'actor_id': 1995005,
#   'order': 81,
#   'name': 'Elise Aliberti'},
#  {'movie_id': 404368,
#   'actor_id': 2009807,
#   'order': 82,
#   'name': 'Maddix Robinson'},
#  {'movie_id': 404368,
#   'actor_id': 96997,
#   'order': 83,
#   'name': 'Bradford Simonsen'},
#  {'movie_id': 404368,
#   'actor_id': 44029,
#   'order': 84,
#   'name': 'Fabienne Rawley'},
#  {'movie_id': 284054,
#   'actor_id': 172069,
#   'order': 0,
#   'name': 'Chadwick Boseman'},
#  {'movie_id': 284054,
#   'actor_id': 135651,
#   'order': 1,
#   'name': 'Michael B. Jordan'},
#  {'movie_id': 284054,
#   'actor_id': 1267329,
#   'order': 2,
#   'name': "Lupita Nyong'o"},
#  {'movie_id': 284054, 'actor_id': 82104, 'order': 3, 'name': 'Danai Gurira'},
#  {'movie_id': 284054, 'actor_id': 7060, 'order': 4, 'name': 'Martin Freeman'},
#  {'movie_id': 284054,
#   'actor_id': 206919,
#   'order': 5,
#   'name': 'Daniel Kaluuya'},
#  {'movie_id': 284054,
#   'actor_id': 1083010,
#   'order': 6,
#   'name': 'Letitia Wright'},
#  {'movie_id': 284054, 'actor_id': 1447932, 'order': 7, 'name': 'Winston Duke'},
#  {'movie_id': 284054,
#   'actor_id': 1225953,
#   'order': 8,
#   'name': 'Sterling K. Brown'},
#  {'movie_id': 284054, 'actor_id': 9780, 'order': 9, 'name': 'Angela Bassett'},
#  {'movie_id': 284054,
#   'actor_id': 2178,
#   'order': 10,
#   'name': 'Forest Whitaker'},
#  {'movie_id': 284054, 'actor_id': 1333, 'order': 11, 'name': 'Andy Serkis'},
#  {'movie_id': 284054,
#   'actor_id': 139900,
#   'order': 12,
#   'name': 'Florence Kasumba'},
#  {'movie_id': 284054, 'actor_id': 51878, 'order': 13, 'name': 'John Kani'},
#  {'movie_id': 284054, 'actor_id': 71078, 'order': 14, 'name': 'David S. Lee'},
#  {'movie_id': 284054, 'actor_id': 1856116, 'order': 15, 'name': 'Nabiyah Be'},
#  {'movie_id': 284054,
#   'actor_id': 4812,
#   'order': 16,
#   'name': 'Isaach De Bankolé'},
#  {'movie_id': 284054,
#   'actor_id': 1181397,
#   'order': 17,
#   'name': 'Connie Chiume'},
#  {'movie_id': 284054,
#   'actor_id': 1979169,
#   'order': 18,
#   'name': 'Dorothy  Steel'},
#  {'movie_id': 284054, 'actor_id': 165424, 'order': 19, 'name': 'Danny Sapani'},
#  {'movie_id': 284054,
#   'actor_id': 1104414,
#   'order': 20,
#   'name': 'Sydelle Noel'},
#  {'movie_id': 284054,
#   'actor_id': 1979170,
#   'order': 21,
#   'name': 'Marija Abney'},
#  {'movie_id': 284054,
#   'actor_id': 1979176,
#   'order': 22,
#   'name': 'Zola Williams'},
#  {'movie_id': 284054,
#   'actor_id': 1580160,
#   'order': 23,
#   'name': 'Janeshia Adams-Ginyard'},
#  {'movie_id': 284054,
#   'actor_id': 1979172,
#   'order': 24,
#   'name': 'Maria Hippolyte'},
#  {'movie_id': 284054,
#   'actor_id': 1979183,
#   'order': 25,
#   'name': 'Marie Mouroum'},
#  {'movie_id': 284054,
#   'actor_id': 1903679,
#   'order': 26,
#   'name': 'Jénel Stevens'},
#  {'movie_id': 284054, 'actor_id': 1431508, 'order': 27, 'name': 'Sope Aluko'},
#  {'movie_id': 284054, 'actor_id': 7624, 'order': 28, 'name': 'Stan Lee'},
#  {'movie_id': 284054,
#   'actor_id': 1222428,
#   'order': 29,
#   'name': 'Atandwa Kani'},
#  {'movie_id': 284054,
#   'actor_id': 1734933,
#   'order': 30,
#   'name': 'Ashton Tyler'},
#  {'movie_id': 284054,
#   'actor_id': 77278,
#   'order': 31,
#   'name': 'Denzel Whitaker'},
#  {'movie_id': 284054,
#   'actor_id': 1787399,
#   'order': 32,
#   'name': 'Shaunette Renée Wilson'},
#  {'movie_id': 284054,
#   'actor_id': 1979177,
#   'order': 33,
#   'name': 'Christine Hollingsworth'},
#  {'movie_id': 284054,
#   'actor_id': 1821546,
#   'order': 34,
#   'name': 'Lucy Hockings'},
#  {'movie_id': 284054,
#   'actor_id': 965219,
#   'order': 35,
#   'name': 'Bambadjan Bamba'},
#  {'movie_id': 284054,
#   'actor_id': 1787404,
#   'order': 36,
#   'name': 'Roland Kilumbu'},
#  {'movie_id': 284054,
#   'actor_id': 171733,
#   'order': 37,
#   'name': 'Francesca Faridany'},
#  {'movie_id': 284054,
#   'actor_id': 1301772,
#   'order': 38,
#   'name': 'Mark Ashworth'},
#  {'movie_id': 284054, 'actor_id': 1609481, 'order': 39, 'name': 'Seth Carr'},
#  {'movie_id': 284054,
#   'actor_id': 1456750,
#   'order': 40,
#   'name': 'Jeremy Sample'},
#  {'movie_id': 284054, 'actor_id': 58930, 'order': 41, 'name': 'Alexis Rhee'},
#  {'movie_id': 284054,
#   'actor_id': 1688889,
#   'order': 42,
#   'name': 'Alex Hibbert'},
#  {'movie_id': 284054, 'actor_id': 131133, 'order': 43, 'name': 'Trevor Noah'},
#  {'movie_id': 284054,
#   'actor_id': 60898,
#   'order': 44,
#   'name': 'Sebastian Stan'},
#  {'movie_id': 284054,
#   'actor_id': 1767219,
#   'order': 45,
#   'name': 'Tahseen Ghauri'},
#  {'movie_id': 284054, 'actor_id': 1787407, 'order': 46, 'name': 'Danny Chung'},
#  {'movie_id': 284054, 'actor_id': 973644, 'order': 47, 'name': 'Shad Gaspard'},
#  {'movie_id': 284054,
#   'actor_id': 1771603,
#   'order': 48,
#   'name': 'William Cowboy Reed'},
#  {'movie_id': 284054,
#   'actor_id': 1787401,
#   'order': 49,
#   'name': 'Michael David Yuhl'},
#  {'movie_id': 284054,
#   'actor_id': 1773399,
#   'order': 50,
#   'name': 'Elizabeth Elkins'},
#  {'movie_id': 284054, 'actor_id': 1787400, 'order': 51, 'name': 'Raven Wynn'},
#  {'movie_id': 284054,
#   'actor_id': 1787402,
#   'order': 52,
#   'name': 'Amechi Okocha'},
#  {'movie_id': 284054, 'actor_id': 1460999, 'order': 53, 'name': 'Tony Sears'},
#  {'movie_id': 284054,
#   'actor_id': 1787405,
#   'order': 54,
#   'name': 'Timothy Carr'},
#  {'movie_id': 284054, 'actor_id': 1787406, 'order': 55, 'name': 'Apollo GT'},
#  {'movie_id': 284054,
#   'actor_id': 1787408,
#   'order': 56,
#   'name': 'James Siderits'},
#  {'movie_id': 284054, 'actor_id': 1367313, 'order': 57, 'name': 'Travis Love'},
#  {'movie_id': 284054,
#   'actor_id': 1734929,
#   'order': 58,
#   'name': 'Lidya Jewett'},
#  {'movie_id': 284054,
#   'actor_id': 1795537,
#   'order': 59,
#   'name': 'Alona Leoine'},
#  {'movie_id': 284054,
#   'actor_id': 1856121,
#   'order': 60,
#   'name': 'Kinley Fleurejuste'},
#  {'movie_id': 284054, 'actor_id': 1856126, 'order': 61, 'name': 'Ofu Obekpa'},
#  {'movie_id': 284054,
#   'actor_id': 1856124,
#   'order': 62,
#   'name': 'Michael R. Ciminna'},
#  {'movie_id': 284054, 'actor_id': 1856128, 'order': 63, 'name': 'John Y Lee'},
#  {'movie_id': 284054,
#   'actor_id': 1856131,
#   'order': 64,
#   'name': 'Byron Coolie'},
#  {'movie_id': 284054,
#   'actor_id': 1856132,
#   'order': 65,
#   'name': 'William Walker'},
#  {'movie_id': 284054,
#   'actor_id': 1754081,
#   'order': 66,
#   'name': 'Joseph Akharoh Jr.'},
#  {'movie_id': 284054,
#   'actor_id': 1856133,
#   'order': 67,
#   'name': 'Stanley Aughtry'},
#  {'movie_id': 284054,
#   'actor_id': 1856135,
#   'order': 68,
#   'name': 'Raenen Golez'},
#  {'movie_id': 284054,
#   'actor_id': 1856136,
#   'order': 69,
#   'name': 'Leo De Rivera'},
#  {'movie_id': 284054, 'actor_id': 1856138, 'order': 70, 'name': 'Tevin Beech'},
#  {'movie_id': 284054, 'actor_id': 1856137, 'order': 71, 'name': 'Tari Omoro'},
#  {'movie_id': 284054,
#   'actor_id': 1856139,
#   'order': 72,
#   'name': 'Andrea Antonio Canal'},
#  {'movie_id': 284054,
#   'actor_id': 1826048,
#   'order': 73,
#   'name': 'David Dunston'},
#  {'movie_id': 284054,
#   'actor_id': 1856140,
#   'order': 75,
#   'name': 'Josue Louis-Charles'},
#  {'movie_id': 284054,
#   'actor_id': 1842230,
#   'order': 76,
#   'name': 'Isaac Phillips'},
#  {'movie_id': 284054,
#   'actor_id': 1787403,
#   'order': 77,
#   'name': 'Jamel Chambers'},
#  {'movie_id': 284054,
#   'actor_id': 2123041,
#   'order': 78,
#   'name': 'Michael Christopher Rodney'},
#  {'movie_id': 284054, 'actor_id': 2363214, 'order': 79, 'name': 'Shivam Pota'},
#  {'movie_id': 383498, 'actor_id': 10859, 'order': 0, 'name': 'Ryan Reynolds'},
#  {'movie_id': 383498, 'actor_id': 16851, 'order': 1, 'name': 'Josh Brolin'},
#  {'movie_id': 383498, 'actor_id': 1545693, 'order': 2, 'name': 'Zazie Beetz'},
#  {'movie_id': 383498,
#   'actor_id': 1139349,
#   'order': 3,
#   'name': 'Julian Dennison'},
#  {'movie_id': 383498, 'actor_id': 1109702, 'order': 4, 'name': 'Karan Soni'},
#  {'movie_id': 383498, 'actor_id': 51990, 'order': 5, 'name': 'T.J. Miller'},
#  {'movie_id': 383498,
#   'actor_id': 1492326,
#   'order': 6,
#   'name': 'Brianna Hildebrand'},
#  {'movie_id': 383498, 'actor_id': 122750, 'order': 7, 'name': 'Leslie Uggams'},
#  {'movie_id': 383498,
#   'actor_id': 54882,
#   'order': 8,
#   'name': 'Morena Baccarin'},
#  {'movie_id': 383498, 'actor_id': 1292258, 'order': 9, 'name': 'Jack Kesy'},
#  {'movie_id': 383498, 'actor_id': 1665, 'order': 10, 'name': 'Eddie Marsan'},
#  {'movie_id': 383498,
#   'actor_id': 230660,
#   'order': 11,
#   'name': 'Shiori Kutsuna'},
#  {'movie_id': 383498,
#   'actor_id': 80507,
#   'order': 12,
#   'name': 'Stefan Kapičić'},
#  {'movie_id': 383498,
#   'actor_id': 1368836,
#   'order': 13,
#   'name': 'Andre Tricoteux'},
#  {'movie_id': 383498,
#   'actor_id': 215887,
#   'order': 14,
#   'name': 'Randal Reeder'},
#  {'movie_id': 383498,
#   'actor_id': 1843783,
#   'order': 15,
#   'name': 'Nikolai Witschl'},
#  {'movie_id': 383498,
#   'actor_id': 1357969,
#   'order': 16,
#   'name': 'Thayr Harris'},
#  {'movie_id': 383498, 'actor_id': 1091324, 'order': 17, 'name': 'Rob Delaney'},
#  {'movie_id': 383498, 'actor_id': 1610940, 'order': 18, 'name': 'Lewis Tan'},
#  {'movie_id': 383498,
#   'actor_id': 137905,
#   'order': 19,
#   'name': 'Bill Skarsgård'},
#  {'movie_id': 383498, 'actor_id': 53256, 'order': 20, 'name': 'Terry Crews'},
#  {'movie_id': 383498, 'actor_id': 287, 'order': 21, 'name': 'Brad Pitt'},
#  {'movie_id': 383498, 'actor_id': 1224673, 'order': 22, 'name': 'Paul Wu'},
#  {'movie_id': 383498,
#   'actor_id': 112692,
#   'order': 23,
#   'name': 'Robert Maillet'},
#  {'movie_id': 383498, 'actor_id': 21088, 'order': 24, 'name': 'Alan Tudyk'},
#  {'movie_id': 383498, 'actor_id': 1892, 'order': 25, 'name': 'Matt Damon'},
#  {'movie_id': 383498,
#   'actor_id': 1237734,
#   'order': 26,
#   'name': 'Michasha Armstrong'},
#  {'movie_id': 383498, 'actor_id': 74677, 'order': 27, 'name': 'Hayley Sales'},
#  {'movie_id': 383498,
#   'actor_id': 1935296,
#   'order': 28,
#   'name': 'Islie Hirvonen'},
#  {'movie_id': 383498, 'actor_id': 2105672, 'order': 29, 'name': 'Joe Doserro'},
#  {'movie_id': 383498,
#   'actor_id': 2080718,
#   'order': 30,
#   'name': 'Jagua Arneja'},
#  {'movie_id': 383498, 'actor_id': 168520, 'order': 31, 'name': 'Gerry South'},
#  {'movie_id': 383498, 'actor_id': 64674, 'order': 32, 'name': 'Mike Dopud'},
#  {'movie_id': 383498,
#   'actor_id': 1848567,
#   'order': 33,
#   'name': 'Luke Roessler'},
#  {'movie_id': 383498, 'actor_id': 2105682, 'order': 34, 'name': 'Andy Canete'},
#  {'movie_id': 383498,
#   'actor_id': 2041208,
#   'order': 35,
#   'name': 'Tanis Dolman'},
#  {'movie_id': 383498,
#   'actor_id': 2105686,
#   'order': 36,
#   'name': 'Eleanor Walker'},
#  {'movie_id': 383498,
#   'actor_id': 1882895,
#   'order': 37,
#   'name': 'Hunter Dillon'},
#  {'movie_id': 383498, 'actor_id': 1366, 'order': 38, 'name': 'Sala Baker'},
#  {'movie_id': 383498,
#   'actor_id': 1904663,
#   'order': 39,
#   'name': 'Sonia Sunger'},
#  {'movie_id': 383498, 'actor_id': 91269, 'order': 40, 'name': 'Paul Wernick'},
#  {'movie_id': 383498, 'actor_id': 7932, 'order': 41, 'name': 'Rhett Reese'},
#  {'movie_id': 383498,
#   'actor_id': 2105699,
#   'order': 42,
#   'name': 'Abiola Uthman'},
#  {'movie_id': 383498, 'actor_id': 2105700, 'order': 43, 'name': 'Tony Bailey'},
#  {'movie_id': 383498, 'actor_id': 40684, 'order': 44, 'name': 'David Leitch'},
#  {'movie_id': 383498, 'actor_id': 6968, 'order': 45, 'name': 'Hugh Jackman'},
#  {'movie_id': 383498, 'actor_id': 5530, 'order': 46, 'name': 'James McAvoy'},
#  {'movie_id': 383498, 'actor_id': 3292, 'order': 47, 'name': 'Nicholas Hoult'},
#  {'movie_id': 383498,
#   'actor_id': 113505,
#   'order': 48,
#   'name': 'Kodi Smit-McPhee'},
#  {'movie_id': 383498,
#   'actor_id': 1253199,
#   'order': 49,
#   'name': 'Alexandra Shipp'},
#  {'movie_id': 383498, 'actor_id': 55089, 'order': 50, 'name': 'Evan Peters'},
#  {'movie_id': 383498,
#   'actor_id': 1034681,
#   'order': 51,
#   'name': 'Tye Sheridan'},
#  {'movie_id': 424783,
#   'actor_id': 130640,
#   'order': 0,
#   'name': 'Hailee Steinfeld'},
#  {'movie_id': 424783,
#   'actor_id': 1563266,
#   'order': 1,
#   'name': 'Jorge Lendeborg Jr.'},
#  {'movie_id': 424783, 'actor_id': 56446, 'order': 2, 'name': 'John Cena'},
#  {'movie_id': 424783,
#   'actor_id': 1517834,
#   'order': 3,
#   'name': 'Jason Ian Drucker'},
#  {'movie_id': 424783, 'actor_id': 21063, 'order': 4, 'name': 'Pamela Adlon'},
#  {'movie_id': 424783,
#   'actor_id': 1184280,
#   'order': 5,
#   'name': 'Stephen Schneider'},
#  {'movie_id': 424783, 'actor_id': 934136, 'order': 6, 'name': 'Ricardo Hoyos'},
#  {'movie_id': 424783, 'actor_id': 40543, 'order': 7, 'name': 'John Ortiz'},
#  {'movie_id': 424783, 'actor_id': 114674, 'order': 8, 'name': 'Glynn Turman'},
#  {'movie_id': 424783, 'actor_id': 41247, 'order': 9, 'name': 'Len Cariou'},
#  {'movie_id': 424783,
#   'actor_id': 2216189,
#   'order': 10,
#   'name': 'Kollin Holtz'},
#  {'movie_id': 424783,
#   'actor_id': 1456287,
#   'order': 11,
#   'name': 'Gracie Dzienny'},
#  {'movie_id': 424783, 'actor_id': 162272, 'order': 12, 'name': 'Fred Dryer'},
#  {'movie_id': 424783,
#   'actor_id': 2201167,
#   'order': 13,
#   'name': 'Isabelle Ellingson'},
#  {'movie_id': 424783, 'actor_id': 2221430, 'order': 14, 'name': 'Mika Kubo'},
#  {'movie_id': 424783,
#   'actor_id': 2221445,
#   'order': 15,
#   'name': 'Felicia Stiles'},
#  {'movie_id': 424783,
#   'actor_id': 2221446,
#   'order': 16,
#   'name': 'George Anagnostou'},
#  {'movie_id': 424783,
#   'actor_id': 1732883,
#   'order': 17,
#   'name': 'Brandon Wardle'},
#  {'movie_id': 424783,
#   'actor_id': 1246804,
#   'order': 18,
#   'name': 'Lenny Jacobson'},
#  {'movie_id': 424783, 'actor_id': 154332, 'order': 19, 'name': 'Megyn Price'},
#  {'movie_id': 424783,
#   'actor_id': 2172134,
#   'order': 20,
#   'name': 'Krystin Goodwin'},
#  {'movie_id': 424783, 'actor_id': 2216183, 'order': 21, 'name': 'Nick Pilla'},
#  {'movie_id': 424783,
#   'actor_id': 1139163,
#   'order': 22,
#   'name': 'Sachin Bhatt'},
#  {'movie_id': 424783,
#   'actor_id': 1694924,
#   'order': 23,
#   'name': 'Tim Martin Gleason'},
#  {'movie_id': 424783,
#   'actor_id': 2137392,
#   'order': 24,
#   'name': 'David Waters'},
#  {'movie_id': 424783,
#   'actor_id': 92611,
#   'order': 25,
#   'name': 'Antonio D. Charity'},
#  {'movie_id': 424783,
#   'actor_id': 2216184,
#   'order': 26,
#   'name': 'Courtney Coker'},
#  {'movie_id': 424783, 'actor_id': 56679, 'order': 27, 'name': 'Edwin Hodge'},
#  {'movie_id': 424783, 'actor_id': 1897705, 'order': 28, 'name': 'Jake Huang'},
#  {'movie_id': 424783,
#   'actor_id': 1723161,
#   'order': 29,
#   'name': 'Holland Diaz'},
#  {'movie_id': 424783,
#   'actor_id': 2221528,
#   'order': 30,
#   'name': 'David Cutler'},
#  {'movie_id': 424783, 'actor_id': 1663196, 'order': 31, 'name': 'Lars Slind'},
#  {'movie_id': 424783,
#   'actor_id': 527393,
#   'order': 32,
#   'name': "Dylan O'Brien"},
#  {'movie_id': 424783, 'actor_id': 19540, 'order': 33, 'name': 'Peter Cullen'},
#  {'movie_id': 424783, 'actor_id': 9780, 'order': 34, 'name': 'Angela Bassett'},
#  {'movie_id': 424783,
#   'actor_id': 15009,
#   'order': 35,
#   'name': 'Justin Theroux'},
#  {'movie_id': 424783,
#   'actor_id': 164614,
#   'order': 36,
#   'name': 'David Sobolov'},
#  {'movie_id': 424783, 'actor_id': 15761, 'order': 37, 'name': 'Grey DeLisle'},
#  {'movie_id': 424783, 'actor_id': 2204260, 'order': 38, 'name': 'Jon Bailey'},
#  {'movie_id': 424783, 'actor_id': 571562, 'order': 39, 'name': 'Steve Blum'},
#  {'movie_id': 424783,
#   'actor_id': 80823,
#   'order': 40,
#   'name': 'Andrew Morgado'},
#  {'movie_id': 424783, 'actor_id': 176035, 'order': 41, 'name': 'Kirk Baily'},
#  {'movie_id': 424783,
#   'actor_id': 2204259,
#   'order': 42,
#   'name': 'Dennis Singletary'},
#  {'movie_id': 424783,
#   'actor_id': 1422991,
#   'order': 46,
#   'name': 'Vanessa Ross'},
#  {'movie_id': 424783, 'actor_id': 1753418, 'order': 47, 'name': 'Tony Toste'},
#  {'movie_id': 424783, 'actor_id': 2221554, 'order': 48, 'name': 'Nico Abiera'},
#  {'movie_id': 424783,
#   'actor_id': 2221556,
#   'order': 49,
#   'name': 'Jiana Alvarez'},
#  {'movie_id': 424783,
#   'actor_id': 2221558,
#   'order': 50,
#   'name': 'Yianni Apostolopolous'},
#  {'movie_id': 424783, 'actor_id': 2221559, 'order': 51, 'name': 'Jace Areff'},
#  {'movie_id': 424783, 'actor_id': 2221560, 'order': 52, 'name': 'Manny Avina'},
#  {'movie_id': 424783,
#   'actor_id': 1923573,
#   'order': 53,
#   'name': 'William W. Barbour'},
#  {'movie_id': 335983, 'actor_id': 2524, 'order': 0, 'name': 'Tom Hardy'},
#  {'movie_id': 335983,
#   'actor_id': 1812,
#   'order': 1,
#   'name': 'Michelle Williams'},
#  {'movie_id': 335983, 'actor_id': 53240, 'order': 2, 'name': 'Riz Ahmed'},
#  {'movie_id': 335983, 'actor_id': 87954, 'order': 3, 'name': 'Scott Haze'},
#  {'movie_id': 335983, 'actor_id': 81316, 'order': 4, 'name': 'Reid Scott'},
#  {'movie_id': 335983, 'actor_id': 213001, 'order': 5, 'name': 'Jenny Slate'},
#  {'movie_id': 335983, 'actor_id': 4766, 'order': 6, 'name': 'Melora Walters'},
#  {'movie_id': 335983,
#   'actor_id': 57755,
#   'order': 7,
#   'name': 'Woody Harrelson'},
#  {'movie_id': 335983, 'actor_id': 2141479, 'order': 8, 'name': 'Peggy Lu'},
#  {'movie_id': 335983,
#   'actor_id': 1765806,
#   'order': 9,
#   'name': 'Malcolm C. Murray'},
#  {'movie_id': 335983, 'actor_id': 1431508, 'order': 10, 'name': 'Sope Aluko'},
#  {'movie_id': 335983, 'actor_id': 31528, 'order': 11, 'name': 'Wayne Pére'},
#  {'movie_id': 335983, 'actor_id': 101065, 'order': 12, 'name': 'Michelle Lee'},
#  {'movie_id': 335983, 'actor_id': 2068598, 'order': 13, 'name': 'Kurt Yue'},
#  {'movie_id': 335983,
#   'actor_id': 1387252,
#   'order': 14,
#   'name': "Chris O'Hara"},
#  {'movie_id': 335983, 'actor_id': 53257, 'order': 15, 'name': 'Emilio Rivera'},
#  {'movie_id': 335983,
#   'actor_id': 2141521,
#   'order': 16,
#   'name': 'Amelia Young'},
#  {'movie_id': 335983,
#   'actor_id': 1642892,
#   'order': 17,
#   'name': 'Ariadne Joseph'},
#  {'movie_id': 335983,
#   'actor_id': 2141510,
#   'order': 18,
#   'name': 'Deen Brooksher'},
#  {'movie_id': 335983, 'actor_id': 2141520, 'order': 19, 'name': 'David Jones'},
#  {'movie_id': 335983, 'actor_id': 2974, 'order': 20, 'name': 'Roger Yuan'},
#  {'movie_id': 335983,
#   'actor_id': 61705,
#   'order': 21,
#   'name': 'Woon Young Park'},
#  {'movie_id': 335983,
#   'actor_id': 2141516,
#   'order': 22,
#   'name': 'Patrick Chundah Chu'},
#  {'movie_id': 335983, 'actor_id': 208316, 'order': 23, 'name': 'Vickie Eng'},
#  {'movie_id': 335983, 'actor_id': 1215837, 'order': 24, 'name': 'Mac Brandt'},
#  {'movie_id': 335983, 'actor_id': 216147, 'order': 25, 'name': 'Nick Thune'},
#  {'movie_id': 335983,
#   'actor_id': 2191401,
#   'order': 26,
#   'name': 'Michael Dennis Hill'},
#  {'movie_id': 335983, 'actor_id': 1044954, 'order': 27, 'name': 'Sam Medina'},
#  {'movie_id': 335983,
#   'actor_id': 2023715,
#   'order': 28,
#   'name': 'Scott Deckert'},
#  {'movie_id': 335983,
#   'actor_id': 2191402,
#   'order': 29,
#   'name': 'Lauren Richards'},
#  {'movie_id': 335983,
#   'actor_id': 1668606,
#   'order': 30,
#   'name': 'Jared Bankens'},
#  {'movie_id': 335983,
#   'actor_id': 105714,
#   'order': 31,
#   'name': 'Lucas Fleischer'},
#  {'movie_id': 335983,
#   'actor_id': 1401994,
#   'order': 32,
#   'name': 'Michael Burgess'},
#  {'movie_id': 335983,
#   'actor_id': 1685538,
#   'order': 33,
#   'name': 'Diesel Madkins'},
#  {'movie_id': 335983, 'actor_id': 2141502, 'order': 34, 'name': 'Rxchie'},
#  {'movie_id': 335983,
#   'actor_id': 1736538,
#   'order': 35,
#   'name': 'Otis Winston'},
#  {'movie_id': 335983, 'actor_id': 2191406, 'order': 36, 'name': 'Zeva DuVall'},
#  {'movie_id': 335983,
#   'actor_id': 1853396,
#   'order': 37,
#   'name': 'Selena Anduze'},
#  {'movie_id': 335983,
#   'actor_id': 2191420,
#   'order': 38,
#   'name': 'Brittany L. Smith'},
#  {'movie_id': 335983,
#   'actor_id': 2141519,
#   'order': 39,
#   'name': 'Jordan Foster'},
#  {'movie_id': 335983,
#   'actor_id': 1078610,
#   'order': 40,
#   'name': 'Jane McNeill'},
#  {'movie_id': 335983, 'actor_id': 155030, 'order': 41, 'name': 'Victor McCay'},
#  {'movie_id': 335983,
#   'actor_id': 1455812,
#   'order': 42,
#   'name': 'Elizabeth Becka'},
#  {'movie_id': 335983, 'actor_id': 77520, 'order': 43, 'name': 'Ron Prather'},
#  {'movie_id': 335983,
#   'actor_id': 2203892,
#   'order': 44,
#   'name': 'Marcia White'},
#  {'movie_id': 335983,
#   'actor_id': 2142766,
#   'order': 45,
#   'name': 'Javier Vazquez Jr.'},
#  {'movie_id': 335983,
#   'actor_id': 170189,
#   'order': 46,
#   'name': 'Ellen Gerstein'},
#  {'movie_id': 335983,
#   'actor_id': 1371236,
#   'order': 47,
#   'name': 'Martin Bats Bradford'},
#  {'movie_id': 335983,
#   'actor_id': 1930879,
#   'order': 48,
#   'name': 'Steven Teuchert'},
#  {'movie_id': 335983,
#   'actor_id': 1792173,
#   'order': 49,
#   'name': 'Al-Jaleel Knox'},
#  {'movie_id': 335983,
#   'actor_id': 1388183,
#   'order': 50,
#   'name': 'Brandon Morales'},
#  {'movie_id': 335983,
#   'actor_id': 1068811,
#   'order': 51,
#   'name': 'Matthew Cornwell'},
#  {'movie_id': 335983,
#   'actor_id': 2159142,
#   'order': 52,
#   'name': 'David Fleischer'},
#  {'movie_id': 335983,
#   'actor_id': 1911542,
#   'order': 53,
#   'name': 'DJames Jones'},
#  {'movie_id': 335983,
#   'actor_id': 2073894,
#   'order': 54,
#   'name': 'Angela Davis'},
#  {'movie_id': 335983, 'actor_id': 7624, 'order': 55, 'name': 'Stan Lee'},
#  {'movie_id': 335983, 'actor_id': 51930, 'order': 56, 'name': 'Wade Williams'},
#  {'movie_id': 335983,
#   'actor_id': 58525,
#   'order': 57,
#   'name': 'Ron Cephas Jones'},
#  {'movie_id': 440471,
#   'actor_id': 16483,
#   'order': 0,
#   'name': 'Sylvester Stallone'},
#  {'movie_id': 440471, 'actor_id': 543530, 'order': 1, 'name': 'Dave Bautista'},
#  {'movie_id': 440471,
#   'actor_id': 109434,
#   'order': 2,
#   'name': 'Huang xiaoming'},
#  {'movie_id': 440471, 'actor_id': 57171, 'order': 3, 'name': 'Jesse Metcalfe'},
#  {'movie_id': 440471, 'actor_id': 62644, 'order': 4, 'name': '50 Cent'},
#  {'movie_id': 440471, 'actor_id': 51682, 'order': 5, 'name': 'Wes Chatham'},
#  {'movie_id': 440471, 'actor_id': 139440, 'order': 6, 'name': 'Tyron Woodley'},
#  {'movie_id': 440471,
#   'actor_id': 1388479,
#   'order': 7,
#   'name': 'Tyler Jon Olson'},
#  {'movie_id': 440471, 'actor_id': 39389, 'order': 8, 'name': 'Titus Welliver'},
#  {'movie_id': 440471, 'actor_id': 1795898, 'order': 9, 'name': 'Shea Buckner'},
#  {'movie_id': 440471, 'actor_id': 5915, 'order': 10, 'name': 'Jaime King'},
#  {'movie_id': 440471, 'actor_id': 1042684, 'order': 11, 'name': 'Lydia Hull'},
#  {'movie_id': 440471,
#   'actor_id': 158155,
#   'order': 12,
#   'name': 'Ashley Cusato'},
#  {'movie_id': 440471,
#   'actor_id': 1826044,
#   'order': 13,
#   'name': 'Corey Winston'},
#  {'movie_id': 440471,
#   'actor_id': 1664061,
#   'order': 14,
#   'name': 'Rowan Bousaid'},
#  {'movie_id': 440471,
#   'actor_id': 1199421,
#   'order': 15,
#   'name': 'Baylee Curran'},
#  {'movie_id': 440471, 'actor_id': 1370998, 'order': 16, 'name': 'Zeeko Zaki'},
#  {'movie_id': 440471,
#   'actor_id': 180150,
#   'order': 17,
#   'name': 'Vincent Young'},
#  {'movie_id': 440471, 'actor_id': 1375305, 'order': 18, 'name': 'Jamie Eddy'},
#  {'movie_id': 440471,
#   'actor_id': 1704007,
#   'order': 19,
#   'name': 'Perry Johnson'},
#  {'movie_id': 440471,
#   'actor_id': 1826045,
#   'order': 20,
#   'name': 'Aurora Karine'},
#  {'movie_id': 440471, 'actor_id': 52905, 'order': 21, 'name': 'Mike Leeder'},
#  {'movie_id': 440471,
#   'actor_id': 1826046,
#   'order': 22,
#   'name': 'Joseph Blake Menzel'},
#  {'movie_id': 440471,
#   'actor_id': 74595,
#   'order': 23,
#   'name': 'Gordon Michaels'},
#  {'movie_id': 440471,
#   'actor_id': 552293,
#   'order': 24,
#   'name': 'Timothy T. Miller'},
#  {'movie_id': 440471,
#   'actor_id': 204650,
#   'order': 25,
#   'name': 'Roman Mitichyan'},
#  {'movie_id': 440471,
#   'actor_id': 1826047,
#   'order': 26,
#   'name': 'Eric Bendross'},
#  {'movie_id': 440471,
#   'actor_id': 1826048,
#   'order': 27,
#   'name': 'David Dunston'},
#  {'movie_id': 338952, 'actor_id': 37632, 'order': 0, 'name': 'Eddie Redmayne'},
#  {'movie_id': 338952,
#   'actor_id': 77795,
#   'order': 1,
#   'name': 'Katherine Waterston'},
#  {'movie_id': 338952, 'actor_id': 998225, 'order': 2, 'name': 'Alison Sudol'},
#  {'movie_id': 338952, 'actor_id': 85, 'order': 3, 'name': 'Johnny Depp'},
#  {'movie_id': 338952, 'actor_id': 9642, 'order': 4, 'name': 'Jude Law'},
#  {'movie_id': 338952, 'actor_id': 58873, 'order': 5, 'name': 'Dan Fogler'},
#  {'movie_id': 338952, 'actor_id': 132157, 'order': 6, 'name': 'Ezra Miller'},
#  {'movie_id': 338952, 'actor_id': 37153, 'order': 7, 'name': 'Zoë Kravitz'},
#  {'movie_id': 338952,
#   'actor_id': 1371041,
#   'order': 8,
#   'name': 'Callum Turner'},
#  {'movie_id': 338952, 'actor_id': 1401531, 'order': 9, 'name': 'Claudia Kim'},
#  {'movie_id': 338952, 'actor_id': 37158, 'order': 10, 'name': 'Carmen Ejogo'},
#  {'movie_id': 338952,
#   'actor_id': 1394648,
#   'order': 11,
#   'name': 'Jessica Williams'},
#  {'movie_id': 338952,
#   'actor_id': 87426,
#   'order': 12,
#   'name': 'William Nadylam'},
#  {'movie_id': 338952,
#   'actor_id': 55584,
#   'order': 13,
#   'name': 'Ingvar Eggert Sigurðsson'},
#  {'movie_id': 338952,
#   'actor_id': 110902,
#   'order': 14,
#   'name': 'Ólafur Darri Ólafsson'},
#  {'movie_id': 338952,
#   'actor_id': 1204379,
#   'order': 15,
#   'name': 'Kevin Guthrie'},
#  {'movie_id': 338952,
#   'actor_id': 85148,
#   'order': 16,
#   'name': 'Brontis Jodorowsky'},
#  {'movie_id': 338952,
#   'actor_id': 143971,
#   'order': 17,
#   'name': 'Derek Riddell'},
#  {'movie_id': 338952,
#   'actor_id': 1180795,
#   'order': 18,
#   'name': 'David Sakurai'},
#  {'movie_id': 338952,
#   'actor_id': 43135,
#   'order': 19,
#   'name': 'Fiona Glascott'},
#  {'movie_id': 338952, 'actor_id': 26396, 'order': 20, 'name': 'Wolf Roth'},
#  {'movie_id': 338952,
#   'actor_id': 1901525,
#   'order': 21,
#   'name': 'Victoria Yeates'},
#  {'movie_id': 338952,
#   'actor_id': 1383392,
#   'order': 22,
#   'name': 'Poppy Corby-Tuech'},
#  {'movie_id': 338952, 'actor_id': 25135, 'order': 23, 'name': 'Cornell John'},
#  {'movie_id': 338952,
#   'actor_id': 1193021,
#   'order': 24,
#   'name': 'Sabine Crossen'},
#  {'movie_id': 338952,
#   'actor_id': 1395427,
#   'order': 25,
#   'name': 'Claudius Peters'},
#  {'movie_id': 338952,
#   'actor_id': 2243650,
#   'order': 26,
#   'name': 'Bart Soroczynski'},
#  {'movie_id': 338952,
#   'actor_id': 2243660,
#   'order': 27,
#   'name': 'Danielle Hugues'},
#  {'movie_id': 338952,
#   'actor_id': 1791620,
#   'order': 28,
#   'name': 'Alfie Simmons'},
#  {'movie_id': 338952,
#   'actor_id': 2243662,
#   'order': 29,
#   'name': 'Isaac Cortinovis Johnson'},
#  {'movie_id': 338952,
#   'actor_id': 1347006,
#   'order': 30,
#   'name': 'Olivia Popica'},
#  {'movie_id': 338952,
#   'actor_id': 2243659,
#   'order': 31,
#   'name': 'Alfie Mailley'},
#  {'movie_id': 338952, 'actor_id': 1997433, 'order': 32, 'name': 'Simon Wan'},
#  {'movie_id': 338952,
#   'actor_id': 1457380,
#   'order': 33,
#   'name': 'Morrison Thomas'},
#  {'movie_id': 338952,
#   'actor_id': 219600,
#   'order': 34,
#   'name': 'Andrew Turner'},
#  {'movie_id': 338952,
#   'actor_id': 1223228,
#   'order': 35,
#   'name': 'Linda Santiago'},
#  {'movie_id': 338952, 'actor_id': 1765394, 'order': 36, 'name': 'Alfrun Rose'},
#  {'movie_id': 338952, 'actor_id': 1997442, 'order': 37, 'name': 'Maja Bloom'},
#  {'movie_id': 338952, 'actor_id': 933272, 'order': 38, 'name': 'Olwen Fouéré'},
#  {'movie_id': 338952,
#   'actor_id': 1017597,
#   'order': 39,
#   'name': 'Simon Meacock'},
#  {'movie_id': 338952, 'actor_id': 73287, 'order': 40, 'name': 'David Wilmot'},
#  {'movie_id': 338952, 'actor_id': 147797, 'order': 41, 'name': 'Ed Gaughan'},
# ...
#  {'movie_id': 351286, 'actor_id': 14592, 'order': 9, 'name': 'BD Wong'},
#  {'movie_id': 351286,
#   'actor_id': 400,
#   'order': 10,
#   'name': 'Geraldine Chaplin'},
#  {'movie_id': 351286,
#   'actor_id': 2058708,
#   'order': 11,
#   'name': 'Isabella Sermon'},
#  {'movie_id': 351286, 'actor_id': 6916, 'order': 12, 'name': 'Peter Jason'},
#  {'movie_id': 351286,
#   'actor_id': 1083177,
#   'order': 13,
#   'name': 'Charlie Rawes'},
#  {'movie_id': 351286, 'actor_id': 2093764, 'order': 14, 'name': 'Kevin Layne'},
#  {'movie_id': 351286, 'actor_id': 589652, 'order': 15, 'name': 'Robert Emms'},
#  {'movie_id': 351286, 'actor_id': 207304, 'order': 16, 'name': 'John Schwab'},
#  {'movie_id': 351286, 'actor_id': 55586, 'order': 17, 'name': 'Sam Redford'},
#  {'movie_id': 351286,
#   'actor_id': 25600,
#   'order': 18,
#   'name': 'Patrick Crowley'},
#  {'movie_id': 351286, 'actor_id': 2125910, 'order': 19, 'name': 'Alex Dower'},
#  {'movie_id': 351286,
#   'actor_id': 1358942,
#   'order': 20,
#   'name': 'Honey Holmes'},
#  {'movie_id': 351286, 'actor_id': 1792454, 'order': 21, 'name': 'Neil Bishop'},
#  {'movie_id': 351286,
#   'actor_id': 2125921,
#   'order': 22,
#   'name': 'Philippa Thomas'},
#  {'movie_id': 351286,
#   'actor_id': 1132153,
#   'order': 23,
#   'name': 'Ronan Summers'},
#  {'movie_id': 351286,
#   'actor_id': 232979,
#   'order': 24,
#   'name': 'Cory Peterson'},
#  {'movie_id': 351286,
#   'actor_id': 2125928,
#   'order': 25,
#   'name': 'Jeremy Gilbert'},
#  {'movie_id': 351286,
#   'actor_id': 1563380,
#   'order': 26,
#   'name': 'Victor Gardener'},
#  {'movie_id': 351286,
#   'actor_id': 1184960,
#   'order': 27,
#   'name': 'Eric Kofi Abrefa'},
#  {'movie_id': 351286, 'actor_id': 1205630, 'order': 28, 'name': 'Ben Peel'},
#  {'movie_id': 351286, 'actor_id': 123796, 'order': 29, 'name': 'Gil Kolirin'},
#  {'movie_id': 351286,
#   'actor_id': 2015334,
#   'order': 30,
#   'name': 'Mitchell L. Johnson'},
#  {'movie_id': 351286,
#   'actor_id': 2060733,
#   'order': 31,
#   'name': 'Paul Sockett'},
#  {'movie_id': 351286, 'actor_id': 2067775, 'order': 32, 'name': 'Daryl Kwan'},
#  {'movie_id': 351286,
#   'actor_id': 20582,
#   'order': 33,
#   'name': 'Michael Papajohn'},
#  {'movie_id': 351286,
#   'actor_id': 1481440,
#   'order': 34,
#   'name': 'Daniel Stisen'},
#  {'movie_id': 351286,
#   'actor_id': 1933302,
#   'order': 35,
#   'name': 'Ian Copley-Johnson'},
#  {'movie_id': 260513, 'actor_id': 8977, 'order': 0, 'name': 'Craig T. Nelson'},
#  {'movie_id': 260513, 'actor_id': 18686, 'order': 1, 'name': 'Holly Hunter'},
#  {'movie_id': 260513, 'actor_id': 59361, 'order': 2, 'name': 'Sarah Vowell'},
#  {'movie_id': 260513, 'actor_id': 59358, 'order': 3, 'name': 'Eli Fucile'},
#  {'movie_id': 260513, 'actor_id': 1852182, 'order': 4, 'name': 'Huck Milner'},
#  {'movie_id': 260513, 'actor_id': 981048, 'order': 5, 'name': 'Nicholas Bird'},
#  {'movie_id': 260513,
#   'actor_id': 2231,
#   'order': 6,
#   'name': 'Samuel L. Jackson'},
#  {'movie_id': 260513, 'actor_id': 59410, 'order': 7, 'name': 'Bob Odenkirk'},
#  {'movie_id': 260513,
#   'actor_id': 2229,
#   'order': 8,
#   'name': 'Catherine Keener'},
#  {'movie_id': 260513, 'actor_id': 7087, 'order': 9, 'name': 'Brad Bird'},
#  {'movie_id': 260513, 'actor_id': 783, 'order': 10, 'name': 'Jonathan Banks'},
#  {'movie_id': 260513,
#   'actor_id': 1075148,
#   'order': 11,
#   'name': 'Michael Bird'},
#  {'movie_id': 260513, 'actor_id': 54830, 'order': 12, 'name': 'Sophia Bush'},
#  {'movie_id': 260513, 'actor_id': 31549, 'order': 13, 'name': 'Phil LaMarr'},
#  {'movie_id': 260513, 'actor_id': 86006, 'order': 14, 'name': 'Paul Eiding'},
#  {'movie_id': 260513,
#   'actor_id': 6588,
#   'order': 15,
#   'name': 'Isabella Rossellini'},
#  {'movie_id': 260513,
#   'actor_id': 7907,
#   'order': 16,
#   'name': 'John Ratzenberger'},
#  {'movie_id': 260513, 'actor_id': 2064907, 'order': 17, 'name': 'Bill Wise'},
#  {'movie_id': 260513,
#   'actor_id': 13473,
#   'order': 18,
#   'name': 'Barry Bostwick'},
#  {'movie_id': 260513, 'actor_id': 57167, 'order': 19, 'name': 'Jere Burns'},
#  {'movie_id': 260513,
#   'actor_id': 49706,
#   'order': 20,
#   'name': 'Adam Rodríguez'},
#  {'movie_id': 260513,
#   'actor_id': 1338319,
#   'order': 21,
#   'name': 'Kimberly Adair Clark'},
#  {'movie_id': 260513, 'actor_id': 57108, 'order': 22, 'name': 'Usher'},
#  {'movie_id': 260513, 'actor_id': 2096193, 'order': 23, 'name': 'Adam Gates'},
#  {'movie_id': 260513,
#   'actor_id': 61010,
#   'order': 24,
#   'name': 'LaTanya Richardson Jackson'},
#  {'movie_id': 260513,
#   'actor_id': 1994376,
#   'order': 28,
#   'name': 'Michael B. Johnson'},
#  {'movie_id': 399402, 'actor_id': 17276, 'order': 0, 'name': 'Gerard Butler'},
#  {'movie_id': 399402, 'actor_id': 64, 'order': 1, 'name': 'Gary Oldman'},
#  {'movie_id': 399402, 'actor_id': 10881, 'order': 2, 'name': 'Toby Stephens'},
#  {'movie_id': 399402, 'actor_id': 4238, 'order': 3, 'name': 'Common'},
#  {'movie_id': 399402,
#   'actor_id': 1817,
#   'order': 4,
#   'name': 'Linda Cardellini'},
#  {'movie_id': 399402, 'actor_id': 55411, 'order': 5, 'name': 'David Gyasi'},
#  {'movie_id': 399402,
#   'actor_id': 35231,
#   'order': 6,
#   'name': 'Gabriel Chavarria'},
#  {'movie_id': 399402, 'actor_id': 93031, 'order': 7, 'name': 'Ryan McPartlin'},
#  {'movie_id': 399402,
#   'actor_id': 205149,
#   'order': 8,
#   'name': 'Carter MacIntyre'},
#  {'movie_id': 399402, 'actor_id': 987572, 'order': 9, 'name': 'Zane Holtz'},
#  {'movie_id': 399402,
#   'actor_id': 1369329,
#   'order': 10,
#   'name': 'Taylor John Smith'},
#  {'movie_id': 399402,
#   'actor_id': 83456,
#   'order': 11,
#   'name': 'Michael Trucco'},
#  {'movie_id': 399402,
#   'actor_id': 115876,
#   'order': 12,
#   'name': 'Mikhail Gorevoy'},
#  {'movie_id': 399402,
#   'actor_id': 86949,
#   'order': 13,
#   'name': 'Aleksandr Dyachenko'},
#  {'movie_id': 399402, 'actor_id': 52761, 'order': 14, 'name': 'Igor Jijikine'},
#  {'movie_id': 399402,
#   'actor_id': 238130,
#   'order': 15,
#   'name': 'Yuri Kolokolnikov'},
#  {'movie_id': 399402, 'actor_id': 109667, 'order': 16, 'name': 'Ilia Volok'},
#  {'movie_id': 399402,
#   'actor_id': 6692,
#   'order': 17,
#   'name': 'Caroline Goodall'},
#  {'movie_id': 399402, 'actor_id': 17199, 'order': 18, 'name': 'Corey Johnson'},
#  {'movie_id': 399402, 'actor_id': 47933, 'order': 19, 'name': 'Adam James'},
#  {'movie_id': 399402,
#   'actor_id': 1461462,
#   'order': 20,
#   'name': 'Will Attenborough'},
#  {'movie_id': 399402,
#   'actor_id': 1665012,
#   'order': 21,
#   'name': 'Sarah Middleton'},
#  {'movie_id': 399402,
#   'actor_id': 1184331,
#   'order': 22,
#   'name': 'Christopher Goh'},
#  {'movie_id': 399402, 'actor_id': 126429, 'order': 23, 'name': 'Shane Taylor'},
#  {'movie_id': 399402, 'actor_id': 7030, 'order': 24, 'name': 'Henry Goodman'},
#  {'movie_id': 399402, 'actor_id': 23608, 'order': 25, 'name': 'Colin Stinton'},
#  {'movie_id': 399402,
#   'actor_id': 2112441,
#   'order': 26,
#   'name': 'Kieron Bimpson'},
#  {'movie_id': 399402,
#   'actor_id': 1451061,
#   'order': 27,
#   'name': 'Mickey Collins'},
#  {'movie_id': 399402,
#   'actor_id': 6283,
#   'order': 28,
#   'name': 'Michael Nyqvist'},
#  {'movie_id': 332562, 'actor_id': 237405, 'order': 0, 'name': 'Lady Gaga'},
#  {'movie_id': 332562, 'actor_id': 51329, 'order': 1, 'name': 'Bradley Cooper'},
#  {'movie_id': 332562, 'actor_id': 16431, 'order': 2, 'name': 'Sam Elliott'},
#  {'movie_id': 332562,
#   'actor_id': 57906,
#   'order': 3,
#   'name': 'Andrew Dice Clay'},
#  {'movie_id': 332562, 'actor_id': 21660, 'order': 4, 'name': 'Rafi Gavron'},
#  {'movie_id': 332562,
#   'actor_id': 1560244,
#   'order': 5,
#   'name': 'Anthony Ramos'},
#  {'movie_id': 332562, 'actor_id': 4169, 'order': 6, 'name': 'Dave Chappelle'},
#  {'movie_id': 332562,
#   'actor_id': 930961,
#   'order': 8,
#   'name': 'Marlon Williams'},
#  {'movie_id': 332562,
#   'actor_id': 1395597,
#   'order': 9,
#   'name': 'Brandi Carlile'},
#  {'movie_id': 332562, 'actor_id': 12122, 'order': 10, 'name': 'Ron Rifkin'},
#  {'movie_id': 332562,
#   'actor_id': 8689,
#   'order': 11,
#   'name': 'Barry Shabaka Henley'},
#  {'movie_id': 332562,
#   'actor_id': 5146,
#   'order': 12,
#   'name': 'Michael D. Roberts'},
#  {'movie_id': 332562,
#   'actor_id': 1214447,
#   'order': 13,
#   'name': 'Michael Harney'},
#  {'movie_id': 332562,
#   'actor_id': 1214576,
#   'order': 14,
#   'name': 'Rebecca Field'},
#  {'movie_id': 332562, 'actor_id': 170432, 'order': 15, 'name': 'Willam Belli'},
#  {'movie_id': 332562, 'actor_id': 17305, 'order': 16, 'name': 'Greg Grunberg'},
#  {'movie_id': 332562,
#   'actor_id': 1029622,
#   'order': 17,
#   'name': 'D.J. "Shangela" Pierce'},
#  {'movie_id': 332562, 'actor_id': 62842, 'order': 18, 'name': 'Eddie Griffin'},
#  {'movie_id': 332562, 'actor_id': 93015, 'order': 19, 'name': 'Drena De Niro'},
#  {'movie_id': 332562,
#   'actor_id': 1530563,
#   'order': 20,
#   'name': 'Jacob Schick'},
#  {'movie_id': 332562, 'actor_id': 1129833, 'order': 21, 'name': 'Gabe Fazio'},
#  {'movie_id': 332562, 'actor_id': 6735, 'order': 22, 'name': 'Luenell'},
#  {'movie_id': 332562,
#   'actor_id': 1453337,
#   'order': 23,
#   'name': 'Lukas Nelson'},
#  {'movie_id': 332562,
#   'actor_id': 2195797,
#   'order': 24,
#   'name': 'Anthony LoGerfo'},
#  {'movie_id': 332562,
#   'actor_id': 1970358,
#   'order': 25,
#   'name': 'Corey McCormick'},
#  {'movie_id': 332562, 'actor_id': 2195798, 'order': 26, 'name': 'Logan Metz'},
#  {'movie_id': 332562, 'actor_id': 2195799, 'order': 27, 'name': 'Tato Melgar'},
#  {'movie_id': 332562, 'actor_id': 217361, 'order': 28, 'name': 'Don Roy King'},
#  {'movie_id': 332562, 'actor_id': 1997030, 'order': 29, 'name': 'Halsey'},
#  {'movie_id': 332562, 'actor_id': 7447, 'order': 30, 'name': 'Alec Baldwin'},
#  {'movie_id': 353081, 'actor_id': 500, 'order': 0, 'name': 'Tom Cruise'},
#  {'movie_id': 353081, 'actor_id': 73968, 'order': 1, 'name': 'Henry Cavill'},
#  {'movie_id': 353081, 'actor_id': 10182, 'order': 2, 'name': 'Ving Rhames'},
#  {'movie_id': 353081, 'actor_id': 11108, 'order': 3, 'name': 'Simon Pegg'},
#  {'movie_id': 353081,
#   'actor_id': 933238,
#   'order': 4,
#   'name': 'Rebecca Ferguson'},
#  {'movie_id': 353081, 'actor_id': 16702, 'order': 5, 'name': 'Sean Harris'},
#  {'movie_id': 353081, 'actor_id': 9780, 'order': 6, 'name': 'Angela Bassett'},
#  {'movie_id': 353081, 'actor_id': 556356, 'order': 7, 'name': 'Vanessa Kirby'},
#  {'movie_id': 353081,
#   'actor_id': 11705,
#   'order': 8,
#   'name': 'Michelle Monaghan'},
#  {'movie_id': 353081, 'actor_id': 8210, 'order': 9, 'name': 'Wes Bentley'},
#  {'movie_id': 353081,
#   'actor_id': 1312122,
#   'order': 10,
#   'name': 'Frederick Schmidt'},
#  {'movie_id': 353081, 'actor_id': 7447, 'order': 11, 'name': 'Alec Baldwin'},
#  {'movie_id': 353081, 'actor_id': 1645047, 'order': 12, 'name': 'Liang Yang'},
#  {'movie_id': 353081,
#   'actor_id': 7742,
#   'order': 13,
#   'name': 'Kristoffer Joner'},
#  {'movie_id': 353081,
#   'actor_id': 1224993,
#   'order': 14,
#   'name': 'Wolf Blitzer'},
#  {'movie_id': 353081, 'actor_id': 1980397, 'order': 15, 'name': 'Dean Ashton'},
#  {'movie_id': 353081,
#   'actor_id': 1126301,
#   'order': 16,
#   'name': 'Alix Bénézech'},
#  {'movie_id': 353081, 'actor_id': 29406, 'order': 17, 'name': 'Joey Ansah'},
#  {'movie_id': 353081, 'actor_id': 34515, 'order': 18, 'name': 'Velibor Topic'},
#  {'movie_id': 353081,
#   'actor_id': 2089917,
#   'order': 19,
#   'name': 'Alexandre Poole'},
#  {'movie_id': 353081,
#   'actor_id': 2089912,
#   'order': 20,
#   'name': 'Andrew Cazanave Pin'},
#  {'movie_id': 353081,
#   'actor_id': 2089913,
#   'order': 21,
#   'name': 'Christophe de Choisy'},
#  {'movie_id': 353081, 'actor_id': 2089918, 'order': 22, 'name': 'Guy Remy'},
#  {'movie_id': 353081,
#   'actor_id': 1692241,
#   'order': 23,
#   'name': 'Jean Baptiste Fillon'},
#  {'movie_id': 353081,
#   'actor_id': 49163,
#   'order': 24,
#   'name': 'Maximilian Geller'},
#  {'movie_id': 353081,
#   'actor_id': 2089914,
#   'order': 25,
#   'name': 'Olivier Huband'},
#  {'movie_id': 353081,
#   'actor_id': 1651413,
#   'order': 26,
#   'name': 'Raphael Desprez'},
#  {'movie_id': 353081,
#   'actor_id': 2089911,
#   'order': 27,
#   'name': 'Raphael Joner'},
#  {'movie_id': 353081,
#   'actor_id': 2089916,
#   'order': 28,
#   'name': 'Thierry Picaut'},
#  {'movie_id': 353081,
#   'actor_id': 1698108,
#   'order': 29,
#   'name': 'Vincent Latorre'},
#  {'movie_id': 353081,
#   'actor_id': 1858373,
#   'order': 30,
#   'name': 'Harvey Djent'},
#  {'movie_id': 353081, 'actor_id': 662006, 'order': 31, 'name': 'Grahame Fox'},
#  {'movie_id': 353081,
#   'actor_id': 1619648,
#   'order': 32,
#   'name': 'David Mumeni'},
#  {'movie_id': 353081,
#   'actor_id': 1808581,
#   'order': 33,
#   'name': 'Charlie Archer'},
#  {'movie_id': 353081,
#   'actor_id': 1441919,
#   'order': 34,
#   'name': 'Caspar Phillipson'},
#  {'movie_id': 353081, 'actor_id': 1769602, 'order': 35, 'name': 'Ffion Jolly'},
#  {'movie_id': 353081,
#   'actor_id': 1627501,
#   'order': 36,
#   'name': 'Lolly Adefope'},
#  {'movie_id': 353081,
#   'actor_id': 1717916,
#   'order': 37,
#   'name': "Ross O'Hennessy"},
#  {'movie_id': 353081, 'actor_id': 1304469, 'order': 38, 'name': 'Russ Bain'},
#  {'movie_id': 353081, 'actor_id': 1303330, 'order': 39, 'name': 'Nigel Allen'},
#  {'movie_id': 353081,
#   'actor_id': 2089919,
#   'order': 40,
#   'name': 'Tracey Saunders'},
#  {'movie_id': 353081,
#   'actor_id': 2089920,
#   'order': 41,
#   'name': 'Alicia Mencía Castaño'},
#  {'movie_id': 353081, 'actor_id': 1917316, 'order': 42, 'name': 'Conny Sharp'},
#  {'movie_id': 353081,
#   'actor_id': 2060814,
#   'order': 43,
#   'name': 'Jessie Vinning'},
#  {'movie_id': 353081,
#   'actor_id': 139635,
#   'order': 44,
#   'name': 'Stuart Davidson'},
#  {'movie_id': 353081,
#   'actor_id': 2000489,
#   'order': 45,
#   'name': 'Julianne Binard'},
#  {'movie_id': 353081,
#   'actor_id': 1655621,
#   'order': 46,
#   'name': 'Bernardo Santos'},
#  {'movie_id': 353081,
#   'actor_id': 1752964,
#   'order': 47,
#   'name': 'Lampros Kalfuntzos'},
#  {'movie_id': 375588,
#   'actor_id': 1303037,
#   'order': 0,
#   'name': 'Taron Egerton'},
#  {'movie_id': 375588, 'actor_id': 134, 'order': 1, 'name': 'Jamie Foxx'},
#  {'movie_id': 375588, 'actor_id': 77335, 'order': 2, 'name': 'Ben Mendelsohn'},
#  {'movie_id': 375588, 'actor_id': 933271, 'order': 3, 'name': 'Eve Hewson'},
#  {'movie_id': 375588, 'actor_id': 1254583, 'order': 4, 'name': 'Jamie Dornan'},
#  {'movie_id': 375588, 'actor_id': 89564, 'order': 5, 'name': 'Tim Minchin'},
#  {'movie_id': 375588, 'actor_id': 220448, 'order': 6, 'name': 'Paul Anderson'},
#  {'movie_id': 375588,
#   'actor_id': 1105957,
#   'order': 7,
#   'name': 'Roderick Hill'},
#  {'movie_id': 375588,
#   'actor_id': 1164,
#   'order': 8,
#   'name': 'F. Murray Abraham'},
#  {'movie_id': 375588, 'actor_id': 208467, 'order': 9, 'name': 'Ian Peck'},
#  {'movie_id': 375588,
#   'actor_id': 956903,
#   'order': 10,
#   'name': 'Cornelius Booth'},
#  {'movie_id': 375588,
#   'actor_id': 2237032,
#   'order': 11,
#   'name': 'Kane Headley-Cummings'},
#  {'movie_id': 375588,
#   'actor_id': 1757668,
#   'order': 12,
#   'name': 'Scot Greenan'},
#  {'movie_id': 375588, 'actor_id': 1404497, 'order': 13, 'name': 'Lara Rossi'},
#  {'movie_id': 375588,
#   'actor_id': 2237040,
#   'order': 14,
#   'name': 'Kevin Griffiths'},
#  {'movie_id': 375588,
#   'actor_id': 2237043,
#   'order': 15,
#   'name': 'Catriona Temple'},
#  {'movie_id': 375588,
#   'actor_id': 79257,
#   'order': 16,
#   'name': 'Björn Bengtsson'},
#  {'movie_id': 375588, 'actor_id': 2141502, 'order': 17, 'name': 'Rxchie'},
#  {'movie_id': 375588, 'actor_id': 25445, 'order': 18, 'name': 'Matt Devere'},
#  {'movie_id': 375588,
#   'actor_id': 1700678,
#   'order': 19,
#   'name': 'Nicholas Wittman'},
#  {'movie_id': 375588, 'actor_id': 1562107, 'order': 20, 'name': 'Yasen Atour'},
#  {'movie_id': 375588, 'actor_id': 11212, 'order': 21, 'name': 'Josh Herdman'},
#  {'movie_id': 375588,
#   'actor_id': 126175,
#   'order': 22,
#   'name': 'Jerome Holder'},
#  {'movie_id': 375588, 'actor_id': 1606756, 'order': 23, 'name': 'Kembe Sorel'},
#  {'movie_id': 375588,
#   'actor_id': 2237047,
#   'order': 24,
#   'name': 'Jonathan Peck'},
#  {'movie_id': 375588, 'actor_id': 76475, 'order': 25, 'name': 'László Áron'},
#  {'movie_id': 375588,
#   'actor_id': 1508585,
#   'order': 26,
#   'name': 'Declan Hannigan'},
#  {'movie_id': 375588,
#   'actor_id': 2237053,
#   'order': 27,
#   'name': 'Antonio Lujak'},
#  {'movie_id': 375588,
#   'actor_id': 2237087,
#   'order': 28,
#   'name': 'Andrea Mladinic'},
#  {'movie_id': 375588,
#   'actor_id': 1303102,
#   'order': 29,
#   'name': 'Frane Perišin'}]

# %%
import pandas as pd
import mysql.connector
import config
cnx = mysql.connector.connect(
    host = config.host,
    user = config.user,
    password = config.password,
    database = config.database)
c = cnx.cursor()

# %%
q = """CREATE TABLE movie_actors (
       id int(7),
       actor VARCHAR(255),
       PRIMARY KEY (id, actor)
     ) ENGINE=InnoDB"""
c.execute(q)
cnx.commit()
# Out:
# ---------------------------------------------------------------------------
# MySQLInterfaceError                       Traceback (most recent call last)
# ~/anaconda3/lib/python3.7/site-packages/mysql/connector/connection_cext.py in cmd_query(self, query, raw, buffered, raw_as_string)
#     471                                raw=raw, buffered=buffered,
# --> 472                                raw_as_string=raw_as_string)
#     473         except MySQLInterfaceError as exc:
#
# MySQLInterfaceError: Table 'movie_actors' already exists
#
# During handling of the above exception, another exception occurred:
#
# ProgrammingError                          Traceback (most recent call last)
# <ipython-input-7-19f4b17b68b3> in <module>
#       4        PRIMARY KEY (id, actor)
#       5      ) ENGINE=InnoDB"""
# ----> 6 c.execute(q)
#       7 cnx.commit()
#
# ~/anaconda3/lib/python3.7/site-packages/mysql/connector/cursor_cext.py in execute(self, operation, params, multi)
#     264             result = self._cnx.cmd_query(stmt, raw=self._raw,
#     265                                          buffered=self._buffered,
# --> 266                                          raw_as_string=self._raw_as_string)
#     267         except MySQLInterfaceError as exc:
#     268             raise errors.get_mysql_exception(msg=exc.msg, errno=exc.errno,
#
# ~/anaconda3/lib/python3.7/site-packages/mysql/connector/connection_cext.py in cmd_query(self, query, raw, buffered, raw_as_string)
#     473         except MySQLInterfaceError as exc:
#     474             raise errors.get_mysql_exception(exc.errno, msg=exc.msg,
# --> 475                                              sqlstate=exc.sqlstate)
#     476         except AttributeError:
#     477             if self._unix_socket:
#
# ProgrammingError: 1050 (42S01): Table 'movie_actors' already exists

# %%
def actor_movie_formatting(details):
    formatted_actor_movies = []
    for actor_movie in details:
        actor_movie_tuple = (actor_movie['movie_id'], actor_movie['name'])
        formatted_actor_movies.append(actor_movie_tuple)
    return formatted_actor_movies

# %%
def add_to_db_actor_movie(actor_movie_list):
    cnx = mysql.connector.connect(
    host = config.host,
    user = config.user,
    password = config.password,
    database = config.database)
    c = cnx.cursor()    
    stmt = """INSERT INTO movie_actors (id, actor) VALUES (%s, %s)"""
    c.executemany(stmt, actor_movie_list)
    cnx.commit()
    c.close()
    cnx.close()

# %%
add_to_db_actor_movie(actor_movie_formatting(movie_actors))

# %%
from bs4 import BeautifulSoup
import config
import requests
import json

# %%
response = requests.get('https://ethnicelebs.com/charlie-sheen')
soup = BeautifulSoup(response.content, 'html.parser')

# %%
inner = soup.find('div', class_='entry-inner')

# %%
inner.select("strong")[0].text.replace('Ethnicity: ', '').split(',')
# Out:
# ['Galician Spanish (paternal grandfather)',
#  ' Irish',
#  ' English',
#  ' Scottish',
#  ' possibly other']

# %%
import pandas as pd
import mysql.connector
import config
cnx = mysql.connector.connect(
    host = config.host,
    user = config.user,
    password = config.password,
    database = config.database)
c = cnx.cursor()
q = """SELECT actor FROM movie_actors WHERE id IN(SELECT id from details WHERE language='en' AND production_country='US' AND revenue > 0 AND budget >0);"""
c.execute(q)
list_of_actors = c.fetchall()

# %%
len(list_of_actors)
# Out:
# 6137

# %%
new_list_of_actors = list(set(list_of_actors))

# %%
len(new_list_of_actors)
# Out:
# 2661

# %%
missing_actors = []
actor_ethnicities = []

# %%
import pandas as pd
import mysql.connector
import config
cnx = mysql.connector.connect(
    host = config.host,
    user = config.user,
    password = config.password,
    database = config.database)
c = cnx.cursor()

# %%
q = """CREATE TABLE actors (
       name VARCHAR(255),
       ethnicity VARCHAR(255)
     ) ENGINE=InnoDB"""
# q = """DROP TABLE actors"""
c.execute(q)
cnx.commit()

# %%
        actor_ethnicity_dict = {}
        soup = BeautifulSoup(response.content, 'html.parser')
        inner = soup.find('strong')
        ethnicities_list = inner.select("strong")[0].text.replace('Ethnicity: ', '').split(',')
        actor_ethnicity_dict[actor[0]] = ethnicities_list
        actor_ethnicities.append(actor_ethnicity_dict)
        print(actor_ethnicity_dict)
        print(n)

# %%
len(missing_actors)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-ff6d83b19498> in <module>
# ----> 1 len(missing_actors)
#
# NameError: name 'missing_actors' is not defined

# %%
missing_actors = []

# %%
actor_ethnicities = []
for n, actor in enumerate(new_list_of_actors[2300:2661]):
#     print('https://ethnicelebs.com/' + actor[0].lower().replace(' ', '-'))
    
    response = requests.get('https://ethnicelebs.com/' + actor[0].lower().replace(' ', '-'))
    if response.status_code != 200:
        missing_actors.append(actor[0].lower().replace(' ', '-'))
        print(actor[0].lower().replace(' ', '-'))
    else:
        actor_ethnicity_dict = {}
        soup = BeautifulSoup(response.content, 'html.parser')
        inner = soup.find('strong')
        inner = inner.text.replace('Ethnicity:\n*', '')
        inner = inner.replace('Ethnicity:', '')
        inner = inner.replace('\n*', ', ')
        print(inner)
#         inner = inner.replace('possibly other', '')
#         inner = inner.replace('possibly ', '')
        inner = inner.replace('or ', ',')
        inner = inner.replace(' (father)', '')
        inner = inner.replace(' (mother)', '')
        inner = inner.replace(' (paternal grandfather)', '')
        inner = inner.replace('paternal grandfather', '')
        inner = inner.replace('maternal grandfather', '')
        inner = inner.replace('maternal grandmother', '')
        inner = inner.replace('paternal grandmother', '')
        inner = inner.replace('mother – ', '')
        inner = inner.replace('father – ', '')
        inner = inner.replace('with smaller amounts of ', '')
        inner = inner.replace('some ', '')
        inner = inner.replace('as well as remote ', '')
        inner = inner.replace('along with remote ', '')
        inner = inner.replace(' remote ', '')
        inner = inner.replace('1/4th ', '')
        inner = inner.replace('1/8th ', '')
        inner = inner.replace('1/8 ', '')
        inner = inner.replace('1/512 ', 'distant ')
        inner = inner.replace('1/1024th ', 'distant ')
        inner = inner.replace('one eighth ', '')
        inner = inner.replace('(one eighth)', '')
        inner = inner.replace('1/16th ', '')
        inner = inner.replace('1/16 ', '')
        inner = inner.replace('as well as ', '')
        inner = inner.replace('1/32', '')
        inner = inner.replace('3/16ths', '')
        inner = inner.replace('1/4', '')
        inner = inner.replace('75% ', '')
        inner = inner.replace('25% ', '')
        inner = inner.replace('50% ', '')
        inner = inner.replace('87.5% ', '')
        inner = inner.replace('12.5% ', '')
        inner = inner.replace('1/1024 ', '')
        inner = inner.replace('1/64th', ',')
        inner = inner.replace('1/64', '')
        inner = inner.replace('37.5% ', '')
        inner = inner.replace('62.5% ', '')
        inner = inner.replace('including ', '')
        inner = inner.replace('one fourth ', '')
        inner = inner.replace('(one quarter) ', '')
        inner = inner.replace('(37.5%) ', '')
        inner = inner.replace('and ', ',')
        inner = inner.replace('mix of ', '')
        inner = inner.replace(u'\xa0',u'')
        inner = inner.replace('/', ', ')
        ethnicities_list = inner.split(',')

        actor_ethnicity_dict[actor[0]] = ethnicities_list
        actor_ethnicities.append(actor_ethnicity_dict)
        print(actor_ethnicity_dict)
        print(n)
print(actor_ethnicities)
print(missing_actors)
# Out:
# owen-asztalos
# father – Eastern European Ashkenazi Jewish, mother – Norwegian, as well as English, Scots-Irish/Northern Irish, and German
# {'Ansel Elgort': ['Eastern European Ashkenazi Jewish', ' Norwegian', ' English', ' Scots-Irish', ' Northern Irish', ' ', 'German']}
# 1
# william-demeo
# Argentinian (father), French, Puerto Rican (mother)
# {'Steve Lemme': ['Argentinian', ' French', ' Puerto Rican']}
# 3
# ramón-rodríguez
# English (father), Ashkenazi Jewish (mother)
# {'Bel Powley': ['English', ' Ashkenazi Jewish']}
# 5
# chris-j.-murray
# jaeden-martell
# German (father), Scottish, small amount of Irish (mother)
# {'Christopher Walken': ['German', ' Scottish', ' small amount of Irish']}
# 8
# English, Irish, Scottish, German (father), Ashkenazi Jewish (mother)
# {'Ashley Tisdale': ['English', ' Irish', ' Scottish', ' German', ' Ashkenazi Jewish']}
# 9
# libby-villari
# Māori, some Welsh (father), Danish, French, English (mother)
# {'Rena Owen': ['Māori', ' Welsh', ' Danish', ' French', ' English']}
# 11
#  Scottish
# {'Scott Speedman': [' Scottish']}
# 12
# jenica-bergere
#  English
# {'Stephen Merchant': [' English']}
# 14
# scott-dymond
# maggie-elizabeth-jones
#  Polish
# {'Christine Baranski': [' Polish']}
# 17
#  Luxembourgish, German
# {'Vicky Krieps': [' Luxembourgish', ' German']}
# 18
# 25% Polish, 25% Ashkenazi Jewish, 50% mix of Irish, with some German and English, and remote Welsh
# {'Emily Ratajkowski': ['Polish', ' Ashkenazi Jewish', ' Irish', ' with German ', 'English', ' andWelsh']}
# 19
#  Welsh
# {'Gwilym Lee': [' Welsh']}
# 20
#  German, as well as 1/8th Bohemian (Czech), 1/16th Austrian, English, Scottish
# {'Scott Bakula': [' German', ' Bohemian (Czech)', ' Austrian', ' English', ' Scottish']}
# 21
#  Polish, possibly other
# {'Tom Lipinski': [' Polish', ' possibly other']}
# 22
#  English
# {'Richard Armitage': [' English']}
# 23
# Italian (father), Ashkenazi Jewish (mother)
# {'John Magaro': ['Italian', ' Ashkenazi Jewish']}
# 24
#  Ashkenazi Jewish
# {'Barbra Streisand': [' Ashkenazi Jewish']}
# 25
# zoë-kravitz
# English, some Scots-Irish/Northern Irish, Scottish, and German (father), likely Irish (mother)
# {'Allison Tolman': ['English', ' Scots-Irish', ' Northern Irish', ' Scottish', ' ', 'German', ' likely Irish']}
# 27
# Ashkenazi Jewish (father), English, German, French, Scottish, Welsh (mother, who likely converted to Judaism)
# {'Ike Barinholtz': ['Ashkenazi Jewish', ' English', ' German', ' French', ' Scottish', ' Welsh (mother', ' who likely converted to Judaism)']}
# 28
#  English, Scottish, Irish, Dutch, German
# {'Pascale Hutton': [' English', ' Scottish', ' Irish', ' Dutch', ' German']}
# 29
# 75%-81.25% Irish, 18.75%-25% mix of English, some Scottish, remote Dutch
# {'Seamus Davey-Fitzpatrick': ['75%-81.Irish', ' 18.75%-English', ' Scottish', 'Dutch']}
# 30
#  Ashkenazi Jewish
# {'Michael Rosenbaum': [' Ashkenazi Jewish']}
# 31
#  African-American
# {'Mike Epps': [' African-American']}
# 32
# steve-whitmire
# khary-payton
#  Norwegian, German, English
# {'Brit Marling': [' Norwegian', ' German', ' English']}
# 35
#  Greek
# {'Demetri Martin': [' Greek']}
# 36
#  Dutch, English, Scottish, French-Canadian, around 1/64th Italian, smalls amount of German and Belgian [Flemish], and remote Norwegian and Cornish
# {'Jane Fonda': [' Dutch', ' English', ' Scottish', ' French-Canadian', ' around ', ' Italian', ' smalls amount of German ', 'Belgian [Flemish]', ' andNorwegian ', 'Cornish']}
# 37
# keene-mcrae
#  African-American
# {'Laurence Fishburne': [' African-American']}
# 39
#  Brazilian [Italian, possibly other]
# {'Morena Baccarin': [' Brazilian [Italian', ' possibly other]']}
# 40
#  English, Irish, Polish, German, Swiss-German
# {'Chad Michael Murray': [' English', ' Irish', ' Polish', ' German', ' Swiss-German']}
# 41
#  Italian
# {'Enrico Colantoni': [' Italian']}
# 42
#  Ashkenazi Jewish
# {'Wallace Shawn': [' Ashkenazi Jewish']}
# 43
#  English, Irish, German, Scottish, Scots-Irish/Northern Irish, distant French and Swiss-German, remote Swedish and Welsh
# {'Casey Affleck': [' English', ' Irish', ' German', ' Scottish', ' Scots-Irish', ' Northern Irish', ' distant French ', 'Swiss-German', 'Swedish ', 'Welsh']}
# 44
# liam-mcintyre
#  Luxembourgish (maternal grandfather), Irish, English, German, 1/16 Syrian-Lebanese
# {'Katee Sackhoff': [' Luxembourgish ()', ' Irish', ' English', ' German', ' Syrian-Lebanese']}
# 46
# kevin-nash
#  English, Scottish, German, approximately 1/16th French-Canadian
# {'Stephen Amell': [' English', ' Scottish', ' German', ' approximately French-Canadian']}
# 48
# john-hannah
#  Ashkenazi Jewish
# {'Debra Messing': [' Ashkenazi Jewish']}
# 50
#  Iranian
# {'Golshifteh Farahani': [' Iranian']}
# 51
#  English, Irish, Scottish, distant Welsh
# {'Nate Corddry': [' English', ' Irish', ' Scottish', ' distant Welsh']}
# 52
#  English, small amount of Welsh
# {'Mike Myers': [' English', ' small amount of Welsh']}
# 53
# kara-hayward
#  African-American, likely some English
# {'Samuel L. Jackson': [' African-American', ' likely English']}
# 55
#  Iranian
# {'Dominic Rains': [' Iranian']}
# 56
# father – English, French-Canadian, Swiss-German, German, Scottish, Irish, Welsh, mother – Ashkenazi Jewish
# {'David Arquette': ['English', ' French-Canadian', ' Swiss-German', ' German', ' Scottish', ' Irish', ' Welsh', ' Ashkenazi Jewish']}
# 57
#  Filipino, likely other
# {'Deric McCabe': [' Filipino', ' likely other']}
# 58
# lew-temple
#  African-American, likely African-Jamaican
# {'Mike Tyson': [' African-American', ' likely African-Jamaican']}
# 60
#  English, German, Swedish, Irish, Scottish, Welsh, remote French
# {'Julia Roberts': [' English', ' German', ' Swedish', ' Irish', ' Scottish', ' Welsh', 'French']}
# 61
# christopher-rivera
# rob-labelle
#  English, German, Romanian
# {'Jennifer Ehle': [' English', ' German', ' Romanian']}
# 64
#  English, German, Scottish, 1/8th Swedish, 1/16th Cornish
# {'Rory Scovel': [' English', ' German', ' Scottish', ' Swedish', ' Cornish']}
# 65
#  Cuban, Guatemalan, French, Spanish
# {'Oscar Isaac': [' Cuban', ' Guatemalan', ' French', ' Spanish']}
# 66
#  African-American
# {'Damon Wayans Jr.': [' African-American']}
# 67
#  English, as well as French-Canadian, Irish, Scottish, German, Swiss-German, and Dutch
# {'Will Forte': [' English', ' French-Canadian', ' Irish', ' Scottish', ' German', ' Swiss-German', ' ', 'Dutch']}
# 68
#  English, Irish, Scottish, Welsh, distant Dutch
# {'Reese Witherspoon': [' English', ' Irish', ' Scottish', ' Welsh', ' distant Dutch']}
# 69
#  English, Anglo-Irish/Northern Irish, Irish
# {'Sam Neill': [' English', ' Anglo-Irish', ' Northern Irish', ' Irish']}
# 70
#  English, some Scots-Irish/Northern Irish, Scottish, and German
# {'Jacob Lofland': [' English', ' Scots-Irish', ' Northern Irish', ' Scottish', ' ', 'German']}
# 71
#  Ashkenazi Jewish, as well as about one eighth Sephardi Jewish
# {'Jenny Slate': [' Ashkenazi Jewish', ' about Sephardi Jewish']}
# 72
#  Cambodian/Khmer
# {'Ellen Wong': [' Cambodian', ' Khmer']}
# 73
#  English, Irish
# {'Lucy Punch': [' English', ' Irish']}
# 74
# shannon-kane
#  African-American
# {'Morris Chestnut': [' African-American']}
# 76
# English, smaller amounts of Scottish, Scots-Irish/Northern Irish, French, and Irish (father), French, Japanese (mother)
# {'Charlie Wright': ['English', ' smaller amounts of Scottish', ' Scots-Irish', ' Northern Irish', ' French', ' ', 'Irish', ' French', ' Japanese']}
# 77
# Ghanaian (father), German, Ashkenazi Jewish (mother)
# {'Boris Kodjoe': ['Ghanaian', ' German', ' Ashkenazi Jewish']}
# 78
# dominic-pace
#  English, some Scottish and Irish
# {'Marcia Gay Harden': [' English', ' Scottish ', 'Irish']}
# 80
# jaime-olías
# armin-shimerman
# English, Swedish, German, Scottish (father), Ashkenazi Jewish (mother)
# {'T.J. Miller': ['English', ' Swedish', ' German', ' Scottish', ' Ashkenazi Jewish']}
# 83
# sarah-snook
# rza
# cyndi-mayo-davis
# Irish (father), Italian (mother)
# {'Michael Kelly': ['Irish', ' Italian']}
# 87
# paul-anderson
# dj-flava
#  Irish, English
# {'Colin Egglesfield': [' Irish', ' English']}
# 90
#  Irish, possibly other
# {'Frankie Shaw': [' Irish', ' possibly other']}
# 91
#  German, English, Scottish, 1/8th French
# {'Melissa Benoist': [' German', ' English', ' Scottish', ' French']}
# 92
#  African American, African-Haitian
# {'Harold Perrineau': [' African American', ' African-Haitian']}
# 93
# Greek (father), English, Scottish (mother)
# {'Amy Sedaris': ['Greek', ' English', ' Scottish']}
# 94
#  Ashkenazi Jewish
# {'Ian Nelson': [' Ashkenazi Jewish']}
# 95
# Moroccan Berber (father), Spanish (mother)
# {'Lubna Azabal': ['Moroccan Berber', ' Spanish']}
# 96
#  Swiss-German, German, English, Dutch, Scottish, distant Irish, French, and Welsh
# {'Taylor Lautner': [' Swiss-German', ' German', ' English', ' Dutch', ' Scottish', ' distant Irish', ' French', ' ', 'Welsh']}
# 97
# michael-arden
# christopher-eccleston
# 37.5% Bohemian Czech, 25% Swedish, 25% German, 12.5% English
# {'Crispin Glover': ['Bohemian Czech', ' Swedish', ' German', ' English']}
# 100
# nicolas-martinez
# 75% mix of German, Irish, Scottish, English, distant Welsh, remote Dutch, 25% mix of Ashkenazi Jewish and more distant Sephardi Jewish
# {'Lily Rabe': ['German', ' Irish', ' Scottish', ' English', ' distant Welsh', 'Dutch', ' Ashkenazi Jewish ', 'more distant Sephardi Jewish']}
# 102
# lauren-vélez
#  English
# {'Lesley Manville': [' English']}
# 104
#  Irish
# {'Pierce Brosnan': [' Irish']}
# 105
#  English
# {'Jim Broadbent': [' English']}
# 106
# onata-aprile
# c.j.-wilson
#  English
# {'Julie Andrews': [' English']}
# 109
#  English, Irish, some German and Scottish, possibly other
# {'Hayley Atwell': [' English', ' Irish', ' German ', 'Scottish', ' possibly other']}
# 110
#  German, English, Scottish
# {'James Badge Dale': [' German', ' English', ' Scottish']}
# 111
# koyu-rankin
#  English, Irish
# {'Mark Rylance': [' English', ' Irish']}
# 113
# Ashkenazi Jewish (father), Irish, some German (mother)
# {'Stephen Lang': ['Ashkenazi Jewish', ' Irish', ' German']}
# 114
#  Welsh
# {'Rhys Ifans': [' Welsh']}
# 115
#  English, Scottish, Irish, some German
# {'Lucy Hale': [' English', ' Scottish', ' Irish', ' German']}
# 116
# ellie-grainger
# father – English, some Cornish, more distant German, mother – Portuguese
# {'Tom Hanks': ['English', ' Cornish', ' more distant German', ' Portuguese']}
# 118
# hadley-belle-miller
#  English, some Northern Irish, German, Swiss-German, Irish, and Scottish
# {'Angela Kinsey': [' English', ' Northern Irish', ' German', ' Swiss-German', ' Irish', ' ', 'Scottish']}
# 120
# 75% Italian [including Sicilian and Piedmontese], 25% mix of German, English, and Irish
# {'Rene Russo': ['Italian [Sicilian ', 'Piedmontese]', ' German', ' English', ' ', 'Irish']}
# 121
#  Scottish, English, 1/8th Ashkenazi Jewish, 1/8th Greek, 1/16th French, some Manx [Isle of Man]
# {'Charlie Rowe': [' Scottish', ' English', ' Ashkenazi Jewish', ' Greek', ' French', ' Manx [Isle of Man]']}
# 122
#  Ashkenazi Jewish
# {'Noah Emmerich': [' Ashkenazi Jewish']}
# 123
# German (father)
# {'Karl Urban': ['German']}
# 124
#  English, German, Scottish, Irish, distant Welsh
# {'Dylan Minnette': [' English', ' German', ' Scottish', ' Irish', ' distant Welsh']}
# 125
#  English
# {'Timothy Spall': [' English']}
# 126
#  English, Scottish
# {'Scottie Thompson': [' English', ' Scottish']}
# 127
#  Swedish, Italian
# {'Michael Nyqvist': [' Swedish', ' Italian']}
# 128
#  possibly English and other
# {'Oona Laurence': [' possibly English ', 'other']}
# 129
#  English, 1/8th Danish, Scottish, some German, French, and Welsh
# {'Sarah Paulson': [' English', ' Danish', ' Scottish', ' German', ' French', ' ', 'Welsh']}
# 130
#  English
# {'Stephen Moyer': [' English']}
# 131
#  Irish
# {'Imelda Staunton': [' Irish']}
# 132
#  Swedish (maternal grandfather), Irish, English, Scottish, Welsh
# {'Mark Hamill': [' Swedish ()', ' Irish', ' English', ' Scottish', ' Welsh']}
# 133
# stephen-rea
# renée-zellweger
# luke-spencer-roberts
#  Ashkenazi Jewish
# {'Rob Reiner': [' Ashkenazi Jewish']}
# 137
# katie-crown
# conrad-vernon
# pfeifer-brown
#  Norwegian, Chinese Malaysian
# {'Natassia Malthe': [' Norwegian', ' Chinese Malaysian']}
# 141
# scott-haze
# evan-helmuth
#  English, with some Scottish, Northern Irish, Welsh, and Dutch, as well as distant Spanish (roughly 1/128th), German, French, and European Royal
# {'Kit Harington': [' English', ' with Scottish', ' Northern Irish', ' Welsh', ' ', 'Dutch', ' distant Spanish (roughly 1', ' 128th)', ' German', ' French', ' ', 'European Royal']}
# 144
#  Puerto Rican [Spanish, Taíno]
# {'Jennifer Lopez': [' Puerto Rican [Spanish', ' Taíno]']}
# 145
# 37.5% Mexican, 25% Italian, 12.5% Ashkenazi Jewish, 12.5% Filipino, 12.5% mix of English, German, Scottish, and Irish
# {'Raymond Ochoa': ['Mexican', ' Italian', ' Ashkenazi Jewish', ' Filipino', ' English', ' German', ' Scottish', ' ', 'Irish']}
# 146
#  English, along with German, Swiss-German, Scots-Irish/Northern Irish, Manx/Isle of Man, Dutch, Danish
# {'Keri Russell': [' English', ' along with German', ' Swiss-German', ' Scots-Irish', ' Northern Irish', ' Manx', ' Isle of Man', ' Dutch', ' Danish']}
# 147
# Igbo Nigerian (father), Polish, English (mother)
# {'Annie Ilonzeh': ['Igbo Nigerian', ' Polish', ' English']}
# 148
#  Ashkenazi Jewish, possibly other
# {'Yani Gellman': [' Ashkenazi Jewish', ' possibly other']}
# 149
# taylor-nichols
#  English
# {'Scott Adkins': [' English']}
# 151
# josé-garcia
# om-puri
# marshall-manesh
#  Ashkenazi Jewish
# {'Bob Balaban': [' Ashkenazi Jewish']}
# 155
# father – Native Hawaiian, Portuguese, English, Scottish, at least 1/16th Chinese, remote Dutch, mother – English
# {'Keanu Reeves': ['Native Hawaiian', ' Portuguese', ' English', ' Scottish', ' at least Chinese', 'Dutch', ' English']}
# 156
# jeremy-dozier
# Estonian, 1/8th Swedish (father)
# {'Alison Pill': ['Estonian', ' Swedish']}
# 158
# cory-hardrict
#  English
# {'Robert Pattinson': [' English']}
# 160
# james-arnold-taylor
#  English, some Irish
# {'Gary Oldman': [' English', ' Irish']}
# 162
#  Brazilian
# {'Alice Braga': [' Brazilian']}
# 163
#  European, evidently one quarter Cherokee Native American
# {'Kristin Chenoweth': [' European', ' evidently one quarter Cherokee Native American']}
# 164
# kate-burton
# sage-correa
# noel-fisher
# Italian (father), Ashkenazi Jewish (mother)
# {"Sofia Black-D'Elia": ['Italian', ' Ashkenazi Jewish']}
# 168
#  English
# {'Sean Harris': [' English']}
# 169
#  Iranian [Persian]
# {'Navid Negahban': [' Iranian [Persian]']}
# 170
# Albanian (father), English, smaller amounts of Scottish, German, and Welsh (mother)
# {'Enver Gjokaj': ['Albanian', ' English', ' smaller amounts of Scottish', ' German', ' ', 'Welsh']}
# 171
# 50% Slovak, 25% Italian, 25% mix of English and German
# {'Bianca Kajlich': ['Slovak', ' Italian', ' English ', 'German']}
# 172
#  Irish
# {'Jonathan Rhys Meyers': [' Irish']}
# 173
# david-kaye
# marcin-kowalczyk
# iván-gonzález
#  Chinese
# {'Daniel Wu': [' Chinese']}
# 177
#  African-American
# {'Yasiin Bey': [' African-American']}
# 178
# lea-coco
#  Norwegian (one eighth), English, French, Scottish, Irish, and Welsh, 1/16th Belgian/Walloon, 1/32 Dutch, 1/32 Belgian/Flemish
# {'Margaret Qualley': [' Norwegian ', ' English', ' French', ' Scottish', ' Irish', ' ', 'Welsh', ' Belgian', ' Walloon', '  Dutch', '  Belgian', ' Flemish']}
# 180
#  Scots-Irish/Northern Irish, Scottish, English
# {'Robert Patrick': [' Scots-Irish', ' Northern Irish', ' Scottish', ' English']}
# 181
# deborra-lee-furness
# allison-cratchley
# kate-del-castillo
# Serbian/Montenegrin-Serbian (father), Russian (mother)
# {'Milla Jovovich': ['Serbian', ' Montenegrin-Serbian', ' Russian']}
# 185
# sharon-horgan
#  English, German, Irish
# {'Julie Hagerty': [' English', ' German', ' Irish']}
# 187
#  English, Irish, Scottish, distant Welsh
# {'Rob Corddry': [' English', ' Irish', ' Scottish', ' distant Welsh']}
# 188
# riley-thomas-stewart
#  Cuban [Spanish, possibly other]
# {'Ana de Armas': [' Cuban [Spanish', ' possibly other]']}
# 190
# liz-cardenas-franke
#  English, as well as distant Welsh
# {'Emily Blunt': [' English', ' distant Welsh']}
# 192
#  Ashkenazi Jewish
# {'Jason Isaacs': [' Ashkenazi Jewish']}
# 193
#  Ugandan
# {'Daniel Kaluuya': [' Ugandan']}
# 194
#  Ashkenazi Jewish
# {'Martin Landau': [' Ashkenazi Jewish']}
# 195
# German, French, English (father), Italian (mother)
# {'Johnathon Schaech': ['German', ' French', ' English', ' Italian']}
# 196
# gonzalo-menendez
#  English, Welsh, Swedish, German, Norwegian, Scots-Irish/Northern Irish, Irish, Scottish, remote Dutch and French Huguenot
# {'Dakota Johnson': [' English', ' Welsh', ' Swedish', ' German', ' Norwegian', ' Scots-Irish', ' Northern Irish', ' Irish', ' Scottish', 'Dutch ', 'French Huguenot']}
# 198
#  English, French, Irish
# {'Michael Mosley': [' English', ' French', ' Irish']}
# 199
#  Puerto Rican
# {'Melonie Diaz': [' Puerto Rican']}
# 200
# ingrid-caven
#  English, as well as Scottish, German, Scots-Irish/Northern Irish, and Welsh, remote French-Canadian
# {'Blake Lively': [' English', ' Scottish', ' German', ' Scots-Irish', ' Northern Irish', ' ', 'Welsh', 'French-Canadian']}
# 202
#  Welsh
# {'Henry Thomas': [' Welsh']}
# 203
# Italian (father), English, Scottish, Irish, German, remote Dutch (mother)
# {'Owen Vaccaro': ['Italian', ' English', ' Scottish', ' Irish', ' German', 'Dutch']}
# 204
# marion-lambert
# morfydd-clark
#  Scottish, likely Irish
# {'Peter Mullan': [' Scottish', ' likely Irish']}
# 207
#  English, Scottish, Irish, distant German
# {'Nicole Kidman': [' English', ' Scottish', ' Irish', ' distant German']}
# 208
#  African-American
# {'Donald Glover': [' African-American']}
# 209
# ashley-grace
#  Swedish
# {'Dolph Lundgren': [' Swedish']}
# 211
# eric-jacobson
#  English, Scottish, smaller amounts of German, Dutch, French, Swedish, and Welsh
# {'Anna Camp': [' English', ' Scottish', ' smaller amounts of German', ' Dutch', ' French', ' Swedish', ' ', 'Welsh']}
# 213
# jennifer-prior
# valeria-cotto
#  German, Irish, English, Scottish
# {'James Cromwell': [' German', ' Irish', ' English', ' Scottish']}
# 216
#  German, as well as Irish, English, and Dutch
# {'William Fichtner': [' German', ' Irish', ' English', ' ', 'Dutch']}
# 217
#  Japanese
# {'George Takei': [' Japanese']}
# 218
#  German, English, some Scottish and Dutch, 1/16th Ashkenazi Jewish
# {'Megan Boone': [' German', ' English', ' Scottish ', 'Dutch', ' Ashkenazi Jewish']}
# 219
#  Ashkenazi Jewish
# {'Gal Gadot': [' Ashkenazi Jewish']}
# 220
# 75% German, 25% Swedish
# {'Kirsten Dunst': ['German', ' Swedish']}
# 221
# diana-bang
# African-American (father), European (mother)
# {'Kiersey Clemons': ['African-American', ' European']}
# 223
# Ashkenazi Jewish (father), English (mother, who converted to Judaism)
# {'Lara Pulver': ['Ashkenazi Jewish', ' English (mother', ' who converted to Judaism)']}
# 224
# fred-melamed
# neil-brown-jr.
#  Ashkenazi Jewish
# {'Simon Helberg': [' Ashkenazi Jewish']}
# 227
# father – German, Irish, Portuguese Azorean, English, mother – Irish
# {'Amy Poehler': ['German', ' Irish', ' Portuguese Azorean', ' English', ' Irish']}
# 228
# German, Swiss-German, Scottish, English (father), Italian, including Sicilian (mother)
# {'Shelley Hennig': ['German', ' Swiss-German', ' Scottish', ' English', ' Italian', ' Sicilian']}
# 229
# Sephardi Jewish (father), Ashkenazi Jewish, Spanish-Sephardi Jewish (mother)
# {'Daniela Ruah': ['Sephardi Jewish', ' Ashkenazi Jewish', ' Spanish-Sephardi Jewish']}
# 230
#  Swedish, English, possibly other
# {'Devin Druid': [' Swedish', ' English', ' possibly other']}
# 231
# tommy-g.-kendrick
#  Indian
# {'Neel Sethi': [' Indian']}
# 233
#  Korean
# {'Jihae': [' Korean']}
# 234
#  English, some German and Cornish, possibly other
# {'Kate Bosworth': [' English', ' German ', 'Cornish', ' possibly other']}
# 235
# English, Scots-Irish/Northern Irish (father), Filipino (mother)
# {'Lou Diamond Phillips': ['English', ' Scots-Irish', ' Northern Irish', ' Filipino']}
# 236
#  African-American
# {'Tracy Morgan': [' African-American']}
# 237
# jason-cope
# anna-geislerová
#  Irish
# {'Owen Wilson': [' Irish']}
# 240
#  English
# {'Sean Bean': [' English']}
# 241
#  English
# {'Augustus Prew': [' English']}
# 242
# katrina-bowden
#  Irish, English, German
# {'James Woods': [' Irish', ' English', ' German']}
# 244
#  English, some German and Scots-Irish (Northern Irish), distant Dutch
# {'Shelley Long': [' English', ' German ', 'Scots-Irish (Northern Irish)', ' distant Dutch']}
# 245
#  African-American
# {'Jeffrey Wright': [' African-American']}
# 246
#  Irish
# {'Colin Farrell': [' Irish']}
# 247
# roland-møller
# alessandro-lindblad
#  German, English, Irish, Scottish
# {'Michael Shannon': [' German', ' English', ' Irish', ' Scottish']}
# 250
#  German, English, Scottish, some Dutch, remote French
# {'Nicholas Braun': [' German', ' English', ' Scottish', ' Dutch', 'French']}
# 251
#  Czech (maternal grandfather), English, Irish, German
# {'Stefanie Scott': [' Czech ()', ' English', ' Irish', ' German']}
# 252
#  Italian, possibly other
# {'Spencer Lofranco': [' Italian', ' possibly other']}
# 253
#  Ashkenazi Jewish
# {'Michael Rapaport': [' Ashkenazi Jewish']}
# 254
# anna-hutchison
# father – English, Irish, German, Swiss-German, French, mother – German
# {'Sandra Bullock': ['English', ' Irish', ' German', ' Swiss-German', ' French', ' German']}
# 256
#  German, English, Irish, Northern Irish, Scottish, distant Swiss-French and French
# {'Willem Dafoe': [' German', ' English', ' Irish', ' Northern Irish', ' Scottish', ' distant Swiss-French ', 'French']}
# 257
#  Ashkenazi Jewish
# {'Emory Cohen': [' Ashkenazi Jewish']}
# 258
#  English, Welsh
# {'Vinnie Jones': [' English', ' Welsh']}
# 259
# mother – Puerto Rican, Cuban, including African and Taíno, biological father – publicly unknown
# {'Rosario Dawson': ['Puerto Rican', ' Cuban', ' African ', 'Taíno', ' biological publicly unknown']}
# 260
# 25% Korean, 25% German, 50% Venezuelan
# {'Fred Armisen': ['Korean', ' German', ' Venezuelan']}
# 261
# English, Scottish, Irish, German (father), Ashkenazi Jewish (mother)
# {'Julia Garner': ['English', ' Scottish', ' Irish', ' German', ' Ashkenazi Jewish']}
# 262
# Peruvian [Spanish, possibly German and Cuban] (father), Ashkenazi Jewish, Croatian and Czech (mother)
# {'Melissa Bolona': ['Peruvian [Spanish', ' possibly German ', 'Cuban]', ' Ashkenazi Jewish', ' Croatian ', 'Czech']}
# 263
#  African-American [including Cameroonian]
# {'Taraji P. Henson': [' African-American [Cameroonian]']}
# 264
#  Romanian
# {'Florian Munteanu': [' Romanian']}
# 265
#  English, Irish, some French
# {'Julianna Guill': [' English', ' Irish', ' French']}
# 266
#  Sindhi Indian
# {'Archie Panjabi': [' Sindhi Indian']}
# 267
#  Italian (paternal grandfather), German, English, Irish
# {'Annalise Basso': [' Italian', ' German', ' English', ' Irish']}
# 268
# phaldut-sharma
# lee-asquith-coe
# douglas-m.-griffin
#  German, English, Scottish, Irish, distant Dutch
# {'Joel David Moore': [' German', ' English', ' Scottish', ' Irish', ' distant Dutch']}
# 272
# tómas-lemarquis
#  Chilean, Cuban
# {'Jorge Garcia': [' Chilean', ' Cuban']}
# 274
# rock-duer
#  Swedish, small amount of Finnish, distant Baltic German
# {'Alicia Vikander': [' Swedish', ' small amount of Finnish', ' distant Baltic German']}
# 276
# jonathan-alpert
# j.p.-valenti
#  Argentinian (Spanish, likely some Sephardi Jewish)
# {'Carlos Alazraqui': ['Argentinian (Spanish', ' likely Sephardi Jewish)']}
# 279
#  Indian [Tamil, Bengali]
# {'Mindy Kaling': [' Indian [Tamil', ' Bengali]']}
# 280
#  English, Scottish, Irish
# {'Ryan Robbins': [' English', 'Scottish', ' Irish']}
# 281
#  Indian [Tamil]
# {'Aziz Ansari': [' Indian [Tamil]']}
# 282
#  English, Irish, small amounts of German and Welsh, remote Scottish and French
# {'Megan Mullally': [' English', ' Irish', ' small amounts of German ', 'Welsh', 'Scottish ', 'French']}
# 283
# charlie-murphy
#  Mexican
# {'Danny Trejo': [' Mexican']}
# 285
#  Irish
# {'Colm Meaney': [' Irish']}
# 286
# robert-paterson
# Italian (father), Irish (mother)
# {'Max Martini': ['Italian', ' Irish']}
# 288
#  Scottish, English, possibly other
# {'Jennifer Carpenter': [' Scottish', ' English', ' possibly other']}
# 289
#  Ashkenazi Jewish
# {'Natasha Lyonne': [' Ashkenazi Jewish']}
# 290
# keith-carradine
#  German, English, Norwegian, Danish, Irish, Dutch Jewish, French Jewish, Scottish, Northern Irish
# {'Max Thieriot': [' German', ' English', ' Norwegian', ' Danish', ' Irish', ' Dutch Jewish', ' French Jewish', ' Scottish', ' Northern Irish']}
# 292
# 62.5% Bohemian [Czech], 25% Irish, 12.5% German, including Swiss-German
# {'Ashton Kutcher': ['Bohemian [Czech]', ' Irish', ' German', ' Swiss-German']}
# 293
#  English
# {'Ophelia Lovibond': [' English']}
# 294
# percy-daggs-iii
#  Italian, some Sephardi Jewish
# {'Michael Angarano': [' Italian', ' Sephardi Jewish']}
# 296
# tom-mcgrath
#  French, English
# {'Emilie de Ravin': [' French', ' English']}
# 298
#  Norwegian
# {'Eric Christian Olsen': [' Norwegian']}
# 299
# neal-huff
#  Swedish
# {'Peter Stormare': [' Swedish']}
# 301
# 25% Slovak, 25% German
# {'Angelina Jolie': ['Slovak', ' German ']}
# 302
#  Irish, Scottish, as well as 1/32 Indian
# {'Billy Connolly': [' Irish', ' Scottish', '  Indian']}
# 303
#  English, some German, Scots-Irish/Northern Irish, and Scottish, distant French and Welsh
# {'Lucas Hedges': [' English', ' German', ' Scots-Irish', ' Northern Irish', ' ', 'Scottish', ' distant French ', 'Welsh']}
# 304
# Irish (mother), possibly English (father)
# {'Joshua Jackson': ['Irish', ' possibly English']}
# 305
# ariel-levy
#  Ashkenazi Jewish (grandfather), as well as English, German, Scottish, possibly around 1/16th Irish, and remote Dutch and Belgian/Flemish
# {'Zac Efron': [' Ashkenazi Jewish (grandfather)', ' English', ' German', ' Scottish', ' possibly around Irish', ' andDutch ', 'Belgian', ' Flemish']}
# 307
#  English, German, Scottish, some Irish, more distant Swiss-German, remote Cornish and Jersey [Channel Islander]
# {'Israel Broussard': [' English', ' German', ' Scottish', ' Irish', ' more distant Swiss-German', 'Cornish ', 'Jersey [Channel Islander]']}
# 308
# iris-bahr
#  Syrian (great-grandfather), Italian, Irish, possibly other
# {'Charlie Tahan': [' Syrian (great-grandfather)', ' Italian', ' Irish', ' possibly other']}
# 310
# lorraine-nicholson
#  Ghanaian
# {'Abraham Attah': [' Ghanaian']}
# 312
#  Scottish
# {'James McAvoy': [' Scottish']}
# 313
#  English, Swedish, German, Austrian
# {'Elisabeth Moss': [' English', ' Swedish', ' German', ' Austrian']}
# 314
#  Armenian, English, likely some Arab
# {'Andy Serkis': [' Armenian', ' English', ' likely Arab']}
# 315
# andrew-lees
#  African-American
# {'Angela Bassett': [' African-American']}
# 317
#  Danish, some Swedish
# {'Nikolaj Coster-Waldau': [' Danish', ' Swedish']}
# 318
# blythe-danner
# rachael-taylor
# ionut-grama
#  African-American
# {'Viola Davis': [' African-American']}
# 322
# 75% Italian [including Sicilian], 25% English
# {'Jason Biggs': ['Italian [Sicilian]', ' English']}
# 323
#  English, Irish, German, 1/8th French-Canadian, 1/8th Swedish
# {'Grey Damon': [' English', ' Irish', ' German', ' French-Canadian', ' Swedish']}
# 324
# javier-botet
#  Ukrainian
# {'Vera Farmiga': [' Ukrainian']}
# 326
#  Brazilian [Italian, Spanish, Portuguese, Swiss, possibly Indigenous Brazilian]
# {'Fernanda Andrade': [' Brazilian [Italian', ' Spanish', ' Portuguese', ' Swiss', ' possibly Indigenous Brazilian]']}
# 327
#  English
# {'Eddie Marsan': [' English']}
# 328
#  English, German, Polish
# {'Kirby Bliss Blanton': [' English', ' German', ' Polish']}
# 329
#  African-American
# {'Tony Cox': [' African-American']}
# 330
# georgina-cates
#  English, Scots-Irish (Northern Irish), Irish
# {'Lynn Collins': [' English', ' Scots-Irish (Northern Irish)', ' Irish']}
# 332
#  British Isles, possibly other
# {'Mackenzie Foy': [' British Isles', ' possibly other']}
# 333
# imogene-wolodarsky
#  Scottish
# {'Kelly Macdonald': [' Scottish']}
# 335
#  English, Irish
# {'Evangeline Lilly': [' English', ' Irish']}
# 336
# stephen-boss
# chloe-csengery
#  Chinese
# {'Jing Tian': [' Chinese']}
# 339
# max-charles
# jeannie-berlin
# Portuguese/Madeiran, Swedish (father), Ashkenazi Jewish (mother)
# {'Dave Franco': ['Portuguese', ' Madeiran', ' Swedish', ' Ashkenazi Jewish']}
# 342
# 50% Estonian, 25% Greek, 12.5% Norwegian, 12.5% mix of German and English
# {'Mena Suvari': ['Estonian', ' Greek', ' Norwegian', ' German ', 'English']}
# 343
# Ashkenazi Jewish (father), German, likely Polish (mother)
# {'Chelsea Handler': ['Ashkenazi Jewish', ' German', ' likely Polish']}
# 344
# father – Irish, German, mother – French-Canadian, English, small amount of German
# {'Mickey Rourke': ['Irish', ' German', ' French-Canadian', ' English', ' small amount of German']}
# 345
#  Swedish, Norwegian, Scottish, English, 1/32 German
# {'Erik Stolhanske': [' Swedish', ' Norwegian', ' Scottish', ' English', '  German']}
# 346
# African-American (biological father), Polish, Belgian Flemish (biological mother)
# {'Keegan-Michael Key': ['African-American (biological father)', ' Polish', ' Belgian Flemish (biological mother)']}
# 347
#  Italian
# {'Daniel Franzese': [' Italian']}
# 348
# dejan-angelov
# mugga
#  Dominican Republic [African]
# {'Jorge Lendeborg Jr.': [' Dominican Republic [African]']}
# 351
#  Italian, Irish
# {'Dawn Olivieri': [' Italian', ' Irish']}
# 352
#  English, some Scots-Irish/Northern Irish, distant German and Dutch
# {'Powers Boothe': [' English', ' Scots-Irish', ' Northern Irish', ' distant German ', 'Dutch']}
# 353
#  Cuban [African, some Spanish]
# {'Christina Milian': [' Cuban [African', ' Spanish]']}
# 354
#  Portuguese (paternal grandmother), Ashkenazi Jewish (one eighth), English, Cornish, Scottish, Irish, German
# {'Colin Hanks': [' Portuguese ()', ' Ashkenazi Jewish ', ' English', ' Cornish', ' Scottish', ' Irish', ' German']}
# 355
# Slovak, Polish, possibly other (father), Peruvian (mother)
# {'Isabela Moner': ['Slovak', ' Polish', ' possibly other', ' Peruvian']}
# 356
#  Korean
# {'Ki Hong Lee': [' Korean']}
# 357
#  Chinese
# {'Hayden Szeto': [' Chinese']}
# 358
#  Gujarati Indian
# {'Kal Penn': [' Gujarati Indian']}
# 359
#  German, French, Finnish, Swedish, other
# {'Mark Webber': [' German', ' French', ' Finnish', ' Swedish', ' other']}
# 360
# [{'Ansel Elgort': ['Eastern European Ashkenazi Jewish', ' Norwegian', ' English', ' Scots-Irish', ' Northern Irish', ' ', 'German']}, {'Steve Lemme': ['Argentinian', ' French', ' Puerto Rican']}, {'Bel Powley': ['English', ' Ashkenazi Jewish']}, {'Christopher Walken': ['German', ' Scottish', ' small amount of Irish']}, {'Ashley Tisdale': ['English', ' Irish', ' Scottish', ' German', ' Ashkenazi Jewish']}, {'Rena Owen': ['Māori', ' Welsh', ' Danish', ' French', ' English']}, {'Scott Speedman': [' Scottish']}, {'Stephen Merchant': [' English']}, {'Christine Baranski': [' Polish']}, {'Vicky Krieps': [' Luxembourgish', ' German']}, {'Emily Ratajkowski': ['Polish', ' Ashkenazi Jewish', ' Irish', ' with German ', 'English', ' andWelsh']}, {'Gwilym Lee': [' Welsh']}, {'Scott Bakula': [' German', ' Bohemian (Czech)', ' Austrian', ' English', ' Scottish']}, {'Tom Lipinski': [' Polish', ' possibly other']}, {'Richard Armitage': [' English']}, {'John Magaro': ['Italian', ' Ashkenazi Jewish']}, {'Barbra Streisand': [' Ashkenazi Jewish']}, {'Allison Tolman': ['English', ' Scots-Irish', ' Northern Irish', ' Scottish', ' ', 'German', ' likely Irish']}, {'Ike Barinholtz': ['Ashkenazi Jewish', ' English', ' German', ' French', ' Scottish', ' Welsh (mother', ' who likely converted to Judaism)']}, {'Pascale Hutton': [' English', ' Scottish', ' Irish', ' Dutch', ' German']}, {'Seamus Davey-Fitzpatrick': ['75%-81.Irish', ' 18.75%-English', ' Scottish', 'Dutch']}, {'Michael Rosenbaum': [' Ashkenazi Jewish']}, {'Mike Epps': [' African-American']}, {'Brit Marling': [' Norwegian', ' German', ' English']}, {'Demetri Martin': [' Greek']}, {'Jane Fonda': [' Dutch', ' English', ' Scottish', ' French-Canadian', ' around ', ' Italian', ' smalls amount of German ', 'Belgian [Flemish]', ' andNorwegian ', 'Cornish']}, {'Laurence Fishburne': [' African-American']}, {'Morena Baccarin': [' Brazilian [Italian', ' possibly other]']}, {'Chad Michael Murray': [' English', ' Irish', ' Polish', ' German', ' Swiss-German']}, {'Enrico Colantoni': [' Italian']}, {'Wallace Shawn': [' Ashkenazi Jewish']}, {'Casey Affleck': [' English', ' Irish', ' German', ' Scottish', ' Scots-Irish', ' Northern Irish', ' distant French ', 'Swiss-German', 'Swedish ', 'Welsh']}, {'Katee Sackhoff': [' Luxembourgish ()', ' Irish', ' English', ' German', ' Syrian-Lebanese']}, {'Stephen Amell': [' English', ' Scottish', ' German', ' approximately French-Canadian']}, {'Debra Messing': [' Ashkenazi Jewish']}, {'Golshifteh Farahani': [' Iranian']}, {'Nate Corddry': [' English', ' Irish', ' Scottish', ' distant Welsh']}, {'Mike Myers': [' English', ' small amount of Welsh']}, {'Samuel L. Jackson': [' African-American', ' likely English']}, {'Dominic Rains': [' Iranian']}, {'David Arquette': ['English', ' French-Canadian', ' Swiss-German', ' German', ' Scottish', ' Irish', ' Welsh', ' Ashkenazi Jewish']}, {'Deric McCabe': [' Filipino', ' likely other']}, {'Mike Tyson': [' African-American', ' likely African-Jamaican']}, {'Julia Roberts': [' English', ' German', ' Swedish', ' Irish', ' Scottish', ' Welsh', 'French']}, {'Jennifer Ehle': [' English', ' German', ' Romanian']}, {'Rory Scovel': [' English', ' German', ' Scottish', ' Swedish', ' Cornish']}, {'Oscar Isaac': [' Cuban', ' Guatemalan', ' French', ' Spanish']}, {'Damon Wayans Jr.': [' African-American']}, {'Will Forte': [' English', ' French-Canadian', ' Irish', ' Scottish', ' German', ' Swiss-German', ' ', 'Dutch']}, {'Reese Witherspoon': [' English', ' Irish', ' Scottish', ' Welsh', ' distant Dutch']}, {'Sam Neill': [' English', ' Anglo-Irish', ' Northern Irish', ' Irish']}, {'Jacob Lofland': [' English', ' Scots-Irish', ' Northern Irish', ' Scottish', ' ', 'German']}, {'Jenny Slate': [' Ashkenazi Jewish', ' about Sephardi Jewish']}, {'Ellen Wong': [' Cambodian', ' Khmer']}, {'Lucy Punch': [' English', ' Irish']}, {'Morris Chestnut': [' African-American']}, {'Charlie Wright': ['English', ' smaller amounts of Scottish', ' Scots-Irish', ' Northe ...
# ['gregg-henry', 'rachel-korine', 'pierce-gagnon', 'suzan-crowley', 'madison-wolfe', 'shawn-roberts', 'claire-julien', 'brittany-daniel', 'abigail-hargrove', 'rodger-bumpass', 'michael-kopsa', 'gina-mckee', 'august-diehl', 'jeffrey-demunn', 'ward-horton', 'hunter-mccracken', 'vicky-mcclure', 'zoë-borde', 'jazmyn-simon', 'dimiter-d.-marinov', 'erica-ash', 'shanelle-workman', 'finnegan-williams', 'betsy-russell', 'jack-bright', 'joanna-vanderham', 'tom-mison', 'zackary-arthur', 'meredith-droeger', 'mimi-kennedy', 'mark-killeen', 'lowell-landes', 'tom-bennett', 'payman-maadi', 'leigh-whannell', 'angus-macfadyen', 'david-lyons', 'rolf-kanies', 'arash-marandi', "y'lan-noel", 'ashley-aufderheide', 'lenn-kudrjawizki', 'busy-philipps', 'verónica-echegui', 'ralph-brown', 'jorge-diaz', 'alycia-debnam-carey', 'julia-chan', 'shane-carruth', 'léa-seydoux', 'simon-yam', 'matthew-lee-erlbach', 'óscar-jaenada', 'tucker-albrizzi', 'philip-anthony-rodriguez', 'mariah-bonner', 'zulay-henao', 'pilou-asbæk', 'mélanie-laurent', 'adam-barnett', 'timothy-eulich', 'pat-healy', 'ginger-lynn-allen', 'ned-dennehy', 'lloyd-owen', 'janelle-monáe', 'tess-liu', 'mike-hatton', 'brooke-smith', 'john-carroll-lynch', 'andrew-daly', 'werner-herzog', 'j.-quinton-johnson', 'brian-boland', 'essie-davis', 'sam-medina', 'lorelei-linklater', 'joel-garland', 'dale-dickey', 'luca-calvani', 'noah-johnston', 'meg-foster', 'adrian-rawlins', 'florence-hartigan', 'colleen-camp', 'glenn-morshower', 'john-mahoney', 'david-bierend', 'hazuki-kato', 'adelaide-clemens', 'christopher-knights', 'gregory-jones', 'william-peltz', 'johan-leysen', 'min-tanaka', 'stephanie-szostak', 'zoe-aggeliki', 'riley-griffiths', 'faith-ford', 'ariel-schulman', 'opeyemi-fagbohungbe', 'brady-allen', 'jonny-brugh', 'jeffrey-thomas', 'audrey-wasilewski', 'catherine-kresge', 'sara-sohn', 'cem-y?lmaz', 'huck-milner', 'madeline-carroll', 'leehom-wang', 'kylie-rogers', 'nick-lashaway', 'suzanne-cryer', 'rachael-markarian', 'robert-john-burke', 'mathilde-ollivier', 'ruby-barnhill', 'chris-mulkey', 'sarah-butler', 'jeff-bennett', 'drago?-bucur', 'hynden-walch', 'masam-holden', 'adam-rodríguez', 'amy-hargreaves', 'ronan-raftery', 'hanna-brown', 'gael-garcía-bernal', 'kentucker-audley', 'emma-bellomy', 'david-wenham', 'paul-freeman', 'jaqueline-fleming', 'michael-mcelhatton', 'david-zayas', 'joe-slaughter', 'penelope-ann-miller', 'jasper-newell', 'colin-woodell', 'tom-noonan', 'stacy-keach', 'alexander-garfin', 'joseph-lee', 'ayush-tandon', 'james-nesbitt', 'courtney-fansler', 'eric-sheffer-stevens', 'jessica-guadix', 'peter-carey', 'kate-dickie', 'simon-mcburney', 'aaron-burns', 'lily-gladstone', 'r.a.-mihailoff', 'jakob-salvati', 'adam-david-thompson', 'dana-ashbrook', 'zachary-booth', 'bud-luckey', 'amanda-brooks', 'tiger-hu-chen', 'kristen-connolly', 'barry-shabaka-henley', 'pixie-davies', 'mimi-rogers', 'sophie-nélisse', 'grace-palmer', 'dan-gill', 'eduardo-verástegui', 'pihla-viitala', 'gina-montana', 'luke-tyler', 'taylor-hickson', 'clancy-brown', 'brad-garrett', 'quvenzhané-wallis', 'timothy-radford', 'kou-shibasaki', 'christopher-nicholas-smith', 'hayes-macarthur', 'penélope-cruz', 'hope-davis', 'santiago-segura', 'karren-karagulian', 'haluk-bilginer', 'patrick-kerton', 'derek-magyar', 'clément-sibony', 'saskia-reeves', 'daniel-olbrychski', 'cosmo', 'maria-doyle-kennedy', 'ralph-garman', 'alexa-nisenson', 'emily-meade', 'carolina-guerra', 'jonas-armstrong', 'jim-parrack', 'olwen-fouéré', 'jon-ted-wynne', 'thierry-neuvic', 'yukiyoshi-ozawa', 'michelle-la', 'cade-woodward', 'kitana-kiki-rodriguez', 'camilla-rutherford', 'jack-boulter', 'sean-whalen', 'larenz-tate', 'april-bowlby', 'jasper-pääkkönen', 'emily-maddison', 'lea-thompson', 'resse-hartwig', 'richard-pepple', 'richard-cabral', 'andré-holland', 'chris-riggi', 'daniel-wyllie', 'emily-barclay', 'brendan-meyer', 'gianny-taufer', 'sarah-baker', 'wes-robinson', 'megan-faccio', 'ingrid-bisu', 'scott-c.-roe', 'moica', 'carolyn-king', 'roxanne-mckee', 'mic ...

# %%
add_to_db_actor_ethnicities(actor_formatting(actor_ethnicities))

# %%
def actor_formatting(ethnicities_list):
    formatted_actor_ethnicities = []
    for actor in ethnicities_list:
        for key, value in actor.items():
            for ethnicity in value:
                actor_tuple = (key, ethnicity)
                formatted_actor_ethnicities.append(actor_tuple)
    return formatted_actor_ethnicities

# %%
def add_to_db_actor_ethnicities(formatted_actor_ethnicities):
    cnx = mysql.connector.connect(
    host = config.host,
    user = config.user,
    password = config.password,
    database = config.database)
    c = cnx.cursor()    
    stmt = """INSERT INTO actors (name, ethnicity) VALUES (%s, %s)"""
    c.executemany(stmt, formatted_actor_ethnicities)
    cnx.commit()
    c.close()
    cnx.close()

# %%
import pandas as pd
import mysql.connector
import config
cnx = mysql.connector.connect(
    host = config.host,
    user = config.user,
    password = config.password,
    database = config.database)
c = cnx.cursor()
q = """SET SQL_SAFE_UPDATES = 0;"""
c.execute(q)
cnx.commit()

# c = cnx.cursor()
# q = """DELETE FROM actors WHERE ethnicity = ''""";
# c.execute(q)
# cnx.commit()

# q = """UPDATE actors SET ethnicity = RTRIM(LTRIM(ethnicity));"""
# c.execute(q)
# cnx.commit()

# c = cnx.cursor()
# q = """DELETE FROM actors WHERE ethnicity LIKE '%possibly%'""";
# c.execute(q)
# cnx.commit()

# q = """DELETE FROM actors WHERE ethnicity LIKE '%distant%'""";
# c.execute(q)
# cnx.commit()

# q = """DELETE FROM actors WHERE ethnicity LIKE '%small%amount%'""";
# c.execute(q)
# cnx.commit()

# q = """DELETE FROM actors WHERE ethnicity LIKE '%other%'""";
# c.execute(q)
# cnx.commit()


# q = """DELETE FROM actors WHERE ethnicity LIKE '%unknown%'""";
# c.execute(q)
# cnx.commit()

# q = """DELETE FROM actors WHERE ethnicity LIKE '%uncertain%'""";
# c.execute(q)
# cnx.commit()

# q = """UPDATE actors SET ethnicity = REPLACE(ethnicity, 'along with', '')""";
# c.execute(q)
# cnx.commit()

# q = """UPDATE actors SET ethnicity = REPLACE(ethnicity, 'and', '')""";
# c.execute(q)
# cnx.commit()

# q = """UPDATE actors SET ethnicity = REPLACE(ethnicity, 'between', '')""";
# c.execute(q)
# cnx.commit()

# q = """UPDATE actors SET ethnicity = REPLACE(ethnicity, 'convert to', '')""";
# c.execute(q)
# cnx.commit()

# q = """UPDATE actors SET ethnicity = REPLACE(ethnicity, 'Birth Name', '')""";
# c.execute(q)
# cnx.commit()

# q = """UPDATE actors SET ethnicity = REPLACE(ethnicity, ':', '')""";
# c.execute(q)
# cnx.commit()

# q = """UPDATE actors SET ethnicity = REPLACE(ethnicity, 'approximately', '')""";
# c.execute(q)
# cnx.commit()

# q = """UPDATE actors SET ethnicity = REPLACE(ethnicity, 'around', '')""";
# c.execute(q)
# cnx.commit()

# q = """UPDATE actors SET ethnicity = REPLACE(ethnicity, 'at least', '')""";
# c.execute(q)
# cnx.commit()

# q = """UPDATE actors SET ethnicity = REPLACE(ethnicity, '1', '')""";
# c.execute(q)
# cnx.commit()

# q = """UPDATE actors SET ethnicity = REPLACE(ethnicity, '1.5' , '')""";
# c.execute(q)
# cnx.commit()

# q = """UPDATE actors SET ethnicity = REPLACE(ethnicity, '1024th' , '')""";
# c.execute(q)
# cnx.commit()

# q = """UPDATE actors SET ethnicity = REPLACE(ethnicity, '128th' , '')""";
# c.execute(q)
# cnx.commit()

# q = """UPDATE actors SET ethnicity = REPLACE(ethnicity, '16ths' , '')""";
# c.execute(q)
# cnx.commit()

# q = """UPDATE actors SET ethnicity = REPLACE(ethnicity, '30%', '')""";
# c.execute(q)
# cnx.commit()

# q = """UPDATE actors SET ethnicity = REPLACE(ethnicity, '31.' , '')""";
# c.execute(q)
# cnx.commit()

# q = """UPDATE actors SET ethnicity = REPLACE(ethnicity, '32' , '')""";
# c.execute(q)
# cnx.commit()

# q = """UPDATE actors SET ethnicity = REPLACE(ethnicity, '40.6' , '')""";
# c.execute(q)
# cnx.commit()

# q = """UPDATE actors SET ethnicity = REPLACE(ethnicity, '43.' , '')""";
# c.execute(q)
# cnx.commit()

# q = """UPDATE actors SET ethnicity = REPLACE(ethnicity, '512th' , '')""";
# c.execute(q)
# cnx.commit()

# q = """UPDATE actors SET ethnicity = REPLACE(ethnicity, '56.' , '')""";
# c.execute(q)
# cnx.commit()

# q = """UPDATE actors SET ethnicity = REPLACE(ethnicity, '59.3' , '')""";
# c.execute(q)
# cnx.commit()

# q = """UPDATE actors SET ethnicity = REPLACE(ethnicity, '6.' , '')""";
# c.execute(q)
# cnx.commit()

# q = """UPDATE actors SET ethnicity = REPLACE(ethnicity, ')', '')""";
# c.execute(q)
# cnx.commit()

# q = """UPDATE actors SET ethnicity = REPLACE(ethnicity, '[', '')""";
# c.execute(q)
# cnx.commit()

# q = """UPDATE actors SET ethnicity = REPLACE(ethnicity, ']', '')""";
# c.execute(q)
# cnx.commit()

# q = """UPDATE actors SET ethnicity = REPLACE(ethnicity, '16th' , '')""";
# c.execute(q)
# cnx.commit()
# q = """UPDATE actors SET ethnicity = REPLACE(ethnicity, '18.75%' , '')""";
# c.execute(q)
# cnx.commit()
# q = """UPDATE actors SET ethnicity = REPLACE(ethnicity, '18.' , '')""";
# c.execute(q)
# cnx.commit()
# q = """UPDATE actors SET ethnicity = REPLACE(ethnicity, '2048' , 'distant')""";
# c.execute(q)
# cnx.commit()
# q = """UPDATE actors SET ethnicity = REPLACE(ethnicity, '256th' , '')""";
# c.execute(q)
# cnx.commit()
# q = """UPDATE actors SET ethnicity = REPLACE(ethnicity, '256' , '')""";
# c.execute(q)
# cnx.commit()
# q = """UPDATE actors SET ethnicity = REPLACE(ethnicity, '28.1' , '')""";
# c.execute(q)
# cnx.commit()
# q = """UPDATE actors SET ethnicity = REPLACE(ethnicity, '(', '')""";
# c.execute(q)
# cnx.commit()
# q = """UPDATE actors SET ethnicity = REPLACE(ethnicity, '3.1', '')""";
# c.execute(q)
# cnx.commit()
# q = """UPDATE actors SET ethnicity = REPLACE(ethnicity, '62.5%', '')""";
# c.execute(q)
# cnx.commit()
# q = """UPDATE actors SET ethnicity = REPLACE(ethnicity, 'about', '')""";
# c.execute(q)
# cnx.commit()
# q = """UPDATE actors SET ethnicity = REPLACE(ethnicity, '68.', '')""";
# c.execute(q)
# cnx.commit()

# q = """UPDATE actors SET ethnicity = REPLACE(ethnicity, '68.', '')""";
# c.execute(q)
# cnx.commit()
# q = """UPDATE actors SET ethnicity = REPLACE(ethnicity, '75%', '')""";
# c.execute(q)
# cnx.commit()
# q = """UPDATE actors SET ethnicity = REPLACE(ethnicity, '8', '')""";
# c.execute(q)
# cnx.commit()
# q = """UPDATE actors SET ethnicity = REPLACE(ethnicity, '81.', '')""";
# c.execute(q)
# cnx.commit()

# q = """UPDATE actors SET ethnicity = REPLACE(ethnicity, 'one quarter', '')""";
# c.execute(q)
# cnx.commit()

# q = """UPDATE actors SET ethnicity = REPLACE(ethnicity, 'degree of', '')""";
# c.execute(q)
# cnx.commit()

# q = """UPDATE actors SET ethnicity = REPLACE(ethnicity, 'one eighth', '')""";
# c.execute(q)
# cnx.commit()

# q = """UPDATE actors SET ethnicity = REPLACE(ethnicity, 'mostly', '')""";
# c.execute(q)
# cnx.commit()

# q = """UPDATE actors SET ethnicity = REPLACE(ethnicity, 'predominantly', '')""";
# c.execute(q)
# cnx.commit()

# q = """UPDATE actors SET ethnicity = REPLACE(ethnicity, 'Ethnicity', '')""";
# c.execute(q)
# cnx.commit()

# q = """UPDATE actors SET ethnicity = REPLACE(ethnicity, 'from the', '')""";
# c.execute(q)
# cnx.commit()

# q = """UPDATE actors SET ethnicity = REPLACE(ethnicity, 'region', '')""";
# c.execute(q)
# cnx.commit()


# q = """UPDATE actors SET ethnicity = REPLACE(ethnicity, 'about', '')""";
# c.execute(q)
# cnx.commit()

# q = """UPDATE actors SET ethnicity = REPLACE(ethnicity, 'almost', '')""";
# c.execute(q)
# cnx.commit()

# q = """UPDATE actors SET ethnicity = REPLACE(ethnicity, 'Ethnicity', '')""";
# c.execute(q)
# cnx.commit()

# q = """UPDATE actors SET ethnicity = REPLACE(ethnicity, 'less', '')""";
# c.execute(q)
# cnx.commit()

# q = """UPDATE actors SET ethnicity = REPLACE(ethnicity, '37.5%', '')""";
# c.execute(q)
# cnx.commit()

# q = """UPDATE actors SET ethnicity = REPLACE(ethnicity, 'to 25%', '')""";
# c.execute(q)
# cnx.commit()

# q = """UPDATE actors SET ethnicity = REPLACE(ethnicity, 'half', '')""";
# c.execute(q)
# cnx.commit()

# q = """UPDATE actors SET ethnicity = REPLACE(ethnicity, 'one half', '')""";
# c.execute(q)
# cnx.commit()

# q = """UPDATE actors SET ethnicity = REPLACE(ethnicity, 'likely', '')""";
# c.execute(q)
# cnx.commit()

# q = """UPDATE actors SET ethnicity = REPLACE(ethnicity, 'less', '')""";
# c.execute(q)
# cnx.commit()

# q = """UPDATE actors SET ethnicity = REPLACE(ethnicity, 'mainly', '')""";
# c.execute(q)
# cnx.commit()

# q = """UPDATE actors SET ethnicity = REPLACE(ethnicity, 'maternal grand', '')""";
# c.execute(q)
# cnx.commit()

# q = """UPDATE actors SET ethnicity = REPLACE(ethnicity, 'one sixteenth', '')""";
# c.execute(q)
# cnx.commit()

# q = """UPDATE actors SET ethnicity = REPLACE(ethnicity, 'father', '')""";
# c.execute(q)
# cnx.commit()

# q = """UPDATE actors SET ethnicity = REPLACE(ethnicity, 'Piedmontese', '')""";
# c.execute(q)
# cnx.commit()

# q = """UPDATE actors SET ethnicity = REPLACE(ethnicity, 'great-great-grandfather', '')""";
# c.execute(q)
# cnx.commit()

# q = """UPDATE actors SET ethnicity = REPLACE(ethnicity, 'great-grandfather', '')""";
# c.execute(q)
# cnx.commit()

# q = """UPDATE actors SET ethnicity = REPLACE(ethnicity, 'three fourths', '')""";
# c.execute(q)
# cnx.commit()

# q = """UPDATE actors SET ethnicity = REPLACE(ethnicity, 'converted to', '')""";
# c.execute(q)
# cnx.commit()

# q = """UPDATE actors SET ethnicity = REPLACE(ethnicity, '-', ' ')""";
# c.execute(q)
# cnx.commit()

q = """UPDATE actors SET ethnicity = REPLACE(ethnicity, '–', ' ')""";
c.execute(q)
cnx.commit()


# q = """UPDATE actors SET ethnicity = REPLACE(ethnicity, '3.', ' ')""";
# c.execute(q)
# cnx.commit()


# q = """UPDATE actors SET ethnicity = REPLACE(ethnicity, '.', ' ')""";
# c.execute(q)
# cnx.commit()

# q = """UPDATE actors SET ethnicity = REPLACE(ethnicity, '45%', ' ')""";
# c.execute(q)
# cnx.commit()


# q = """UPDATE actors SET ethnicity = REPLACE(ethnicity, 'from', ' ')""";
# c.execute(q)
# cnx.commit()

# q = """UPDATE actors SET ethnicity = REPLACE(ethnicity, 'three quarters', ' ')""";
# c.execute(q)
# cnx.commit()

# q = """UPDATE actors SET ethnicity = REPLACE(ethnicity, 'one fourth', ' ')""";
# c.execute(q)
# cnx.commit()

# q = """UPDATE actors SET ethnicity = REPLACE(ethnicity, 'roughly', ' ')""";
# c.execute(q)
# cnx.commit()

# q = """UPDATE actors SET ethnicity = REPLACE(ethnicity, 'biologically', ' ')""";
# c.execute(q)
# cnx.commit()

# q = """UPDATE actors SET ethnicity = REPLACE(ethnicity, 'with', ' ')""";
# c.execute(q)
# cnx.commit()

# q = """UPDATE actors SET ethnicity = REPLACE(ethnicity, 'who', ' ')""";
# c.execute(q)
# cnx.commit()

# q = """UPDATE actors SET ethnicity = REPLACE(ethnicity, 'may have', ' ')""";
# c.execute(q)
# cnx.commit()

# q = """UPDATE actors SET ethnicity = REPLACE(ethnicity, 'great great gr', ' ')""";
# c.execute(q)
# cnx.commit()

q = """UPDATE actors SET ethnicity = RTRIM(LTRIM(ethnicity));"""
c.execute(q)
cnx.commit()

# q = """DELETE FROM actors WHERE ethnicity LIKE '%distant%'""";
# c.execute(q)
# cnx.commit()

q = """DELETE FROM actors WHERE ethnicity = ''""";
c.execute(q)
cnx.commit()






















# q = """DELETE FROM actors WHERE ethnicity LIKE '%likely%'""";
# c.execute(q)
# cnx.commit()


c.close()
# Out:
# True

# %%
import pandas as pd
import mysql.connector
import config
cnx = mysql.connector.connect(
    host = config.host,
    user = config.user,
    password = config.password,
    database = config.database)
c = cnx.cursor()

# q = """ALTER TABLE actors
# ADD COLUMN nonwhite VARCHAR(15) AFTER ethnicity;"""
# c.execute(q)
# cnx.commit()
# c.close()

q = """UPDATE actors 
        set nonwhite=case 
        when ethnicity LIKE '%Chilean%' then 'non-white'
        when ethnicity LIKE '%Colombian%' then 'non-white'
        when ethnicity LIKE '%Mexican%' then 'non-white'
        when ethnicity LIKE '%Moroccan%' then 'non-white'
        when ethnicity LIKE '%Peruvian%' then 'non-white'
        when ethnicity LIKE '%Venezuelan%' then 'non-white'
        when ethnicity LIKE '%African%' then 'non-white'
        when ethnicity LIKE '%Afrikan%' then 'non-white'
        when ethnicity LIKE '%Puerto Rican%' then 'non-white'
        
        
        when ethnicity LIKE '%Irish%' then 'white'
        when ethnicity LIKE '%English%' then 'white'
        when ethnicity LIKE '%German%' then 'white'
        when ethnicity LIKE '%Swedish%' then 'white'
        when ethnicity LIKE '%Scottish%' then 'white'
        when ethnicity LIKE '%French%' then 'white'
        when ethnicity LIKE '%Dutch%' then 'white'
        when ethnicity LIKE '%Jewish%' then 'white'
        when ethnicity LIKE '%Welsh%' then 'white'
        when ethnicity LIKE '%Austrian%' then 'white'
        when ethnicity LIKE '%Norwegian%' then 'white'
        when ethnicity LIKE '%Danish%' then 'white'
        when ethnicity LIKE '%Finnish%' then 'white'
        when ethnicity LIKE '%Italian%' then 'white'
        when ethnicity LIKE '%Canadian%' then 'white'
        when ethnicity LIKE '%Belgian%' then 'white'
        when ethnicity LIKE '%Flemish%' then 'white'
        when ethnicity LIKE '%Swiss%' then 'white'
        when ethnicity LIKE '%Hungarian%' then 'white'
        when ethnicity LIKE '%Greek%' then 'white'
        when ethnicity LIKE '%Breton%' then 'white'
        when ethnicity LIKE '%Sorbian%' then 'white'
        when ethnicity LIKE '%Russian%' then 'white'
        when ethnicity LIKE '%Slovak%' then 'white'
        when ethnicity LIKE '%Croatian%' then 'white'
        when ethnicity LIKE '%Slovenian%' then 'white'
        when ethnicity LIKE '%Sicilian%' then 'white'
        when ethnicity LIKE '%Canadian%' then 'white'
        when ethnicity LIKE '%Cornish%' then 'white'
        when ethnicity LIKE '%Channel Islander%' then 'white'
        when ethnicity LIKE '%Jersey%' then 'white'
        when ethnicity LIKE '%Guernsey%' then 'white'
        when ethnicity LIKE '%Canadian%' then 'white'
        when ethnicity LIKE '%Spanish%' then 'white'
        when ethnicity LIKE '%Czech%' then 'white'
        when ethnicity LIKE '%Lithuanian%' then 'white'
        when ethnicity LIKE '%Scandinavian%' then 'white'
        when ethnicity LIKE '%Serbian%' then 'white'
        when ethnicity LIKE '%Bohemian%' then 'white'
        when ethnicity LIKE '%British%' then 'white'
        when ethnicity LIKE '%Walloon%' then 'white'
        when ethnicity LIKE '%Polish%' then 'white'
        when ethnicity LIKE '%Judaism%' then 'white'
        when ethnicity LIKE '%Catalan%' then 'white'
        when ethnicity LIKE '%Ecuadorian%' then 'white'
        when ethnicity LIKE '%European%' then 'white'
        when ethnicity LIKE '%Extremaduran%' then 'white'
        when ethnicity LIKE '%Frisian%' then 'white'
        when ethnicity LIKE '%Galacian%' then 'white'
        when ethnicity LIKE '%Icelandic%' then 'white'
        when ethnicity LIKE '%Isle of Man%' then 'white'
        when ethnicity LIKE '%Latvian%' then 'white'
        when ethnicity LIKE '%Rusyn%' then 'white'
        when ethnicity LIKE '%Moravian%' then 'white'
        when ethnicity LIKE '%Romanian%' then 'white'
        when ethnicity LIKE '%Ruthenian%' then 'white'
        when ethnicity LIKE '%Ukranian%' then 'white'
        when ethnicity LIKE '%Ulster%' then 'white'
        when ethnicity LIKE '%Portuguese%' then 'white'
        when ethnicity LIKE '%Maltese%' then 'white'
        when ethnicity LIKE '%Greenlic%' then 'white'
        when ethnicity LIKE '%Maltese%' then 'white'
        else 'non-white'
        end;"""
c.execute(q)
cnx.commit()

cnx.close()
